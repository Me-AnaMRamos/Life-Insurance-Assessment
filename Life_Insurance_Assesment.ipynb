# %% [markdown]
# # Multilayer Perceptron for Risk Classification of Life Insurance Applicants
#
# ## Introduction
#
# Traditionally, underwriters in insurance companies have collaborated closely with pricing actuaries to evaluate and manage risks, establishing prices (pure risk premium) in line with the company's risk management policies. This process required underwriters to manually review extensive information to determine pricing, including identifying insurable perils, defining policy coverage, and assessing the level of risk posed to the insured.
#
# Nowadays, the underwriting process is becoming increasingly automated, enabling insurers to make rapid decisions regarding underwriting and pricing while providing tailored coverage specific to each client's risk profile. However, in a world where on-demand services are the norm, the life insurance application process remains outdated. Customers still need to provide extensive information for risk classification and eligibility, including scheduling medical exams —a process that typically takes an average of 30 days. [[1]](#R-1)
#
#
# In the coming years, it is anticipated that the underwriting process will be reduced to just a few seconds, thanks to automation supported by machine learning and deep learning models integrated into the technology framework. These models will utilize both internal data from companies and a wide range of external data accessed through application programming interfaces and analytics providers. [[11]](#R-11) To contribute to this evolving process, it is essential to evaluate the suitability of the most promising deep learning models for these tasks, considering their acute predictive abilities for extensive datasets.
#
# ## Objective
#
# The aim of this project is to build a neural network model to predict risk ratings for life insurance applicants, and to evaluate and compare its performance against other machine learning models. This will determine its suitability for the task of risk assessment, supporting the modernization of the underwriting process. We will use the dataset featured in the Prudential Life Insurance Assessment competition previously hosted on Kaggle. [[1]](#R-1)
#
#
# ## Project Outline
#
# In this project, we will:
#
# 1. Explore, preprocess, and encode the dataset of life insurance applicants following the recommended procedure at [[10]](#R-10).
# 2. Select, build, and optimize our neural network model for this task following an iterative development process.
# 3. Evaluate its performance and compare it to other machine learning models.
#
#
# ## Table of Contents
#
# - [1 - Data preparation](#1)
#    - [1.1 - Import data](#1.1)
#    - [1.2 - Data Overview](#1.2)
#    - [1.3 - Exploratory data analysis](#1.3)
#    - [1.5 - Train-validation-test split of the dataset](#1.4)
#    - [1.5 - Handling missing values](#1.5)
# - [2 - Feature Engenieering](#2)
#    - [2.1 - One hot encoding](#2.1)
#    - [2.2 - Normalization](#2.2)
#    - [2.3 - K-means clustering](#2.3)
#    - [2.4 - Feature selection](#2.4)
# - [3 - Model development](#3)
#    - [3.1 QWK metric implementation](#3.1)
#    - [3.2 Hyperparametr Optimization](#3.2)
#      - [3.2.1 Model 1: Multilayer perceptron](#3.2.1)
#      - [3.2.2 Model 2: CORN multilayer perceptron](#3.2.2)
#    - [3.3 Model Selection](#3.3)
# - [4 -  Evaluating model performance](#5)
# - [7 - Bibliography](#6)

# %% [markdown]
# <a name='1'></a>
# # 1. Data Preparation
#
# <a name='1.1'></a>
# ## 1.1 Import the Data
#
# First we'll start by importing the necessary libaries for the preprocessing and feature engenieering part of our data.

# %%
# Import key modules that will be used throughout the project.

#import sys
#import math

import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt # graphs/plotting
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
import keras_tuner as kt

from sklearn.preprocessing import LabelEncoder
from scikitplot.metrics import plot_roc, plot_confusion_matrix
from sklearn.metrics import classification_report, balanced_accuracy_score

import coral_ordinal as coral

def print_colored(text, color='puple'):
     print(text)


# # Check to ensure that both CSV files are held in the correct (input) directory.
import os
# for dirname, _, filenames in os.walk('.\data_set'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
# Load data
main_data = pd.read_csv('Data_sets/train.csv')
# Set 'id' as the index column.
main_data_index_set = main_data.set_index('Id')

# %% [markdown]
# <a name='1.2'></a>
# ## 1.2 Data preview
#
#
# Now we'll review a summary of our data, and visualize some of the risk features for the first applicants.

# %%
# Review the main characteristics of the Pandas dataframe.
print_colored("Columns datatypes:\n", color="purple")
print(main_data.dtypes)
print()
# Out:
# Columns datatypes:
#
# Id                      int64
# Product_Info_1          int64
# Product_Info_2         object
# Product_Info_3          int64
# Product_Info_4        float64
#                        ...
# Medical_Keyword_45      int64
# Medical_Keyword_46      int64
# Medical_Keyword_47      int64
# Medical_Keyword_48      int64
# Response                int64
# Length: 128, dtype: object

# %%
# Use select_dtypes to select columns with non-numeric data types
non_numeric_columns = main_data.select_dtypes(exclude=['number']).columns
print_colored("Columns with non-numeric values:\n", color="purple")
print(non_numeric_columns)
print()
# Out:
# Columns with non-numeric values:
#
# Index(['Product_Info_2'], dtype='object')

# %%
# Analyze dataframe
print_colored("Data Summary:", color="purple")
main_data.describe()
# Out:
# Data Summary:
#                  Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# count  59381.000000    59381.000000    59381.000000    59381.000000
# mean   39507.211515        1.026355       24.415655        0.328952
# std    22815.883089        0.160191        5.072885        0.282562
# min        2.000000        1.000000        1.000000        0.000000
# 25%    19780.000000        1.000000       26.000000        0.076923
# 50%    39487.000000        1.000000       26.000000        0.230769
# 75%    59211.000000        1.000000       26.000000        0.487179
# max    79146.000000        2.000000       38.000000        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7       Ins_Age  \
# count    59381.000000    59381.000000    59381.000000  59381.000000
# mean         2.006955        2.673599        1.043583      0.405567
# std          0.083107        0.739103        0.291949      0.197190
# min          2.000000        1.000000        1.000000      0.000000
# 25%          2.000000        3.000000        1.000000      0.238806
# 50%          2.000000        3.000000        1.000000      0.402985
# 75%          2.000000        3.000000        1.000000      0.567164
# max          3.000000        3.000000        3.000000      1.000000
#
#                  Ht            Wt  ...  Medical_Keyword_40  \
# count  59381.000000  59381.000000  ...        59381.000000
# mean       0.707283      0.292587  ...            0.056954
# std        0.074239      0.089037  ...            0.231757
# min        0.000000      0.000000  ...            0.000000
# 25%        0.654545      0.225941  ...            0.000000
# 50%        0.709091      0.288703  ...            0.000000
# 75%        0.763636      0.345188  ...            0.000000
# max        1.000000      1.000000  ...            1.000000
#
#        Medical_Keyword_41  Medical_Keyword_42  Medical_Keyword_43  \
# count        59381.000000        59381.000000        59381.000000
# mean             0.010054            0.045536            0.010710
# std              0.099764            0.208479            0.102937
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        Medical_Keyword_44  Medical_Keyword_45  Medical_Keyword_46  \
# count        59381.000000        59381.000000        59381.000000
# mean             0.007528            0.013691            0.008488
# std              0.086436            0.116207            0.091737
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        Medical_Keyword_47  Medical_Keyword_48      Response
# count        59381.000000        59381.000000  59381.000000
# mean             0.019905            0.054496      5.636837
# std              0.139676            0.226995      2.456833
# min              0.000000            0.000000      1.000000
# 25%              0.000000            0.000000      4.000000
# 50%              0.000000            0.000000      6.000000
# 75%              0.000000            0.000000      8.000000
# max              1.000000            1.000000      8.000000
#
# [8 rows x 127 columns]

# %%
main_data_index_set.head()
# Out:
#     Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# Id
# 2                1             D3              10        0.076923
# 5                1             A1              26        0.076923
# 6                1             E1              26        0.076923
# 7                1             D4              10        0.487179
# 8                1             D2              26        0.230769
#
#     Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# Id
# 2                2               1               1  0.641791  0.581818
# 5                2               3               1  0.059701  0.600000
# 6                2               3               1  0.029851  0.745455
# 7                2               3               1  0.164179  0.672727
# 8                2               3               1  0.417910  0.654545
#
#           Wt  ...  Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# Id            ...
# 2   0.148536  ...                   0                   0                   0
# 5   0.131799  ...                   0                   0                   0
# 6   0.288703  ...                   0                   0                   0
# 7   0.205021  ...                   0                   0                   0
# 8   0.234310  ...                   0                   0                   0
#
#     Medical_Keyword_43  Medical_Keyword_44  Medical_Keyword_45  \
# Id
# 2                    0                   0                   0
# 5                    0                   0                   0
# 6                    0                   0                   0
# 7                    0                   0                   0
# 8                    0                   0                   0
#
#     Medical_Keyword_46  Medical_Keyword_47  Medical_Keyword_48  Response
# Id
# 2                    0                   0                   0         8
# 5                    0                   0                   0         4
# 6                    0                   0                   0         8
# 7                    0                   0                   0         8
# 8                    0                   0                   0         8
#
# [5 rows x 127 columns]

# %% [markdown]
# From the cells above, we observe that our dataset comprises approximately 60,000 applicants and their application details, encapsulated by over 100 variables. Our dataframe includes variables of different types, including a non-numeric (character) variable. Among the numeric-valued features, some are normalized, while others are not. We will address this issues during the preprocessing and feature engineering stages.

# %%
# Visualise the distribution of applicants' risk ratings in the full dataset.

plt.hist(main_data_index_set['Response'], bins=sorted(main_data_index_set['Response'].unique()),color='rebeccapurple')
plt.xlabel('Response')
plt.ylabel('# of Applicants')
plt.title('Response Distribution')
# Out:
# Text(0.5, 1.0, 'Response Distribution')

# %% [markdown]
# The histogram depicted above illustrates the distribution of applicants based on their assigned risk ratings (i.e., Response) for the complete dataset. It's noteworthy that the distribution is imbalanced, with a skew towards classes 6-8, although classes 1-2 also represent a significant portion of the dataset.
#
# <a name='1.3'></a>
#
# ## 1.3 Conduct Exploratory Data Analysis (EDA) to Visualize Distributions and Correlations
#
# In the subsequent cell, the features are organized into lists corresponding to each set of variables within the dataset. For example, all variables from Product_Info_1 to Product_Info_7 are grouped under the list ColSet1_ProdInfo. Variables not grouped under any particular category by name are included in the ColSet2_ApplicantInfo list.

# %%
# Split out the full set of the main dataset's columns into separate lists.

ColSet1_ProdInfo = ['Product_Info_1','Product_Info_2','Product_Info_3','Product_Info_4','Product_Info_5','Product_Info_6','Product_Info_7']
ColSet2_ApplicantInfo = ['Ins_Age','Ht','Wt','BMI']
ColSet3_EmploymentInfo = ['Employment_Info_1','Employment_Info_2','Employment_Info_3','Employment_Info_4','Employment_Info_5','Employment_Info_6']
ColSet4_InsuredInfo = ['InsuredInfo_1','InsuredInfo_2','InsuredInfo_3','InsuredInfo_4','InsuredInfo_5','InsuredInfo_6','InsuredInfo_7']
ColSet5_InsuranceHistoryInfo = ['Insurance_History_1','Insurance_History_2','Insurance_History_3','Insurance_History_4','Insurance_History_5','Insurance_History_7','Insurance_History_8','Insurance_History_9']
ColSet6_FamilyHistoryInfo = ['Family_Hist_1','Family_Hist_2','Family_Hist_3','Family_Hist_4','Family_Hist_5']

ColSet7_MedicalHistoryInfo = ['Medical_History_1','Medical_History_2','Medical_History_3','Medical_History_4','Medical_History_5','Medical_History_6','Medical_History_7','Medical_History_8',
                              'Medical_History_9','Medical_History_10','Medical_History_11','Medical_History_12','Medical_History_13','Medical_History_14','Medical_History_15',
                              'Medical_History_16','Medical_History_17','Medical_History_18','Medical_History_19','Medical_History_20','Medical_History_21','Medical_History_22',
                              'Medical_History_23','Medical_History_24','Medical_History_25','Medical_History_26','Medical_History_27','Medical_History_28','Medical_History_29',
                              'Medical_History_30','Medical_History_31','Medical_History_32','Medical_History_33','Medical_History_34','Medical_History_35','Medical_History_36',
                              'Medical_History_37','Medical_History_38','Medical_History_39','Medical_History_40','Medical_History_41']

ColSet8_MedicalKeywordInfo = ['Medical_Keyword_1','Medical_Keyword_2','Medical_Keyword_3','Medical_Keyword_4','Medical_Keyword_5','Medical_Keyword_6','Medical_Keyword_7','Medical_Keyword_8',
                              'Medical_Keyword_9','Medical_Keyword_10','Medical_Keyword_11','Medical_Keyword_12','Medical_Keyword_13','Medical_Keyword_14','Medical_Keyword_15','Medical_Keyword_16',
                              'Medical_Keyword_17','Medical_Keyword_18','Medical_Keyword_19','Medical_Keyword_20','Medical_Keyword_21','Medical_Keyword_22','Medical_Keyword_23','Medical_Keyword_24',
                              'Medical_Keyword_25','Medical_Keyword_26','Medical_Keyword_27','Medical_Keyword_28','Medical_Keyword_29','Medical_Keyword_30','Medical_Keyword_31','Medical_Keyword_32',
                              'Medical_Keyword_33','Medical_Keyword_34','Medical_Keyword_35','Medical_Keyword_36','Medical_Keyword_37','Medical_Keyword_38','Medical_Keyword_39','Medical_Keyword_40',
                              'Medical_Keyword_41','Medical_Keyword_42','Medical_Keyword_43','Medical_Keyword_44','Medical_Keyword_45','Medical_Keyword_46','Medical_Keyword_47','Medical_Keyword_48']

# %% [markdown]
# ### Distribution plots
#
# In this section, we will generate Kernel Density Estimate (KDE) plots for each feature - where Response is set as the hue of each curve - in order to compare distributions across each risk rating, and identify any potential trends or correlations within the dataset.

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(25,15))

# Product_Info_2 has been excluded - as this has not yet been encoded into numeric values.
ColSet1_ProdInfo_kde = ['Product_Info_1','Product_Info_3','Product_Info_4','Product_Info_5','Product_Info_6','Product_Info_7']

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet1_ProdInfo_kde].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(25,15))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet3_EmploymentInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(25,20))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet4_InsuredInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])

# Delete any unused sets of axes in the subplot grid.    
fig.delaxes(axes[2,1])
fig.delaxes(axes[2,2])

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(25,20))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet5_InsuranceHistoryInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])
    
# Delete any unused sets of axes in the subplot grid.    
fig.delaxes(axes[2,2])

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=12, ncols=4, figsize=(25,50))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet8_MedicalKeywordInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//4,i%4])
# Out:
# C:\Users\Ramos\AppData\Local\Temp\ipykernel_5480\1793688068.py:6: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=main_data_index_set,

# %% [markdown]
# The KDE plots for the feature sets including Product information, Insured information, Employment information, Medical Keywords, and Insurance History information reveal several distributions with differing modalities. However, a consistent observation across all these sets is the close overlap among the Response groups or cohorts of applicants, with no significant disparities in relative densities. Consequently, any divergence observed in these features is unlikely to contribute significantly to predicting an applicant's risk rating independently.

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(25,15))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet2_ApplicantInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//2,i%2])

# %% [markdown]
# The Kernel Density Estimate (KDE) plots for Ins_Age, Ht, Wt, and BMI illustrate significant variations in the composition and structure of each Response group's distribution. While the majority of the density is concentrated within specific ranges for each feature, there are noticeable differences in skewness among the Response groups. For instance, class 8 exhibits positive skewness in Ins_Age, Ht, Wt, and BMI, while most other classes display negative skewness. Additionally, class 8 presents distinct patterns, such as lower values in Wt and higher values in BMI compared to other classes, suggesting potential correlations with risk ratings. These observations align with expectations regarding health-related factors such as weight, BMI, and age.

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(25,15))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet6_FamilyHistoryInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])

# Delete any unused sets of axes in the subplot grid.    
fig.delaxes(axes[1,2])

# %%
# Review the main characteristics of the Pandas dataframe.
print_colored("Family_Hist_1 datatype:\n", color="purple")
print(main_data["Family_Hist_1"].dtypes)
print()
# Analyze dataframe
print_colored("Family_Hist_1 Summary:", color="purple")
main_data["Family_Hist_1"].describe()
# Out:
# Family_Hist_1 datatype:
#
# int64
#
# Family_Hist_1 Summary:
# count    59381.000000
# mean         2.686230
# std          0.483159
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max          3.000000
# Name: Family_Hist_1, dtype: float64

# %% [markdown]
# The Family_Hist_1 variable is integer type, constrained within values from 1 to 3, and its KDE shows a prominent density at 3, a medium at 2 and a very low one at 1. Howver, this feature shows minimal variation in relative densities across different Response classes, suggesting it may not significantly influence predicting an applicant's risk rating.
#
# On the other hand, the KDE plots for Family_Hist_2 to Family_Hist_5 depict unimodal distributions, each displaying varying shapes and structures across Response groups. These distributions often show widening and shouldering of peaks, with the majority of densities concentrated between x=0.2 and x=0.8. While the shapes and skewness/kurtosis of these distributions differ among cohorts, class 8 generally demonstrates higher positive kurtosis compared to other classes, with broader density plots being characteristic of most other Response groups.

# %%
# Set up a subplot grid.
fig, axes = plt.subplots(nrows=11, ncols=4, figsize=(25,75))

# Produce kernel density estimate plots for each set of columns.
for i, column in enumerate(main_data_index_set[ColSet7_MedicalHistoryInfo].columns):
    sns.kdeplot(data=main_data_index_set,
                x=column,
                hue="Response", fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//4,i%4])

# Delete any unused sets of axes in the subplot grid.    
fig.delaxes(axes[10,1])
fig.delaxes(axes[10,2])
fig.delaxes(axes[10,3])
# Out:
# C:\Users\Ramos\AppData\Local\Temp\ipykernel_5480\217326378.py:6: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=main_data_index_set,

# %% [markdown]
# The majority of these KDE plots demonstrate distributions that closely overlap among each Response group or cohort of applicants, indicating that variations in the underlying features are unlikely to provide significant predictive power individually for determining an applicant's risk rating. However, there are notable exceptions:
#
# - Medical_History_2, Medical_History_15, Medical_History_24: These KDE plots display multimodal distributions with some degree of predictive distinction in terms of variance. The peaks of each Response group's distribution show varying levels of broadening and shouldering. However, it's crucial to consider the y-axis scales, as the densities for each underlying distribution are very small, limiting their individual predictive power.
#
# - Medical_History_10: In the KDE plot, we observe that for cohorts of low-risk applicants, the distributions appear bimodal, whereas for higher risk levels, the distribution tends to have a single peak. However, it's important to note that this column contains a high proportion of missing values. Therefore, the distributions should not be considered highly predictive.
#
# - Medical_History_23: This KDE plot suggests some potential predictive power. As the Response value or risk rating increases, each peak in the bimodal distribution becomes sharper, indicating more positive kurtosis. In simpler terms, values further away from the peak centers tend to correlate with lower risk ratings, while values closely overlapping with the peaks tend to represent applicants with higher risk ratings.
#
# ## Correlation plots/heatmaps
#
# Next, we will generate a correlation heatmap plot for all features to better understand the correlations between each pair of features and uncover possible interactions within the data.

# %%
# Replace non-numeric values with NaN
main_data_index_set_numeric = main_data_index_set.apply(pd.to_numeric, errors='coerce')

# Produce a correlation matrix of the dataset
corrs = main_data_index_set_numeric.corr()

# Plot the correlation matrix as a heatmap using Seaborn
plt.figure(figsize=(45,40))
sns.heatmap(corrs, cmap='RdBu_r', mask=np.triu(corrs))
plt.show()

# %% [markdown]
# Based on the chart above, we can deduce the following insights regarding each column set:
#
# - Column Set 1 - Product Info: These columns demonstrate minimal interaction or correlation with the majority of other feature sets. However, exceptions include Employment_Info_1, Employment_Info_5, and Insured_Info_6, which may directly correlate due to factors such as an applicant's employment or financial status influencing the type of policy or product they apply for.
#
# - Column Set 2 - Applicant Info: These columns display a varied range of interactions with other feature sets. Notably, strong anti-/correlations (excluding those within the same column set) are observed between several Family_Hist columns and Insured_Info_6.
#
# - Column Set 3 - Employment Info: Apart from two notable anti-correlations - between Employment_Info_2 and Employment_Info_3, and Employment_Info_5 and Product_Info_3 - and a few moderate interactions with Employment_Info_6 and Family_Hist_2 / Family_Hist_4, this column set exhibits relatively weak interactions with other features.
#
# - Column Set 4 - Insured Info: The column InsuredInfo_2 shows a relatively strong correlation with InsuredInfo_7, and also strong anticorrelations with some Applicant Info columns. Otherwise, this column set shows limited interactions with other features.
#
# - Column Set 5 - Insurance History Info: This feature set demonstrates several strong inter-correlations among other Insurance_History columns, but does not show significant interactions with other features.
#
# - Column Set 6 - Family History Info: Family_Hist_2 and Family_Hist_4 exhibit a notably strong positive correlation with Ins_Age, as well as with Medical_History_10 and Medical_History_15 to a lesser extent.
#
# - Column Set 7 - Medical History Info: This column set reveals several correlation hotspots with several Medical_Keyword columns, as well as with Ins_Age and some Family_Hist columns.
#
# - Column Set 8 - Medical Keyword Info: These columns exhibit correlation hotspots with several Medical_History columns but do not show significant interactions with other features.
#
# ### Missing Values and Excess Zeroes
#
# To avoid test-data leakage during our model validation and testing process, it is crucial to use only a "training" set of data to assess the completeness of our data. Therefore, we will split the full dataset into training, validation, and testing sets. We will then review the training set for missing values and excess zeroes.
#
# <a name='1.4'></a>
# ## 1.4 Perform a train-validation-test split of the dataset
#
# Here, we will create separate dataframes to store the features and target variables.
#
# These dataframes will then be used with the train_test_split() function from scikit-learn to split the data into training, validation, and test subsets.

# %%
# Assign the features to their own dataframe.
X_full = main_data_index_set.drop(['Response'], axis=1)

# Assign the target variable to its own dataframe.
y_full = main_data_index_set.Response

# Perform a train-test split to obtain the training, validation and test data as separate dataframes.
from sklearn.model_selection import train_test_split

# Split out test/holdout set from full dataset.
# We will set the size of the X/y test datasets to be 20% of the original (full) X/y datasets, via the train_size/test_size parameters.
X_rem, X_test, y_rem, y_test = train_test_split(X_full, y_full, train_size=0.8, test_size=0.2, random_state=0, stratify=y_full)

# Split remaining portion into training/validation sets.
# We will set the size of the X/y train datasets to be 60% of the original (full) X/y datasets, via the train_size/test_size parameters.
X_train, X_valid, y_train, y_valid = train_test_split(X_rem, y_rem, train_size=0.75, test_size=0.25, random_state=0, stratify=y_rem)

# %% [markdown]
# <a name='1.5'></a>
# ## 1.5 Handling missing values
#
# We will now review the training subset to identify where missing values occur. We assume that any missing data are Missing Completely at Random (MCAR) and that any subsequent analysis or imputation will not introduce implicit bias.

# %%
# Determine which columns contain nulls/missing values.
X_train_cols_with_missing = [col for col in X_train.columns
                     if X_train[col].isnull().any()]

# Summarise how many missing values are present in each column.
X_train[X_train_cols_with_missing].isna().sum()
# Out:
# Employment_Info_1         16
# Employment_Info_4       4002
# Employment_Info_6       6518
# Insurance_History_5    15196
# Family_Hist_2          17141
# Family_Hist_3          20591
# Family_Hist_4          11458
# Family_Hist_5          25107
# Medical_History_1       5368
# Medical_History_10     35299
# Medical_History_15     26744
# Medical_History_24     33312
# Medical_History_32     34980
# dtype: int64

# %%
## Calculate the proportion of zeroes relative to non-zero values.
for col in X_train_cols_with_missing:
    sum = X_train[col].isna().sum()
    length = len(X_train[col].index)
    ratio = sum/length
    print('Proportion of zeroes in', col, 'is: ', round(ratio*100,2), '%.')
# Out:
# Proportion of zeroes in Employment_Info_1 is:  0.04 %.
# Proportion of zeroes in Employment_Info_4 is:  11.23 %.
# Proportion of zeroes in Employment_Info_6 is:  18.29 %.
# Proportion of zeroes in Insurance_History_5 is:  42.65 %.
# Proportion of zeroes in Family_Hist_2 is:  48.11 %.
# Proportion of zeroes in Family_Hist_3 is:  57.79 %.
# Proportion of zeroes in Family_Hist_4 is:  32.16 %.
# Proportion of zeroes in Family_Hist_5 is:  70.47 %.
# Proportion of zeroes in Medical_History_1 is:  15.07 %.
# Proportion of zeroes in Medical_History_10 is:  99.08 %.
# Proportion of zeroes in Medical_History_15 is:  75.06 %.
# Proportion of zeroes in Medical_History_24 is:  93.5 %.
# Proportion of zeroes in Medical_History_32 is:  98.18 %.

# %% [markdown]
# Several columns have been identified in the code above with varying proportions of missing values. Some columns have manageable amounts of missing data and can be preprocessed using imputation methods. However, a few columns are highly incomplete. To avoid introducing significant bias into these features' distributions, we will delete columns where the proportion of missing values in the training subset exceeds 40%.

# %%
# These columns have been selected as they contain a high proportion of blanks/missing values (deemed here as >40%) in the TRAINING dataset.
cols_to_delete_due_to_missing_data = ['Insurance_History_5',
                                      'Family_Hist_2', 'Family_Hist_3', 'Family_Hist_5',
                                      'Medical_History_10', 'Medical_History_15', 'Medical_History_24', 'Medical_History_32']

# Delete columns from ALL datasets where the proportion of zeroes in the TRAINING dataset exceeds a stipulated threshold.
X_train = X_train.drop(cols_to_delete_due_to_missing_data, axis=1)
X_valid = X_valid.drop(cols_to_delete_due_to_missing_data, axis=1)
X_test = X_test.drop(cols_to_delete_due_to_missing_data, axis=1)

# %%
# These columns still contain missing values, and require imputation before they can be supplied as inputs to each ML classifier.
cols_to_impute = ['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6',
                 'Family_Hist_4',
                 'Medical_History_1']

# %%
# Import the IterativeImputer class from sklearn - NOTE: enable_iterative_imputer also needs to be imported as this is an experimental feature. 
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Take a copy of each dataset before transforming.
copy_X_train = X_train.copy()
copy_X_valid = X_valid.copy()
copy_X_test = X_test.copy()

# Filter the splits down to the columns that require imputation.
X_train_pre_impute = copy_X_train[cols_to_impute]
X_valid_pre_impute = copy_X_valid[cols_to_impute]
X_test_pre_impute = copy_X_test[cols_to_impute]

# Save the other columns into separate dataframes, for re-joining later on.
X_train_no_impute = copy_X_train.drop(cols_to_impute, axis=1)
X_valid_no_impute = copy_X_valid.drop(cols_to_impute, axis=1)
X_test_no_impute = copy_X_test.drop(cols_to_impute, axis=1)

# Initialise the IterativeImputer transformer.
X_imputer = IterativeImputer(random_state=0)

# Transform the train/val/test datasets using iterative imputation.
X_train_post_impute = pd.DataFrame(X_imputer.fit_transform(X_train_pre_impute), columns=X_train_pre_impute.columns)
X_valid_post_impute = pd.DataFrame(X_imputer.transform(X_valid_pre_impute), columns=X_valid_pre_impute.columns)
X_test_post_impute = pd.DataFrame(X_imputer.transform(X_test_pre_impute), columns=X_train_pre_impute.columns)

# Reset the indexes of each dataset, as they are dropped during imputation.
X_train_post_impute.index = X_train_pre_impute.index
X_valid_post_impute.index = X_valid_pre_impute.index
X_test_post_impute.index = X_test_pre_impute.index

# Re-join the imputed columns with the remaining columns in each dataset.
X_train_imputed = pd.concat([X_train_no_impute, X_train_post_impute], axis=1)
X_valid_imputed = pd.concat([X_valid_no_impute, X_valid_post_impute], axis=1)
X_test_imputed = pd.concat([X_test_no_impute, X_test_post_impute], axis=1)

# %% [markdown]
# ### Checks - before/after iterative imputation
# We will now review the dataset both before and after iterative imputation to understand how each column's distribution has been affected.

# %%
# KDE Plots - Before imputation.

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(25,10))

for i, column in enumerate(main_data_index_set[X_train_post_impute.columns].columns):
    sns.kdeplot(data=main_data_index_set[X_train_post_impute.columns],
                x=column,
                fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])
    
fig.delaxes(axes[1,2])

# %%
# KDE Plots - After imputation.

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(25,10))

for i, column in enumerate(X_train_post_impute.columns):
    sns.kdeplot(data=X_train_post_impute,
                x=column,
                fill=True, common_norm=True, alpha=0.05,
                ax=axes[i//3,i%3])
    
fig.delaxes(axes[1,2])

# %% [markdown]
# As shown above, three of the five columns' distributions appear to be mostly unchanged. However, we have introduced additional probability density and peak splitting in Family_Hist_4 (at approximately x=0.4 and x=0.6) and Medical_History_1 (at approximately x=10).
#
# <a name='2'></a>
# # 2. Perform feature engineering (using training data)
#
# In this section, we will normalise the data, implement categorical encoding and K-means clustering in order to create new features within our dataset that our model can be fitted to.

# %%
# Create a clone copy of each imputed dataset to avoid changing any original data.
copy_X_train_imputed = X_train_imputed.copy()
copy_X_valid_imputed = X_valid_imputed.copy()
copy_X_test_imputed = X_test_imputed.copy()

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1. One-Hot Encoding
#
# We will one-hot encode the Product_Info_2 column to convert categorical inputs into numerical, machine-interpretable values.

# %%
from sklearn.preprocessing import OneHotEncoder

# Initialise a one-hot encoder to columns that contain categorical data.
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
OH_col = ['Product_Info_2']

## We set handle_unknown='ignore' to avoid errors when the validation data contains classes that aren't represented
## in the training data, and setting sparse=False ensures that the encoded columns are returned as a numpy array
## (instead of a sparse matrix).

# Use the one-hot encoder to transform the categorical data columns. 
OH_col_train = pd.DataFrame(OH_encoder.fit_transform(copy_X_train_imputed[OH_col]))
OH_col_valid = pd.DataFrame(OH_encoder.transform(copy_X_valid_imputed[OH_col]))
OH_col_test = pd.DataFrame(OH_encoder.transform(copy_X_test_imputed[OH_col]))

# One-hot encoding removes the index; re-assign the original index.
OH_col_train.index = copy_X_train_imputed.index
OH_col_valid.index = copy_X_valid_imputed.index
OH_col_test.index = copy_X_test_imputed.index

# Add column-labelling back in, using the get_feature_names() function. 
OH_col_train.columns = OH_encoder.get_feature_names_out(OH_col)
OH_col_valid.columns = OH_encoder.get_feature_names_out(OH_col)
OH_col_test.columns = OH_encoder.get_feature_names_out(OH_col)

# Create dataframes that only include the numerical features/columns (these will be concatenated with the one-hot encoded dataframes).
copy_X_train_imputed_no_OH_col = copy_X_train_imputed.drop(OH_col, axis=1)
copy_X_valid_imputed_no_OH_col = copy_X_valid_imputed.drop(OH_col, axis=1)
copy_X_test_imputed_no_OH_col = copy_X_test_imputed.drop(OH_col, axis=1)

# Concatenate the one-hot encoded columns with the existing numerical features/columns.
X_train_enc = pd.concat([copy_X_train_imputed_no_OH_col, OH_col_train], axis=1)
X_valid_enc = pd.concat([copy_X_valid_imputed_no_OH_col, OH_col_valid], axis=1)
X_test_enc = pd.concat([copy_X_test_imputed_no_OH_col, OH_col_test], axis=1)

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 Normalization
# Next, we will perform min-max normalization on the encoded datasets, ensuring that all features lie between 0 and 1.

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialise the MinMaxScaler model, then fit it to the (encoded) training dataset.
MM_scaler = MinMaxScaler()
MM_scaler.fit(X_train_enc)

# Then, normalise/transform the training, validation and test datasets.
X_train_scale = pd.DataFrame(MM_scaler.transform(X_train_enc),
                             index=X_train_enc.index,
                             columns=X_train_enc.columns)

X_valid_scale = pd.DataFrame(MM_scaler.transform(X_valid_enc),
                             index=X_valid_enc.index,
                             columns=X_valid_enc.columns)

X_test_scale = pd.DataFrame(MM_scaler.transform(X_test_enc),
                             index=X_test_enc.index,
                             columns=X_test_enc.columns)

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 K-means clustering

# %%
# Create copies of the scaled datasets, prior to performing K-Means clustering.
copy_X_train_scale = X_train_scale.copy()
copy_X_valid_scale = X_valid_scale.copy()
copy_X_test_scale = X_test_scale.copy()

from sklearn.cluster import KMeans

# %%
# Determine the optimal number of clusters.
# Method: Cluster the dataset into k clusters, then calculate the inertia/sum of squared distances.
# Repeat this by looping through k=1 to k=30.

Sum_of_squared_distances = []
K = range(1,30)
for k in K:
    km = KMeans(n_clusters=k, n_init='auto')
    km = km.fit(copy_X_train_scale)
    Sum_of_squared_distances.append(km.inertia_)

# %%
# Determine the optimal number of clusters.
# Method: Cluster the dataset into k clusters, then calculate the inertia/sum of squared distances.
# Repeat this by looping through k=1 to k=30.

Sum_of_squared_distances = []
K = range(1,30)
for k in K:
    km = KMeans(n_clusters=k, n_init='auto')
    km = km.fit(copy_X_train_scale)
    Sum_of_squared_distances.append(km.inertia_)

# %%
# Create a plot of K-values versus their respective inertias/sums of squared distances.
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# As shown above, the "elbow" of the curve begins to form at k=15.
#
# Increasing k beyond this value does not yield a significant benefit in the rate of reduction in the training dataset's inertia - hence, we will set k=15 when initialising the KMeans() clustering algorithm below.

# %%
# Set n_clusters=15, as derived from the elbow-method analysis above:
kmeans = KMeans(n_clusters=15, n_init=10, random_state=0)

# Fit the K-Means clustering algorithm to the training dataset, then predict the train/valid/test datasets.
copy_X_train_scale["Cluster"] = kmeans.fit_predict(copy_X_train_scale)
copy_X_valid_scale["Cluster"] = kmeans.predict(copy_X_valid_scale)
copy_X_test_scale["Cluster"] = kmeans.predict(copy_X_test_scale)

# Convert the cluster labels into one-hot encoded variants.
X_train_cluster_OH_enc = pd.get_dummies(copy_X_train_scale.Cluster).add_prefix('KMeansCluster_')
X_valid_cluster_OH_enc = pd.get_dummies(copy_X_valid_scale.Cluster).add_prefix('KMeansCluster_')
X_test_cluster_OH_enc = pd.get_dummies(copy_X_test_scale.Cluster).add_prefix('KMeansCluster_')

# Re-join the K-Means clustering labels onto the original dataframes.
X_train_KMeans = pd.concat([copy_X_train_scale, X_train_cluster_OH_enc], axis=1)
X_valid_KMeans = pd.concat([copy_X_valid_scale, X_valid_cluster_OH_enc], axis=1)
X_test_KMeans = pd.concat([copy_X_test_scale, X_test_cluster_OH_enc], axis=1)

# Remove the initially derived "Cluster" columns from each dataset.
X_train_KMeans = X_train_KMeans.drop(['Cluster'], axis=1)
X_valid_KMeans = X_valid_KMeans.drop(['Cluster'], axis=1)
X_test_KMeans = X_test_KMeans.drop(['Cluster'], axis=1)

# %% [markdown]
# <a name='2.4'></a>
# ### 2.4 Feature selection

# %% [markdown]
# We will perform feature selection using validation data via L1 (lasso) regularisation using functions that are readily available in sklearn - for more information, see this link: Feature Selection via scikit-learn.

# %%
# Import key modules in order to perform LASSO-based feature selection.
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

# Establish the Lasso (L1) Regularisation model that will perform feature selection.
linearsvc = LinearSVC(penalty="l1", dual=False, tol=1e-3, C=1e-2, random_state=0).fit(X_valid_KMeans, y_valid)
model = SelectFromModel(linearsvc, prefit=True)

# Reduce the dataset to the most important features, using the regularisation model above.
X_valid_L1 = model.transform(X_valid_KMeans)

# Convert the transformed dataset into a dataframe with the same size/shape as the original dataset.
# For features that were previously removed, this dataset will now include zeroes instead of their original values.
selected_features = pd.DataFrame(model.inverse_transform(X_valid_L1),
                                 index=X_valid_KMeans.index,
                                 columns=X_valid_KMeans.columns)

# Drop columns from the dataframe where features are deemed unimportant in capturing the dataset's variance.
# To achieve this, we selectively drop columns where their variance is equal to 0 (i.e. where a column only contains zeroes).
X_valid_L1reg = selected_features.drop(selected_features.columns[selected_features.var() == 0], axis=1)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Determine the number of columns that are kept after L1 regularisation.

len(selected_features.columns[selected_features.var() != 0])
# Out:
# 57

# %%
# Produce a separate list containing the columns preserved after L1 regularisation.
selected_columns = selected_features.columns[selected_features.var() != 0]

# Reduce the training/test datasets to the same set of columns.
X_train_L1reg = X_train_KMeans[selected_columns]
X_test_L1reg = X_test_KMeans[selected_columns]

# %%
print("X_train_L1reg shape:", X_valid_L1reg.shape)  # e.g., (N, 58)
# Out:
# X_train_L1reg shape: (11876, 57)

# %%
# Label-encode each dataset for compatibility with the XGBoost classifier (model 12) - "use_label_encoder" has since become deprecated.
le = LabelEncoder()


# Convert each set of class labels (1-8) into encoded labels (0-7).
y_train = le.fit_transform(y_train)
y_valid = le.transform(y_valid)
y_test = le.transform(y_test)

# %%
# # Save Preprocessed Datasets 
# X_train_L1reg.to_csv('X_train_preprocessed.csv', index=False)
# X_valid_L1reg.to_csv('X_valid_preprocessed.csv', index=False)
# X_test_L1reg.to_csv('X_test_preprocessed.csv', index=False)

# %%
# Load Preprocessed Datasets 
X_train_L1reg = pd.read_csv('X_train_preprocessed.csv')
X_valid_L1reg = pd.read_csv('X_valid_preprocessed.csv')
X_test_L1reg = pd.read_csv('X_test_preprocessed.csv')

# %%
# Convert pandas dataframes to numpy arrays for hyperparameter tuning

X_train_L1reg_np=X_train_L1reg.to_numpy().astype('float32')
X_test_L1reg_np=X_test_L1reg.to_numpy().astype('float32')
X_valid_L1reg_np=X_valid_L1reg.to_numpy().astype('float32')

# %% [markdown]
# <a name='3'></a>
# # 3. Model Development
#
#
# The basic model architecture we have selected is the standard model for tabular data: a multilayer perceptron. To avoid the vanishing gradients problem, each hidden layer will have RELU as the activation function, and the optimization algorithm will be backpropagation.
#
# $$Input -> (Linear -> RELU) x #Hidden Layers -> Output$$
#
# During the iterative development of our model, following the strategy at [(#)], we will explore, optimize, and evaluate two variations of this architecture.
#
# - ### Model 1: Regular Multilayer Perceptron
# The output layer of this model uses the softmax activation function, and the loss function is cross-entropy, as is standard for multi-classification problems.
#
# $$Input -> (Linear -> RELU) x #Hidden Layers -> SOFTMAX$$
#
# - ### Model 2: Ordinal Multilayer Perceptron
# The structure of the hidden layers is the same as the previous model, but the last layer is a logits layer with 7 units, each representing a conditional probability score - the probability of the data point belonging to a class greater than the unit's class given that it belongs to a class greater or equal to it. The loss function will be the CoRan Loss function as presented in the paper [()]. This method accounts for the ordinal nature of the classification problem.
#
# $$Input -> (Linear -> RELU) x #Hidden Layers -> LOGITS$$
#
# We will also consider batch normalization for more rapid convergence of the model and for its regularizing effects. Additionally, we'll employ dropout layers as a regularization method, exploring different rates if a model exhibits significant variance.
#
# $$Input -> ( (Batch_Norm ->) Linear -> (Dropout ->) RELU ) x #Hidden Layers -> Output$$
#
# We will utilize the TensorFlow Keras Sequential API to construct the multilayer perceptron models and leverage the TensorFlow KerasTuner API for efficient hyperparameter tuning of the models. We'll employ the hyperband search method to tune the number of layers, units per layer, learning rate, and mini-batch size hyperparameters, choosing them to minimize the loss function of each model.
#
# The metric that will ultimately decide the best model will be the Quadratic Weighted Kappa metric, tailored for ordinal classification tasks and used in the Prudential Financial Kaggle competition to evaluate performance. We will consider a performance of 0.679 in this metric as our baseline, as it was the best performance in the competition.
#
# <a name='3.1'></a>
# ## 3.1 Quadratic Weighted Kappa Metric Implementation
#
# We have implemented the quadratic weighted kappa metric for tensors to use it with the Keras Tuner API.

# %%
# Metric for the hyperparameter optimization of ordinal classification tasks
@keras.saving.register_keras_serializable(package="custom_package", name="QuadraticWeightedKappa")
def QuadraticWeightedKappa(y_true, y_pred_probs, N=8):
    
    """
    Calculate quadratic weighted kappa metric.

    Args:
    - y_true: tf.Tensor of true labels (actual risk) 
    - y_pred_probs: tf.Tensor of predicted probabilities (predicted risk) 
    - N: number of possible ratings

    Returns:
    - Quadratic weighted kappa score
    """

    # Convert probabilities to class predictions        
    y_pred = tf.argmax(y_pred_probs, axis=1)
    
    # Calculate the histogram matrix O
    O = tf.math.confusion_matrix(y_true, y_pred, num_classes=N)
    
    # Calculate the weights matrix w
    i, j = tf.meshgrid(tf.range(N), tf.range(N), indexing='ij')
    w = tf.cast((i - j) ** 2, tf.float32) / tf.cast((N - 1) ** 2, tf.float32)

    # Calculate the histogram matrix of expected ratings E
    hist_true = tf.math.bincount(tf.cast(y_true, tf.int32), minlength=N)
    hist_pred = tf.math.bincount(tf.cast(y_pred, tf.int32), minlength=N)
    E = tf.linalg.matmul(tf.expand_dims(hist_true, axis=-1), tf.expand_dims(hist_pred, axis=0))
    E = tf.cast(E, tf.float32)  # Cast E to float32
    E *= tf.cast(tf.reduce_sum(O),tf.float32)/ tf.reduce_sum(E) 
    
    # Calculate quadratic weighted kappa
    numerator = tf.reduce_sum(w * tf.cast(O, tf.float32))
    denominator = tf.reduce_sum(w * E)
    kappa = 1 - (numerator / denominator)

    return kappa

# %%
import tensorflow as tf
@keras.saving.register_keras_serializable(package="metrics", name="QuadraticWeightedKappaMetric")

class QuadraticWeightedKappaMetric(tf.keras.metrics.Metric):
    def __init__(self, num_classes=8, name="quadratic_weighted_kappa", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.kappa = self.add_weight(name="qwk", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred_classes = tf.argmax(y_pred, axis=1, output_type=tf.int32)
        y_true = tf.cast(y_true, tf.int32)

        O = tf.math.confusion_matrix(y_true, y_pred_classes, num_classes=self.num_classes)

        i, j = tf.meshgrid(tf.range(self.num_classes), tf.range(self.num_classes), indexing='ij')
        w = tf.cast((i - j) ** 2, tf.float32) / tf.cast((self.num_classes - 1) ** 2, tf.float32)

        hist_true = tf.math.bincount(y_true, minlength=self.num_classes)
        hist_pred = tf.math.bincount(y_pred_classes, minlength=self.num_classes)

        E = tf.tensordot(tf.expand_dims(hist_true, 1), tf.expand_dims(hist_pred, 0), axes=1)
        E = tf.cast(E, tf.float32)
        E *= tf.reduce_sum(tf.cast(O, tf.float32)) / tf.reduce_sum(E)

        numerator = tf.reduce_sum(w * tf.cast(O, tf.float32))
        denominator = tf.reduce_sum(w * E)
        kappa_score = 1.0 - (numerator / denominator)

        self.kappa.assign(kappa_score)

    def result(self):
        return self.kappa

    def reset_state(self):
        self.kappa.assign(0.0)

# %% [markdown]
# <a name='3.2'></a>
# ## 3.2 Hyperparameter Optimization
#
# <a name='3.2.1'></a>
# ### 3.2.1 Model 1: Regular Multilayer Perceptron (MLP)
#
# We will start by constructing the hypermodel to define all hyperparameters and variations of the softmax multilayer perceptron model.

# %%
# Set Random seed for reproducibility of initializers
keras.utils.set_random_seed(5)

# %%
class MyHyperModel(kt.HyperModel):
    def build(self, hp):
        
        feature_size= 57
        output_size= 8
        
        model = keras.Sequential()
        
        #Hyperparams definition
        hp_layers = hp.Int('hidden_layers', 1, 5, default = 2)
        hp_bn = hp.Boolean('batch_norm', default = False)
        hp_dropout = hp.Boolean('dropout', default = False)
        hp_do_rate= hp.Float('dropout_rate', min_value = 0.1, max_value = 0.5, default = 0.2)
        hp_learning_rate = hp.Float("learning_rate", min_value = 1e-4, max_value = 1e-1, sampling = "log")

        for i in range(1,1+hp_layers):  
            
             model.add(
                 keras.layers.Dense(                      
                     units=hp.Int('units_'+str(i), min_value = 2*output_size, max_value=2*feature_size, step=32),
                     kernel_initializer = 'he_normal',
                     use_bias=not hp_bn  
                 )
             )
                
             if hp_bn:   
                model.add(keras.layers.BatchNormalization())
                
             model.add(keras.layers.Activation('relu'))
               
             if hp_dropout and (i >= hp_layers-1):   
                model.add(
                   keras.layers.Dropout(rate=hp_do_rate)
                )
                
        model.add(keras.layers.Dense(8, activation='softmax'))        
        
        model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                      loss=keras.losses.SparseCategoricalCrossentropy(),
                      metrics=['accuracy', QuadraticWeightedKappa])  

        return model
    
    
    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size = hp.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024], default = 32),               
                **kwargs,
            )

# %%
#DELETE IF UNNECESARY
class MyHyperModel(kt.HyperModel):
    def build(self, hp):
        
        feature_size= 57
        output_size= 8
        
        model = keras.Sequential()
        
        # --- Hyperparams ---
        hp_layers        = hp.Int('hidden_layers', 1, 5, default = 2)
        hp_bn            = hp.Boolean('batch_norm', default = False)
        hp_dropout       = hp.Boolean('dropout', default = False)
        hp_do_rate       = hp.Float('dropout_rate', min_value = 0.1, max_value = 0.5, default = 0.2)
        hp_learning_rate = hp.Float("learning_rate", min_value = 1e-4, max_value = 1e-1, sampling = "log")

        for i in range(1,1+hp_layers):  
            
             model.add(
                 keras.layers.Dense(                      
                     units=hp.Int('units_'+str(i), min_value = 2*output_size,
                     max_value=2*feature_size, step=32), kernel_initializer = 'he_normal'                    
                 )
             )
                
             if hp_bn:   
                model.add(
                   keras.layers.BatchNormalization()
                )
                
             model.add(
                keras.layers.Activation('relu'),                     
             )
               
             if hp_dropout:   
                model.add(
                   keras.layers.Dropout(rate=hp_do_rate)
                )
                
        model.add(keras.layers.Dense(8, activation='softmax'))        
        
        model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                      loss=keras.losses.SparseCategoricalCrossentropy(),
                      metrics=['accuracy', QuadraticWeightedKappaMetric(num_classes=8)])  

        return model
    
    
    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size = hp.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024], default = 32),               
                **kwargs,
            )

# %% [markdown]
# #### MLP Tuning
# We will begin by tuning the hyperparameters that have consistently shown to be the most relevant in the literature: learning rate and batch size, with the fixed values for hidden layers and units per layer set to 2 and 16, respectively. We will not apply batch normalization or dropout at this stage.

# %%
# Tune only the learning rate and the mini-batch size hyperparameters

hp_mlp_1 = kt.HyperParameters()
hp_mlp_1.Float("learning_rate", min_value=1e-4, max_value=1e-1, sampling="log")
hp_mlp_1.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024])

tuner_mlp_1 = kt.Hyperband(
hypermodel = MyHyperModel(),
hyperparameters = hp_mlp_1,
tune_new_entries = False,
objective = 'val_accuracy',
directory = "Tuners/Tuner_MLP_1",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_1\Search_1\tuner0.json

# %%
tuner_mlp_1.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}

# %%
# tuner_mlp_1.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_mlp_1.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_1\Search_1
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0146 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0143
# Score: 0.5291343927383423
#
# Trial 0235 summary
# Hyperparameters:
# learning_rate: 0.0016978251488635758
# batch_size: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0230
# Score: 0.5267766714096069
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.004426737982217423
# batch_size: 64
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0142
# Score: 0.5257662534713745
#
# Trial 0209 summary
# Hyperparameters:
# learning_rate: 0.0020102516873925975
# batch_size: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0204
# Score: 0.5257662534713745
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.0027085523060129944
# batch_size: 32
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0229
# Score: 0.5255136489868164
#
# Trial 0208 summary
# Hyperparameters:
# learning_rate: 0.0032955659029470334
# batch_size: 32
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0203
# Score: 0.523997962474823
#
# Trial 0203 summary
# Hyperparameters:
# learning_rate: 0.0032955659029470334
# batch_size: 32
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0191
# Score: 0.5226507186889648
#
# Trial 0143 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0141
# Score: 0.5199562311172485
#
# Trial 0252 summary
# Hyperparameters:
# learning_rate: 0.020510566401299328
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# Score: 0.5194510221481323
#
# Trial 0245 summary
# Hyperparameters:
# learning_rate: 0.0044901561839415195
# batch_size: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# hidden_layers: 2
# batch_norm: False
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0239
# Score: 0.5191141963005066

# %%
# Get the optimal hyperparameters
hyps_mlp_1 = tuner_mlp_1.get_best_hyperparameters(num_trials=1)[0]
print(hyps_mlp_1.values)
# Out:
# {'learning_rate': 0.001526017960390335, 'batch_size': 16, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 4, 'tuner/round': 4, 'hidden_layers': 2, 'batch_norm': False, 'dropout': False, 'do_rate': 0.2, 'units_1': 16, 'units_2': 16, 'tuner/trial_id': '0143'}

# %% [markdown]
# Now that we have the optimal values of the learning rate and batch size, let's look for the optimal size of the network.

# %%
hp_mlp_2 = kt.HyperParameters()

# Fix

hp_mlp_2.Fixed("learning_rate", value = hyps_mlp_1["learning_rate"])
hp_mlp_2.Fixed("batch_size", value = hyps_mlp_1["batch_size"])
hp_mlp_2.Fixed("batch_norm", value = False)
hp_mlp_2.Fixed("dropout", value = False)
hp_mlp_2.Fixed("dropout_rate", value = 0.2)

tuner_mlp_2 = kt.Hyperband(
MyHyperModel(),
hyperparameters = hp_mlp_2,
tune_new_entries = True,
objective = 'val_accuracy',
directory = "Tuners/Tuner_MLP_2",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_2\Search_1\tuner0.json

# %%
tuner_mlp_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# learning_rate (Fixed)
# {'conditions': [], 'value': 0.001526017960390335}
# batch_size (Fixed)
# {'conditions': [], 'value': 16}
# batch_norm (Fixed)
# {'conditions': [], 'value': False}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# do_rate (Fixed)
# {'conditions': [], 'value': 0.2}
# hidden_layers (Int)
# {'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# tuner_mlp_2.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_mlp_2.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_2\Search_1
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0247 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 16
# units_2: 16
# units_3: 112
# units_4: 16
# units_5: 112
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0236
# Score: 0.525934636592865
#
# Trial 0252 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5246716141700745
#
# Trial 0196 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 112
# units_3: 112
# units_4: 48
# units_5: 48
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 0168
# Score: 0.5208824276924133
#
# Trial 0244 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 48
# units_3: 16
# units_4: 16
# units_5: 48
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5202088356018066
#
# Trial 0250 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 80
# units_2: 112
# units_3: 80
# units_4: 16
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5198720097541809
#
# Trial 0203 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 112
# units_3: 112
# units_4: 48
# units_5: 48
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0196
# Score: 0.5192825794219971
#
# Trial 0230 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 16
# units_2: 48
# units_3: 112
# units_4: 112
# units_5: 112
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0224
# Score: 0.5189457535743713
#
# Trial 0232 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 80
# units_2: 16
# units_3: 80
# units_4: 80
# units_5: 80
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0222
# Score: 0.5186931490898132
#
# Trial 0235 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 80
# units_2: 16
# units_3: 80
# units_4: 80
# units_5: 80
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0232
# Score: 0.5184405446052551
#
# Trial 0207 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 80
# units_2: 48
# units_3: 48
# units_4: 80
# units_5: 48
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0201
# Score: 0.5182721614837646

# %%
# Get the optimal hyperparameters
hyps_mlp_2 = tuner_mlp_2.get_best_hyperparameters(num_trials=1)[0]
model_mlp_2 = tuner_mlp_2.hypermodel.build(hyps_mlp_2)

print(hyps_mlp_2.values)
# Out:
# {'learning_rate': 0.001526017960390335, 'batch_size': 16, 'batch_norm': False, 'dropout': False, 'do_rate': 0.2, 'hidden_layers': 2, 'units_1': 16, 'units_2': 16, 'units_3': 112, 'units_4': 16, 'units_5': 112, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0236', 'dropout_rate': 0.2}

# %% [markdown]
# Now, we will train the model with the optimized hyperparameters.

# %%
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                            factor=0.5, patience=4, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#     monitor="loss", mode="min",
#     patience=10, min_delta=1e-4, restore_best_weights=True
# )
# # epochs= (100k steps)/(59k observations)*(16 obs per batch) 
# history_model_mlp_2 = model_mlp_2.fit(x=X_train_L1reg_np, y=y_train, 
#                                        epochs=27,
#                                        validation_data=(X_valid_L1reg_np, y_valid), 
#                                        callbacks = [sched, es_train],
#                                      )
#                                       
# 
# model_mlp_2.save("Models/model_mlp_2/model.keras")
# with open('Models/model_mlp_2/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_2.history, file_pi)

# %%
model_mlp_2 = keras.models.load_model("Models/model_mlp_2/model.keras", compile=False)

model_mlp_2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_2/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_2 = pickle.load(file_pi)

plt.plot(history_model_mlp_2['loss'])
plt.plot(history_model_mlp_2['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
plt.plot(history_model_mlp_2['QuadraticWeightedKappa'])
plt.plot(history_model_mlp_2['val_QuadraticWeightedKappa'])
plt.title('Model QuadraticWeightedKappa')
plt.ylabel('QWK')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_2 = QuadraticWeightedKappa(y_train, model_mlp_2.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_2)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 1s 798us/step - loss: 1.3216 - quadratic_weighted_kappa: 0.4133
# [Loss, Accuracy, Average QWK] : [1.3215572834014893, 0.41333329677581787]
# 1114/1114 [==============================] - 1s 616us/step
# Quadratic Weighted Kappa on training set: 0.48998433

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_2 = QuadraticWeightedKappa(y_valid, model_mlp_2.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 809us/step - loss: 1.3450 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.3449548482894897, 0.8421052694320679]
# 372/372 [==============================] - 0s 642us/step
# Quadratic Weighted Kappa on validation set: 0.49756378

# %% [markdown]
# We observe that there is a high bias and no variance for this model. We won't be trying a larger arquitecture this time since the hyperparameter space of the number of hidden layers was from 1 to 5, and the optimal value found was 2, so its unlikely that the model would favor from a larger arquitecture. We'll therefore opt for optimizing and evaluate the regular multilayer perceptron model adding batch normalization.
#
# #### MLP + Larger size

# %%
SEED = 5
tf.config.experimental.enable_op_determinism()

hp_mlp_3 = kt.HyperParameters()

# Fix
hp_mlp_3.Fixed("batch_norm", value = False)
hp_mlp_3.Fixed("dropout", value = False)
hp_mlp_3.Fixed("dropout_rate", value = 0.0)

hp_mlp_3.Choice("learning_rate", values =[3e-3, hyps_mlp_1["learning_rate"], 1e-3, 3e-4, 5e-4, 7.5e-4,])
hp_mlp_3.Choice("batch_size", values = [hyps_mlp_1["batch_size"],hyps_mlp_1["batch_size"]*2 ])

hp_mlp_3.Int('hidden_layers', min_value=6, max_value=12, step=2)

# build_model(...) = your existing HyperModel / function
tuner_mlp_3 = kt.Hyperband(
    MyHyperModel(),
    objective = kt.Objective("val_loss", direction="min"),
    max_epochs = 70,                 # 60–80 is a good band
    factor = 3,
    hyperband_iterations = 2,        # >1 brackets = better coverage
    hyperparameters = hp_mlp_3,
    tune_new_entries = True,
    seed = SEED,
    directory = "Tuners/Tuner_MLP_3",
    project_name = "Search_1", # new project name
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_3\Search_1\tuner0.json

# %%
tuner_mlp_3.search_space_summary()
# Out:
# Search space summary
# Default search space size: 18
# learning_rate (Choice)
# {'default': 0.003, 'conditions': [], 'values': [0.003, 0.001526017960390335, 0.001, 0.0003, 0.0005, 0.00075], 'ordered': True}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32], 'ordered': True}
# batch_norm (Fixed)
# {'conditions': [], 'value': False}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.0}
# hidden_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 6, 'max_value': 12, 'step': 2, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# os.makedirs("checkpoints", exist_ok=True)
# 
# # Callbacks
# early_stop = keras.callbacks.EarlyStopping(
#     monitor="val_loss",          # stop based on generalization, not train loss
#     mode="min",
#     patience=12,                 # lenient so deeper nets get time to learn
#     min_delta=1e-4,              # require a *meaningful* improvement
#     restore_best_weights=True    # roll back to best epoch within this trial
# )
# 
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor="val_loss",
#     mode="min",
#     factor=0.5,                  # halve LR on plateau
#     patience=5,                  # wait a few epochs before reducing
#     min_lr=5e-5                  # don't shrink LR to near-zero
# )
# 
# # Directory path => SavedModel format (no `.keras` extension)
# ckpt = keras.callbacks.ModelCheckpoint(
#     filepath=os.path.join("checkpoints", "best_mlp3"),
#     monitor="val_loss", mode="min",
#     save_best_only=True
# )

# # IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
# tuner_mlp_3.search(
# X_train_L1reg_np, y_train,
# validation_data=(X_valid_L1reg_np, y_valid),
# epochs=70,                   # matches max_epochs in the tuner
# callbacks=[early_stop, reduce_lr, ckpt],
# verbose=1
# )

# %%
tuner_mlp_3.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_3\Search_1
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0162 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# units_7: 16
# units_8: 80
# units_9: 16
# units_10: 80
# units_11: 80
# units_12: 16
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0160
# Score: 1.3218721151351929
#
# Trial 0160 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# units_7: 16
# units_8: 80
# units_9: 16
# units_10: 80
# units_11: 80
# units_12: 16
# tuner/epochs: 24
# tuner/initial_epoch: 8
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0142
# Score: 1.327062726020813
#
# Trial 0177 summary
# Hyperparameters:
# learning_rate: 0.001
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 16
# units_2: 48
# units_3: 80
# units_4: 16
# units_5: 112
# units_6: 16
# units_7: 16
# units_8: 112
# units_9: 16
# units_10: 80
# units_11: 16
# units_12: 112
# tuner/epochs: 70
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3291114568710327
#
# Trial 0137 summary
# Hyperparameters:
# learning_rate: 0.00075
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 16
# units_5: 16
# units_6: 48
# units_7: 16
# units_8: 80
# units_9: 16
# units_10: 16
# units_11: 112
# units_12: 80
# tuner/epochs: 24
# tuner/initial_epoch: 8
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0128
# Score: 1.3316928148269653
#
# Trial 0172 summary
# Hyperparameters:
# learning_rate: 0.003
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 112
# units_3: 48
# units_4: 16
# units_5: 80
# units_6: 16
# units_7: 16
# units_8: 16
# units_9: 112
# units_10: 112
# units_11: 80
# units_12: 48
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0169
# Score: 1.3317703008651733
#
# Trial 0140 summary
# Hyperparameters:
# learning_rate: 0.00075
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 16
# units_5: 16
# units_6: 48
# units_7: 16
# units_8: 80
# units_9: 16
# units_10: 16
# units_11: 112
# units_12: 80
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0137
# Score: 1.3334726095199585
#
# Trial 0136 summary
# Hyperparameters:
# learning_rate: 0.001526017960390335
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 80
# units_2: 48
# units_3: 16
# units_4: 48
# units_5: 48
# units_6: 48
# units_7: 112
# units_8: 48
# units_9: 80
# units_10: 16
# units_11: 80
# units_12: 80
# tuner/epochs: 24
# tuner/initial_epoch: 8
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0126
# Score: 1.3338807821273804
#
# Trial 0169 summary
# Hyperparameters:
# learning_rate: 0.003
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 112
# units_3: 48
# units_4: 16
# units_5: 80
# units_6: 16
# units_7: 16
# units_8: 16
# units_9: 112
# units_10: 112
# units_11: 80
# units_12: 48
# tuner/epochs: 24
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 1.3344868421554565
#
# Trial 0173 summary
# Hyperparameters:
# learning_rate: 0.00075
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 80
# units_6: 48
# units_7: 16
# units_8: 48
# units_9: 80
# units_10: 16
# units_11: 80
# units_12: 80
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0171
# Score: 1.3354538679122925
#
# Trial 0087 summary
# Hyperparameters:
# learning_rate: 0.003
# batch_size: 16
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 112
# units_2: 112
# units_3: 16
# units_4: 48
# units_5: 112
# units_6: 48
# units_7: 16
# units_8: 112
# units_9: 48
# units_10: 112
# units_11: 48
# units_12: 48
# tuner/epochs: 70
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3358159065246582

# %%
# Get the optimal hyperparameters
hyps_mlp_3 = tuner_mlp_3.get_best_hyperparameters(num_trials=1)[0]
model_mlp_3 = tuner_mlp_3.hypermodel.build(hyps_mlp_3)

print(hyps_mlp_3.values)
# Out:
# {'learning_rate': 0.001526017960390335, 'batch_size': 16, 'batch_norm': False, 'dropout': False, 'dropout_rate': 0.0, 'hidden_layers': 6, 'units_1': 48, 'units_2': 16, 'units_3': 16, 'units_4': 16, 'units_5': 112, 'units_6': 16, 'units_7': 16, 'units_8': 80, 'units_9': 16, 'units_10': 80, 'units_11': 80, 'units_12': 16, 'tuner/epochs': 70, 'tuner/initial_epoch': 24, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0160'}

# %%
hp_mlp_4 = kt.HyperParameters()

# --- Stage A2: LR & BS retune on the best deeper architecture ---
hp_mlp_4.Fixed('batch_norm', False)
hp_mlp_4.Fixed('dropout', False)
hp_mlp_4.Fixed('dropout_rate', 0.0)

# freeze architecture from Stage A1
hp_mlp_4.Fixed('hidden_layers', hyps_mlp_3['hidden_layers'])
for i in range(hyps_mlp_3['hidden_layers']): hp_mlp_4.Fixed(f'units_{i+1}', hyps_mlp_3[f'units_{i+1}'])
    
# initialize tuner
tuner_mlp_4 = kt.Hyperband(
    MyHyperModel(),
    objective = kt.Objective("val_loss", direction="min"),
    max_epochs = 50,                 
    factor = 3,
    hyperband_iterations = 2,        
    hyperparameters = hp_mlp_4,
    tune_new_entries = True,
    seed = SEED,
    directory = "Tuners/Tuner_MLP_4",
    project_name = "Search_1", # new project name
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_4\Search_1\tuner0.json

# %%
# os.makedirs("checkpoints_a2", exist_ok=True)
# 
# # Callbacks
# early_stop = keras.callbacks.EarlyStopping(
#     monitor="val_loss",          # stop based on generalization, not train loss
#     mode="min",
#     patience=8,                 # lenient so deeper nets get time to learn
#     min_delta=1e-4,              # require a *meaningful* improvement
#     restore_best_weights=True    # roll back to best epoch within this trial
# )
# 
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor="val_loss",
#     mode="min",
#     factor=0.5,                  # halve LR on plateau
#     patience=4,                  # wait a few epochs before reducing
#     min_lr=1e-5                  # don't shrink LR to near-zero
# )
# 
# # Directory path => SavedModel format (no `.keras` extension)
# ckpt = keras.callbacks.ModelCheckpoint(
#     filepath=os.path.join("checkpoints_a2", "best_mlp4"),
#     monitor="val_loss", mode="min",
#     save_best_only=True
# )
# 
# 
# # IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
# tuner_mlp_4.search(
#     X_train_L1reg_np, y_train,
#     validation_data=(X_valid_L1reg_np, y_valid),
#     epochs=50,                   # matches max_epochs in the tuner
#     callbacks=[early_stop, reduce_lr, ckpt],
#     verbose=1
# )

# %%
tuner_mlp_4.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_4\Search_1
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0073 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0067
# Score: 1.3193037509918213
#
# Trial 0089 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0018679925114442324
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3204984664916992
#
# Trial 0162 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.006069775986785774
# batch_size: 128
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0157
# Score: 1.3220833539962769
#
# Trial 0050 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0031089211420179527
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0046
# Score: 1.3224303722381592
#
# Trial 0082 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0016506110681584517
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0080
# Score: 1.3237905502319336
#
# Trial 0140 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0009859078787732482
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0136
# Score: 1.3281757831573486
#
# Trial 0046 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0031089211420179527
# batch_size: 32
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0035
# Score: 1.3324698209762573
#
# Trial 0072 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0014383567347209258
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0068
# Score: 1.3326863050460815
#
# Trial 0051 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0013317149227157756
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0047
# Score: 1.3336302042007446
#
# Trial 0163 summary
# Hyperparameters:
# batch_norm: False
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.009937666604570213
# batch_size: 512
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0158
# Score: 1.3350729942321777

# %%
# Get the optimal hyperparameters
hyps_mlp_4 = tuner_mlp_4.get_best_hyperparameters(num_trials=1)[0]
model_mlp_4 = tuner_mlp_4.hypermodel.build(hyps_mlp_4)

print(hyps_mlp_4.values)
# Out:
# {'batch_norm': False, 'dropout': False, 'dropout_rate': 0.0, 'hidden_layers': 6, 'units_1': 48, 'units_2': 16, 'units_3': 16, 'units_4': 16, 'units_5': 112, 'units_6': 16, 'learning_rate': 0.0036584656672746215, 'batch_size': 128, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0067'}

# %%
# # monitor='loss', patience=20, epochs=240
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                           factor=0.5, patience=4, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#     monitor="loss", mode="min",
#     patience=12, min_delta=1e-4, restore_best_weights=True
# )
# # epochs= (100k steps)/(59k observations)*(128 obs per batch) 
# 
# history_model_mlp_4 = model_mlp_4.fit(x=X_train_L1reg_np, y=y_train, 
#                                       epochs=217,
#                                       validation_data=(X_valid_L1reg_np, y_valid), 
#                                       callbacks = [sched, es_train],
#                                      )

# %%
# os.makedirs("Models/model_mlp_4", exist_ok=True)
# 
# model_mlp_4.save("Models/model_mlp_4/model.keras")
# with open('Models/model_mlp_4/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_4.history, file_pi)

# %%
model_mlp_4 = keras.models.load_model("Models/model_mlp_4/model.keras", compile=False)                                                       
model_mlp_4.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_4/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_4 = pickle.load(file_pi)

plt.plot(history_model_mlp_4['loss'])
plt.plot(history_model_mlp_4['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_4.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_4 = QuadraticWeightedKappa(y_train, model_mlp_4.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_4)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 1s 947us/step - loss: 1.0983 - quadratic_weighted_kappa: 0.8750
# [Loss, Accuracy, Average QWK] : [1.098266363143921, 0.875]
# 1114/1114 [==============================] - 1s 740us/step
# Quadratic Weighted Kappa on training set: 0.5919856

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_4.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_4 = QuadraticWeightedKappa(y_valid, model_mlp_4.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_4)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 929us/step - loss: 1.6401 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.640073537826538, 0.8421052694320679]
# 372/372 [==============================] - 0s 744us/step
# Quadratic Weighted Kappa on validation set: 0.47183216

# %% [markdown]
# We observe that there is a high bias and no variance for this model. We won't be trying a larger arquitecture this time since the hyperparameter space of the number of hidden layers was from 1 to 5, and the optimal value found was 2, so its unlikely that the model would favor from a larger arquitecture. We'll therefore opt for optimizing and evaluate the regular multilayer perceptron model adding batch normalization.

# %%
baseline = 0.67938
model_mlp_4_bias = baseline-qwk_train_model_mlp_4
model_mlp_4_var = qwk_train_model_mlp_4-qwk_valid_model_mlp_4
print("Bias / Variance of the model: ")
print(round(model_mlp_4_bias,3),"/",round(model_mlp_4_var,3))
# Out:
# Bias / Variance of the model:
# 0.087 / 0.12

# %% [markdown]
# We observe that there is a high bias and no variance for this model. We won't be trying a larger arquitecture this time since the hyperparameter space of the number of hidden layers was from 1 to 5, and the optimal value found was 2, so its unlikely that the model would favor from a larger arquitecture. We'll therefore opt for optimizing and evaluate the regular multilayer perceptron model adding batch normalization.

# %% [markdown]
# # MLP with Dropout

# %% [markdown]
# We observe that the multilayer perceptron with batch normalization and larger architecture has the lowest bias of all the versions we've tried so far. Also, it decreased variance slightly with respect to its counterpart without batch normalization. Thus, wi will focus now on reducing variance by applying dropout on the last two layers.

# %%
hp_do = kt.HyperParameters()
hp_do.Fixed('batch_norm', False)
hp_do.Fixed('dropout', True)                 # using dropout
hp_do.Choice('dropout_rate', [0.05, 0.10, 0.15, 0.20, 0.25, 0.30])  # light→moderate

# ---- fix architecture from the BN stage ----
hp_do.Fixed('hidden_layers', hyps_mlp_4['hidden_layers'])
for i in range(hyps_mlp_4['hidden_layers']):
    hp_do.Fixed(f'units_{i+1}', hyps_mlp_4[f'units_{i+1}'])

# ---- small LR/BS grids around your BN best (~0.0189) ----
hp_do.Choice('learning_rate',  values=[0.013, hyps_mlp_4['learning_rate'], 0.028])
hp_do.Choice('batch_size',    [64, 128, 256])   # hyps_mlp_4['batch_size']=128

tuner_mlp_do = kt.Hyperband(
    MyHyperModel(),                                  # your BN+Dropout-aware HyperModel
    objective=kt.Objective("val_loss", direction="min"),
    max_epochs=50,
    factor=3,
    hyperband_iterations=2,
    hyperparameters=hp_do,                        # only these will be tuned
    tune_new_entries=False,
    seed=SEED,
    directory="Tuners/Tuner_MLP_DO",
    project_name="Dropout_Search"
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_DO\Dropout_Search\tuner0.json

# %%
# os.makedirs("Tuners/Tuner_MLP_DO/checkpoints", exist_ok=True)
# 
# # Callbacks
# early_stop = keras.callbacks.EarlyStopping(
#     monitor="val_loss",          # stop based on generalization, not train loss
#     mode="min",
#     patience=10,                 
#     min_delta=1e-4,             
#     restore_best_weights=True    # roll back to best epoch within this trial
# )
# 
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor="val_loss",
#     mode="min",
#     factor=0.5,                  
#     patience=4,                  # wait a few epochs before reducing
#     min_lr=1e-6                  # don't shrink LR to near-zero
# )
# 
# # Directory path => SavedModel format (no `.keras` extension)
# ckpt = keras.callbacks.ModelCheckpoint(
#     filepath=os.path.join("Tuners/Tuner_MLP_DO/checkpoints", "best_mlp_do"),
#     monitor="val_loss", mode="min",
#     save_best_only=True
# )
# 
# 
# # IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
# tuner_mlp_do.search(
#     X_train_L1reg_np, y_train,
#     validation_data=(X_valid_L1reg_np, y_valid),
#     epochs=50,                   # matches max_epochs in the tuner
#     callbacks=[early_stop, reduce_lr, ckpt],
#     verbose=1
# )

# %%
tuner_mlp_do.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_DO\Dropout_Search
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0072 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.1
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0067
# Score: 1.327274203300476
#
# Trial 0050 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.05
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 256
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0047
# Score: 1.328022837638855
#
# Trial 0051 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.15
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0048
# Score: 1.3416188955307007
#
# Trial 0073 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.25
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0069
# Score: 1.355264663696289
#
# Trial 0047 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.05
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 256
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0040
# Score: 1.355478286743164
#
# Trial 0048 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.15
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0038
# Score: 1.3573201894760132
#
# Trial 0067 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.1
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0056
# Score: 1.3592208623886108
#
# Trial 0046 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.05
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 64
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0034
# Score: 1.359810471534729
#
# Trial 0049 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.05
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0035
# Score: 1.3630688190460205
#
# Trial 0069 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.25
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0065
# Score: 1.366243839263916

# %%
# Get the optimal hyperparameters
hyps_mlp_do = tuner_mlp_do.get_best_hyperparameters(num_trials=1)[0]
model_mlp_do = tuner_mlp_do.hypermodel.build(hyps_mlp_do)

print(hyps_mlp_do.values)
# Out:
# {'batch_norm': False, 'dropout': True, 'dropout_rate': 0.1, 'hidden_layers': 6, 'units_1': 48, 'units_2': 16, 'units_3': 16, 'units_4': 16, 'units_5': 112, 'units_6': 16, 'learning_rate': 0.0036584656672746215, 'batch_size': 128, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0067'}

# %%
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                           factor=0.5, patience=6, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#     monitor="loss", mode="min",
#     patience=20, min_delta=5e-5, restore_best_weights=True
# )
# # epochs 325= (150k steps) / (59k observations) * (128 obs per batch)
# history_model_mlp_do = model_mlp_do.fit(x=X_train_L1reg_np, y=y_train, 
#                                       epochs=325,
#                                       validation_data=(X_valid_L1reg_np, y_valid), 
#                                       callbacks = [sched, es_train],
#                                      )
# Out:
# Epoch 1/325
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.5955 - accuracy: 0.4171 - QuadraticWeightedKappa: 0.3737 - val_loss: 1.4841 - val_accuracy: 0.4498 - val_QuadraticWeightedKappa: 0.4570 - lr: 0.0037
# Epoch 2/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4751 - accuracy: 0.4622 - QuadraticWeightedKappa: 0.4259 - val_loss: 1.4854 - val_accuracy: 0.4517 - val_QuadraticWeightedKappa: 0.4820 - lr: 0.0037
# Epoch 3/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4479 - accuracy: 0.4713 - QuadraticWeightedKappa: 0.4302 - val_loss: 1.4356 - val_accuracy: 0.4867 - val_QuadraticWeightedKappa: 0.4399 - lr: 0.0037
# Epoch 4/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4359 - accuracy: 0.4787 - QuadraticWeightedKappa: 0.4333 - val_loss: 1.4123 - val_accuracy: 0.4816 - val_QuadraticWeightedKappa: 0.4391 - lr: 0.0037
# Epoch 5/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4244 - accuracy: 0.4812 - QuadraticWeightedKappa: 0.4379 - val_loss: 1.3972 - val_accuracy: 0.4931 - val_QuadraticWeightedKappa: 0.4582 - lr: 0.0037
# Epoch 6/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4160 - accuracy: 0.4836 - QuadraticWeightedKappa: 0.4368 - val_loss: 1.4342 - val_accuracy: 0.4733 - val_QuadraticWeightedKappa: 0.4170 - lr: 0.0037
# Epoch 7/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.4133 - accuracy: 0.4871 - QuadraticWeightedKappa: 0.4391 - val_loss: 1.4020 - val_accuracy: 0.4853 - val_QuadraticWeightedKappa: 0.4976 - lr: 0.0037
# Epoch 8/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1
325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2310 - accuracy: 0.5527 - QuadraticWeightedKappa: 0.5074 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4869 - lr: 1.0000e-06
# Epoch 318/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2305 - accuracy: 0.5531 - QuadraticWeightedKappa: 0.5083 - val_loss: 1.4014 - val_accuracy: 0.5199 - val_QuadraticWeightedKappa: 0.4870 - lr: 1.0000e-06
# Epoch 319/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2331 - accuracy: 0.5532 - QuadraticWeightedKappa: 0.5107 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4870 - lr: 1.0000e-06
# Epoch 320/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2299 - accuracy: 0.5544 - QuadraticWeightedKappa: 0.5069 - val_loss: 1.4014 - val_accuracy: 0.5197 - val_QuadraticWeightedKappa: 0.4869 - lr: 1.0000e-06
# Epoch 321/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2294 - accuracy: 0.5553 - QuadraticWeightedKappa: 0.5126 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4869 - lr: 1.0000e-06
# Epoch 322/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2324 - accuracy: 0.5545 - QuadraticWeightedKappa: 0.5076 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4865 - lr: 1.0000e-06
# Epoch 323/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2304 - accuracy: 0.5555 - QuadraticWeightedKappa: 0.5099 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4867 - lr: 1.0000e-06
# Epoch 324/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2295 - accuracy: 0.5548 - QuadraticWeightedKappa: 0.5071 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4868 - lr: 1.0000e-06
# Epoch 325/325
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2310 - accuracy: 0.5545 - QuadraticWeightedKappa: 0.5061 - val_loss: 1.4014 - val_accuracy: 0.5198 - val_QuadraticWeightedKappa: 0.4866 - lr: 1.0000e-06

# %%
# os.makedirs("Models/model_mlp_do", exist_ok=True)
# 
# model_mlp_do.save("Models/model_mlp_do/model.keras")
# with open('Models/model_mlp_do/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_do.history, file_pi)

# %%
model_mlp_do = keras.models.load_model("Models/model_mlp_do/model.keras", compile=False)                                                       
model_mlp_do.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_do/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_do = pickle.load(file_pi)

plt.plot(history_model_mlp_do['loss'])
plt.plot(history_model_mlp_do['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_do.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_do = QuadraticWeightedKappa(y_train, model_mlp_do.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_do)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 1s 942us/step - loss: 1.2074 - quadratic_weighted_kappa: 0.4286
# [Loss, Accuracy, Average QWK] : [1.2073564529418945, 0.4285714030265808]
# 1114/1114 [==============================] - 1s 711us/step
# Quadratic Weighted Kappa on training set: 0.5249559

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_do.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_do = QuadraticWeightedKappa(y_valid, model_mlp_do.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_do)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 1.4014 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.4014102220535278, 0.8421052694320679]
# 372/372 [==============================] - 0s 774us/step
# Quadratic Weighted Kappa on validation set: 0.49417847

# %%
baseline = 0.67938
model_mlp_do_bias = baseline-qwk_train_model_mlp_do
model_mlp_do_var = qwk_train_model_mlp_do-qwk_valid_model_mlp_do
print("Bias / Variance of the model: ")
print(round(model_mlp_do_bias,3),"/",round(model_mlp_do_var,3))
# Out:
# Bias / Variance of the model:
# 0.154 / 0.031

# %%
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                           factor=0.5, patience=6, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#     monitor="loss", mode="min",
#     patience=20, min_delta=5e-5, restore_best_weights=True
# )
# # epochs 163= (75k steps) / (59k observations) * (128 obs per batch)
# history_model_mlp_do = model_mlp_do.fit(x=X_train_L1reg_np, y=y_train, 
#                                       epochs=163,
#                                       validation_data=(X_valid_L1reg_np, y_valid), 
#                                       callbacks = [sched, es_train],
#                                      )
# Out:
# Epoch 1/163
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2599 - quadratic_weighted_kappa: -0.0132 - val_loss: 1.3886 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 2/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2620 - quadratic_weighted_kappa: 0.3417 - val_loss: 1.3974 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 3/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2584 - quadratic_weighted_kappa: -0.1495 - val_loss: 1.3943 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 4/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2587 - quadratic_weighted_kappa: 0.9200 - val_loss: 1.3918 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 5/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2609 - quadratic_weighted_kappa: 0.5675 - val_loss: 1.3846 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 6/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2612 - quadratic_weighted_kappa: 0.6897 - val_loss: 1.3782 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 7/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2615 - quadratic_weighted_kappa: 0.1667 - val_loss: 1.3754 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 8/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2593 - quadratic_weighted_kappa: 0.3030 - val_loss: 1.3974 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 9/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2604 - quadratic_weighted_kappa: 0.8232 - val_loss: 1.3982 - val_quadratic_weighted_kappa: 0.8421 - lr: 0.0010
# Epoch 10/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2508 - quadratic_weighted_kappa: 0.7663 - val_loss: 1.4015 - val_quadratic_weighted_kappa: 0.8421 - lr: 5.0000e-04
# Epoch 11/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2492 - quadratic_weighted_kappa: 0.5310 - val_loss: 1.3981 - val_quadratic_weighted_kappa: 0.8421 - lr: 5.0000e-04
# Epoch 12/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.
163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2230 - quadratic_weighted_kappa: 0.7754 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 138/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2211 - quadratic_weighted_kappa: 0.7152 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 139/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2232 - quadratic_weighted_kappa: 0.2264 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 140/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2210 - quadratic_weighted_kappa: -0.1127 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 141/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2217 - quadratic_weighted_kappa: 0.0903 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 142/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2209 - quadratic_weighted_kappa: 0.4491 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 143/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2211 - quadratic_weighted_kappa: 0.1857 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 144/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2221 - quadratic_weighted_kappa: 0.6579 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 145/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2216 - quadratic_weighted_kappa: 0.4235 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 146/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2206 - quadratic_weighted_kappa: 0.4934 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 147/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2188 - quadratic_weighted_kappa: 0.6729 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 148/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2207 - quadratic_weighted_kappa: 0.5056 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 149/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2230 - quadratic_weighted_kappa: 0.7456 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 150/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2213 - quadratic_weighted_kappa: 0.6633 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 151/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2202 - quadratic_weighted_kappa: 0.5303 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 152/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2232 - quadratic_weighted_kappa: 0.6846 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 153/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2212 - quadratic_weighted_kappa: 0.4289 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 154/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2233 - quadratic_weighted_kappa: 0.1364 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 155/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2208 - quadratic_weighted_kappa: 0.9082 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 156/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2223 - quadratic_weighted_kappa: 0.7237 - val_loss: 1.4395 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 157/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2219 - quadratic_weighted_kappa: 0.7511 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 158/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2211 - quadratic_weighted_kappa: 0.4721 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 159/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2223 - quadratic_weighted_kappa: 0.2871 - val_loss: 1.4397 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 160/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2221 - quadratic_weighted_kappa: 0.1840 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 161/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2232 - quadratic_weighted_kappa: 0.2678 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 162/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2207 - quadratic_weighted_kappa: 0.4275 - val_loss: 1.4396 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06
# Epoch 163/163
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.2232 - quadratic_weighted_kappa: 0.5302 - val_loss: 1.4397 - val_quadratic_weighted_kappa: 0.8421 - lr: 1.0000e-06

# %%
# os.makedirs("Models/model_mlp_do", exist_ok=True)
# 
# model_mlp_do.save("Models/model_mlp_do/model_2.keras")
# with open('Models/model_mlp_do/trainHistoryDict_2', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_do.history, file_pi)

# %%
model_mlp_do = keras.models.load_model("Models/model_mlp_do/model_2.keras", compile=False)                                                       
model_mlp_do.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_do/trainHistoryDict_2', "rb") as file_pi:
    history_model_mlp_do = pickle.load(file_pi)

plt.plot(range(326,489),history_model_mlp_do['loss'])
plt.plot(range(326,489),history_model_mlp_do['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_do.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_do = QuadraticWeightedKappa(y_train, model_mlp_do.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_do)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 1s 924us/step - loss: 1.1981 - quadratic_weighted_kappa: 0.2526
# [Loss, Accuracy, Average QWK] : [1.1981433629989624, 0.25263160467147827]
# 1114/1114 [==============================] - 1s 757us/step
# Quadratic Weighted Kappa on training set: 0.52832556

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_do.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_do = QuadraticWeightedKappa(y_valid, model_mlp_do.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_do)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 984us/step - loss: 1.4397 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.4396506547927856, 0.8421052694320679]
# 372/372 [==============================] - 0s 769us/step
# Quadratic Weighted Kappa on validation set: 0.49445784

# %%
baseline = 0.67938
model_mlp_do_bias = baseline-qwk_train_model_mlp_do
model_mlp_do_var = qwk_train_model_mlp_do-qwk_valid_model_mlp_do
print("Bias / Variance of the model: ")
print(round(model_mlp_do_bias,3),"/",round(model_mlp_do_var,3))
# Out:
# Bias / Variance of the model:
# 0.151 / 0.034

# %%
hp_do_2 = kt.HyperParameters()
hp_do_2.Fixed('batch_norm', False)
hp_do_2.Fixed('dropout', True)                 # using dropout
hp_do_2.Choice('dropout_rate',  [0.00, 0.02, 0.05, 0.08, 0.10])  # light→moderate

# ---- fix architecture from the BN stage ----
hp_do_2.Fixed('hidden_layers', hyps_mlp_4['hidden_layers'])
for i in range(hyps_mlp_4['hidden_layers']):
    hp_do_2.Fixed(f'units_{i+1}', hyps_mlp_4[f'units_{i+1}'])

# ---- small LR/BS grids around your BN best (~0.0189) ----
hp_do_2.Choice('learning_rate',  values=[0.007,0.013, hyps_mlp_4['learning_rate'], 0.028])
hp_do_2.Choice('batch_size',    [64, 128, 256])   # hyps_mlp_4['batch_size']=128

tuner_mlp_do_2 = kt.Hyperband(
    MyHyperModel(),                                  # your BN+Dropout-aware HyperModel
    objective=kt.Objective("val_loss", direction="min"),
    max_epochs=75,
    factor=3,
    hyperband_iterations=2,
    hyperparameters=hp_do_2,                        # only these will be tuned
    tune_new_entries=False,
    seed=SEED,
    directory="Tuners/Tuner_MLP_DO",
    project_name="Dropout_Search_2"
)

# %%
os.makedirs("Tuners/Tuner_MLP_DO/checkpoints", exist_ok=True)

# Callbacks
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",          # stop based on generalization, not train loss
    mode="min",
    patience=10,                 
    min_delta=1e-4,             
    restore_best_weights=True    # roll back to best epoch within this trial
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    mode="min",
    factor=0.5,                  
    patience=4,                  # wait a few epochs before reducing
    min_lr=1e-6                  # don't shrink LR to near-zero
)

# Directory path => SavedModel format (no `.keras` extension)
ckpt = keras.callbacks.ModelCheckpoint(
    filepath=os.path.join("Tuners/Tuner_MLP_DO/checkpoints", "best_mlp_do_2"),
    monitor="val_loss", mode="min",
    save_best_only=True
)


# IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
tuner_mlp_do_2.search(
    X_train_L1reg_np, y_train,
    validation_data=(X_valid_L1reg_np, y_valid),
    epochs=75,                   # matches max_epochs in the tuner
    callbacks=[early_stop, reduce_lr, ckpt],
    verbose=1
)
# Out:
# Trial 88 Complete [00h 00m 40s]
# val_loss: 1.3329395055770874
#
# Best val_loss So Far: 1.3257004022598267
# Total elapsed time: 00h 20m 15s

# %%
tuner_mlp_do_2.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_DO\Dropout_Search_2
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0050 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 75
# tuner/initial_epoch: 25
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0048
# Score: 1.3257004022598267
#
# Trial 0082 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.1
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 64
# tuner/epochs: 75
# tuner/initial_epoch: 25
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0077
# Score: 1.328095555305481
#
# Trial 0072 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.08
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 75
# tuner/initial_epoch: 25
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0067
# Score: 1.3310879468917847
#
# Trial 0085 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.08
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.007
# batch_size: 128
# tuner/epochs: 75
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.331368088722229
#
# Trial 0087 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.02
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 256
# tuner/epochs: 75
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3329395055770874
#
# Trial 0048 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.0
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 25
# tuner/initial_epoch: 9
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0037
# Score: 1.3334753513336182
#
# Trial 0051 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.02
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 75
# tuner/initial_epoch: 25
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0047
# Score: 1.3340795040130615
#
# Trial 0077 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.1
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 64
# tuner/epochs: 25
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 1.3373124599456787
#
# Trial 0067 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.08
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 25
# tuner/initial_epoch: 9
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0063
# Score: 1.3386563062667847
#
# Trial 0047 summary
# Hyperparameters:
# batch_norm: False
# dropout: True
# dropout_rate: 0.02
# hidden_layers: 6
# units_1: 48
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 112
# units_6: 16
# learning_rate: 0.0036584656672746215
# batch_size: 128
# tuner/epochs: 25
# tuner/initial_epoch: 9
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0034
# Score: 1.3390417098999023

# %%
# Get the optimal hyperparameters
hyps_mlp_do_2 = tuner_mlp_do_2.get_best_hyperparameters(num_trials=1)[0]
model_mlp_do_2 = tuner_mlp_do_2.hypermodel.build(hyps_mlp_do_2)

print(hyps_mlp_do_2.values)
# Out:
# {'batch_norm': False, 'dropout': True, 'dropout_rate': 0.0, 'hidden_layers': 6, 'units_1': 48, 'units_2': 16, 'units_3': 16, 'units_4': 16, 'units_5': 112, 'units_6': 16, 'learning_rate': 0.0036584656672746215, 'batch_size': 128, 'tuner/epochs': 75, 'tuner/initial_epoch': 25, 'tuner/bracket': 3, 'tuner/round': 3, 'tuner/trial_id': '0048'}

# %%
sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
                                          factor=0.5, patience=6, min_lr=1e-6)
es_train = keras.callbacks.EarlyStopping(
    monitor="loss", mode="min",
    patience=20, min_delta=5e-5, restore_best_weights=True
)
# epochs 434= (200k steps) / (59k observations) * (128 obs per batch)
history_model_mlp_do_2 = model_mlp_do_2.fit(x=X_train_L1reg_np, y=y_train, 
                                      epochs=434,
                                      validation_data=(X_valid_L1reg_np, y_valid), 
                                      callbacks = [sched, es_train],
                                     )
# Out:
# Epoch 1/434
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.5610 - accuracy: 0.4180 - QuadraticWeightedKappa: 0.3672 - val_loss: 1.4782 - val_accuracy: 0.4571 - val_QuadraticWeightedKappa: 0.4306 - lr: 0.0037
# Epoch 2/434
# 1114/1114 [==============================] - 2s 1ms/step - loss: 1.4608 - accuracy: 0.4632 - QuadraticWeightedKappa: 0.4211 - val_loss: 1.4877 - val_accuracy: 0.4559 - val_QuadraticWeightedKappa: 0.4741 - lr: 0.0037
# Epoch 3/434
# 1114/1114 [==============================] - 2s 1ms/step - loss: 1.4397 - accuracy: 0.4720 - QuadraticWeightedKappa: 0.4307 - val_loss: 1.4344 - val_accuracy: 0.4741 - val_QuadraticWeightedKappa: 0.4280 - lr: 0.0037
# Epoch 4/434
#  483/1114 [============>.................] - ETA: 0s - loss: 1.4156 - accuracy: 0.4826 - QuadraticWeightedKappa: 0.4288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 8
#       3 es_train = keras.callbacks.EarlyStopping(
#       4     monitor="loss", mode="min",
#       5     patience=20, min_delta=5e-5, restore_best_weights=True
#       6 )
#       7 # epochs 434= (200k steps) / (59k observations) * (128 obs per batch)
# ----> 8 history_model_mlp_do_2 = model_mlp_do_2.fit(x=X_train_L1reg_np, y=y_train,
#       9                                       epochs=434,
#      10                                       validation_data=(X_valid_L1reg_np, y_valid),
#      11                                       callbacks = [sched, es_train],
#      12                                      )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
os.makedirs("Models/model_mlp_do_2", exist_ok=True)

model_mlp_do_2.save("Models/model_mlp_do_2/model.keras")
with open('Models/model_mlp_do_2/trainHistoryDict', 'wb') as file_pi:
    pickle.dump(history_model_mlp_do_2.history, file_pi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 5
#       3 model_mlp_do_2.save("Models/model_mlp_do_2/model.keras")
#       4 with open('Models/model_mlp_do_2/trainHistoryDict', 'wb') as file_pi:
# ----> 5     pickle.dump(history_model_mlp_do_2.history, file_pi)
#
# AttributeError: 'dict' object has no attribute 'history'

# %%
model_mlp_do_2 = keras.models.load_model("Models/model_mlp_do_2/model.keras", compile=False)                                                       
model_mlp_do_2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_do_2/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_do_2 = pickle.load(file_pi)

plt.plot(history_model_mlp_do_2['loss'])
plt.plot(history_model_mlp_do_2['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_do_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_do_2 = QuadraticWeightedKappa(y_train, model_mlp_do_2.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_do_2)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 1s 946us/step - loss: 1.1981 - quadratic_weighted_kappa: 0.2526
# [Loss, Accuracy, Average QWK] : [1.1981433629989624, 0.25263160467147827]
# 1114/1114 [==============================] - 1s 740us/step
# Quadratic Weighted Kappa on training set: 0.52832556

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_do_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_do_2 = QuadraticWeightedKappa(y_valid, model_mlp_do_2.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_do_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 992us/step - loss: 1.4397 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.4396506547927856, 0.8421052694320679]
# 372/372 [==============================] - 0s 810us/step
# Quadratic Weighted Kappa on validation set: 0.49445784

# %%
baseline = 0.67938
model_mlp_do_bias = baseline-qwk_train_model_mlp_do
model_mlp_do_var = qwk_train_model_mlp_do-qwk_valid_model_mlp_do
print("Bias / Variance of the model: ")
print(round(model_mlp_do_bias,3),"/",round(model_mlp_do_var,3))
# Out:
# Bias / Variance of the model:
# 0.151 / 0.034

# %% [markdown]
# #### MLP + Batch Normalization Tuning

# %%
# Tune only the learning rate and the mini-batch size hyperparameters

hp_mlp_1_bn = kt.HyperParameters()
hp_mlp_1_bn.Float("learning_rate", min_value=1e-4, max_value=1e-1, sampling="log")
hp_mlp_1_bn.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024])
hp_mlp_1_bn.Fixed("batch_norm", value = True)

tuner_mlp_1_bn = kt.Hyperband(
hypermodel = MyHyperModel(),
hyperparameters = hp_mlp_1_bn,
tune_new_entries = False,
objective = 'val_accuracy',
directory = "Tuners/Tuner_MLP_BN_1",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_BN_1\Search_1\tuner0.json

# %%
tuner_mlp_1_bn.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}

# %%
# tuner_mlp_1_bn.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_mlp_1_bn.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_BN_1\Search_1
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0143 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0131
# Score: 0.5310710668563843
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.004940941354973656
# batch_size: 32
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0229
# Score: 0.5305658578872681
#
# Trial 0245 summary
# Hyperparameters:
# learning_rate: 0.03881688009650394
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0240
# Score: 0.53031325340271
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.002251828971873677
# batch_size: 64
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0144
# Score: 0.529471218585968
#
# Trial 0208 summary
# Hyperparameters:
# learning_rate: 0.004950942993961915
# batch_size: 64
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0205
# Score: 0.5287975668907166
#
# Trial 0252 summary
# Hyperparameters:
# learning_rate: 0.020510566401299328
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# Score: 0.5287975668907166
#
# Trial 0146 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0143
# Score: 0.5282081365585327
#
# Trial 0209 summary
# Hyperparameters:
# learning_rate: 0.01684037787749665
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0204
# Score: 0.5277871489524841
#
# Trial 0247 summary
# Hyperparameters:
# learning_rate: 0.015816941776291463
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0238
# Score: 0.5263556838035583
#
# Trial 0250 summary
# Hyperparameters:
# learning_rate: 0.0055838062132479395
# batch_size: 16
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# hidden_layers: 2
# batch_norm: True
# dropout: False
# do_rate: 0.2
# units_1: 16
# units_2: 16
# Score: 0.5254294276237488

# %%
# Get the optimal hyperparameters
hyps_mlp_1_bn = tuner_mlp_1_bn.get_best_hyperparameters(num_trials=1)[0]
print(hyps_mlp_1_bn.values)
# Out:
# {'learning_rate': 0.01894635097944879, 'batch_size': 64, 'tuner/epochs': 34, 'tuner/initial_epoch': 12, 'tuner/bracket': 4, 'tuner/round': 3, 'hidden_layers': 2, 'batch_norm': True, 'dropout': False, 'do_rate': 0.2, 'units_1': 16, 'units_2': 16, 'tuner/trial_id': '0131'}

# %% [markdown]
# Now that we have the optimal values of the learning rate and batch size, let's look for the optimal size of the network.

# %%
hp_mlp_2_bn = kt.HyperParameters()
hp_mlp_2_bn.Fixed("learning_rate", value = hyps_mlp_1_bn["learning_rate"])
hp_mlp_2_bn.Fixed("batch_size", value = hyps_mlp_1_bn["batch_size"])
hp_mlp_2_bn.Fixed("batch_norm", value = True)
hp_mlp_2_bn.Fixed("dropout", value = False)
hp_mlp_2_bn.Fixed("dropout_rate", value = 0.2)

tuner_mlp_2_bn = kt.Hyperband(
MyHyperModel(),
hyperparameters = hp_mlp_2_bn,
tune_new_entries = True,
objective = 'val_accuracy',
directory = "Tuners/Tuner_MLP_BN_2",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_BN_2\Search_1\tuner0.json

# %%
tuner_mlp_2_bn.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# learning_rate (Fixed)
# {'conditions': [], 'value': 0.01894635097944879}
# batch_size (Fixed)
# {'conditions': [], 'value': 64}
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# do_rate (Fixed)
# {'conditions': [], 'value': 0.2}
# hidden_layers (Int)
# {'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# tuner_mlp_2_bn.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_mlp_2_bn.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_BN_2\Search_1
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0245 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 5
# units_1: 16
# units_2: 80
# units_3: 16
# units_4: 112
# units_5: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0240
# Score: 0.5301448106765747
#
# Trial 0252 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5282081365585327
#
# Trial 0240 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 5
# units_1: 16
# units_2: 80
# units_3: 16
# units_4: 112
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5280397534370422
#
# Trial 0253 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 3
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 48
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5277029275894165
#
# Trial 0230 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 4
# units_1: 16
# units_2: 112
# units_3: 16
# units_4: 80
# units_5: 112
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0218
# Score: 0.5251768231391907
#
# Trial 0144 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 48
# units_3: 112
# units_4: 48
# units_5: 112
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0136
# Score: 0.525092601776123
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 4
# units_1: 16
# units_2: 112
# units_3: 16
# units_4: 80
# units_5: 112
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0230
# Score: 0.5249242186546326
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 80
# units_3: 16
# units_4: 80
# units_5: 80
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0142
# Score: 0.5246716141700745
#
# Trial 0231 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 5
# units_1: 16
# units_2: 112
# units_3: 48
# units_4: 112
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0216
# Score: 0.5244190096855164
#
# Trial 0228 summary
# Hyperparameters:
# learning_rate: 0.01894635097944879
# batch_size: 64
# batch_norm: True
# dropout: False
# do_rate: 0.2
# hidden_layers: 5
# units_1: 16
# units_2: 112
# units_3: 16
# units_4: 80
# units_5: 112
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0212
# Score: 0.5236611366271973

# %%
# Get the optimal hyperparameters
hyps_mlp_2_bn = tuner_mlp_2_bn.get_best_hyperparameters(num_trials=1)[0]
model_mlp_2_bn = tuner_mlp_2_bn.hypermodel.build(hyps_mlp_2_bn)

print(hyps_mlp_2_bn.values)
# Out:
# {'learning_rate': 0.01894635097944879, 'batch_size': 64, 'batch_norm': True, 'dropout': False, 'do_rate': 0.2, 'hidden_layers': 5, 'units_1': 16, 'units_2': 80, 'units_3': 16, 'units_4': 112, 'units_5': 16, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0240', 'dropout_rate': 0.2}

# %% [markdown]
# Now, we will train the model with the optimized hyperparameters.

# %%
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                            factor=0.5, patience=6, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#      monitor="loss", mode="min",
#      patience=24, min_delta=1e-4, restore_best_weights=True
# )
# 
# # epochs=108=100k/59k*64
# # 217 qwk: .5119 .5052
# # 150 qwk: .5156 .5094
# history_model_mlp_2_bn = model_mlp_2_bn.fit(x=X_train_L1reg_np, y=y_train, 
#                                             epochs=150, 
#                                             validation_data=(X_valid_L1reg_np, y_valid), 
#                                             callbacks = [sched, es_train],
#                                            )
# model_mlp_2_bn.save("Models/model_mlp_2_bn/model.keras")
# with open('Models/model_mlp_2_bn/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_2_bn.history, file_pi)

# %%
model_mlp_2_bn = keras.models.load_model("Models/model_mlp_2_bn/model.keras")
with open('Models/model_mlp_2_bn/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_2_bn = pickle.load(file_pi)

# %%
plt.plot(history_model_mlp_2_bn['loss'])
plt.plot(history_model_mlp_2_bn['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
plt.plot(history_model_mlp_2_bn['QuadraticWeightedKappa'])
plt.plot(history_model_mlp_2_bn['val_QuadraticWeightedKappa'])
plt.title('Model QuadraticWeightedKappa')
plt.ylabel('QuadraticWeightedKappa')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print()
print("[Loss, Accuracy, Average QWK] :", model_mlp_2_bn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_2_bn = QuadraticWeightedKappa(y_train, model_mlp_2_bn.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_2_bn)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 2s 1ms/step - loss: 1.2329 - accuracy: 0.5491 - QuadraticWeightedKappa: 0.4975
# [Loss, Accuracy, Average QWK] : [1.2329156398773193, 0.54911869764328, 0.4974943697452545]
# 1114/1114 [==============================] - 1s 778us/step
# Quadratic Weighted Kappa on training set: 0.50819147

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_2_bn.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_2_bn = QuadraticWeightedKappa(y_valid, model_mlp_2_bn.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_2_bn)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 979us/step - loss: 1.2985 - accuracy: 0.5309 - QuadraticWeightedKappa: 0.5027
# [Loss, Accuracy, Average QWK]: [1.298513650894165, 0.5309026837348938, 0.5026980638504028]
# 372/372 [==============================] - 0s 766us/step
# Quadratic Weighted Kappa on validation set: 0.5093546

# %%
baseline = 0.67938
model_mlp_2_bn_bias = baseline-qwk_train_model_mlp_2_bn
model_mlp_2_bn_var = qwk_train_model_mlp_2_bn-qwk_valid_model_mlp_2_bn
print("Bias / Variance of the model: ")
print(round(model_mlp_2_bn_bias,3),"/",round(model_mlp_2_bn_var,3))
# Out:
# Bias / Variance of the model:
# 0.171 / -0.001

# %% [markdown]
# Since there's a larger bias than variance, and the optimal number of layers found in the last search was the largest value of the hyperparameter search space, we'll attempt to reduce the bias by increasing the number of layers, for which we will be tuning them from 6 to 8.

# %%
hp_mlp_3.Choice("learning_rate", values =[hyps_mlp_1["learning_rate"], 1e-3, 3e-4, 5e-4, 7.5e-4,])
hp_mlp_3.Choice("batch_size", values = [hyps_mlp_1["batch_size"],hyps_mlp_1["batch_size"]*2 ])

hp_mlp_3_bn = kt.HyperParameters()

# Fixed
hp_mlp_3_bn.Fixed("batch_norm", value = True)
hp_mlp_3_bn.Fixed("dropout", value = False)
hp_mlp_3_bn.Fixed("dropout_rate", value = 0.0)

hp_mlp_3_bn.Choice("learning_rate", values = [9e-3, 1.3e-2, hyps_mlp_1_bn["learning_rate"], 2.8e-2, 4e-2])
hp_mlp_3_bn.Choice("batch_size", values = [32, hyps_mlp_1_bn["batch_size"], 128, 256])

hp_mlp_3_bn.Int('hidden_layers', min_value=6, max_value=12, step=2)

tuner_mlp_3_bn = kt.Hyperband(
    MyHyperModel(),
    objective = kt.Objective("val_loss", direction="min"),
    max_epochs = 70,                 # 60–80 is a good band
    factor = 3,
    hyperband_iterations = 2,        # >1 brackets = better coverage
    hyperparameters = hp_mlp_3_bn,
    tune_new_entries = True,
    seed = SEED,
    directory = "Tuners/Tuner_MLP_BN_3",
    project_name = "Search_1",
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_BN_3\Search_1\tuner0.json

# %%
tuner_mlp_3_bn.search_space_summary()
# Out:
# Search space summary
# Default search space size: 18
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.0}
# learning_rate (Choice)
# {'default': 0.009, 'conditions': [], 'values': [0.009, 0.013, 0.01894635097944879, 0.028, 0.04], 'ordered': True}
# batch_size (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128, 256], 'ordered': True}
# hidden_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 6, 'max_value': 12, 'step': 2, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# os.makedirs("Tuners/Tuner_MLP_BN_3/checkpoints", exist_ok=True)
# 
# # Callbacks
# early_stop = keras.callbacks.EarlyStopping(
#     monitor="val_loss",          # stop based on generalization, not train loss
#     mode="min",
#     patience=12,                 # lenient so deeper nets get time to learn
#     min_delta=1e-4,              # require a *meaningful* improvement
#     restore_best_weights=True    # roll back to best epoch within this trial
# )
# 
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor="val_loss",
#     mode="min",
#     factor=0.5,                  # halve LR on plateau
#     patience=5,                  # wait a few epochs before reducing
#     min_lr=5e-5                  # don't shrink LR to near-zero
# )
# 
# # Directory path => SavedModel format (no `.keras` extension)
# ckpt = keras.callbacks.ModelCheckpoint(
#     filepath=os.path.join("Tuners/Tuner_MLP_BN_3/checkpoints", "best_mlp3"),
#     monitor="val_loss", mode="min",
#     save_best_only=True
# )
# 
# # IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
# tuner_mlp_3_bn.search(
# X_train_L1reg_np, y_train,
# validation_data=(X_valid_L1reg_np, y_valid),
# epochs=70,                   # matches max_epochs in the tuner
# callbacks=[early_stop, reduce_lr, ckpt],
# verbose=1
# )

# %%
tuner_mlp_3_bn.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_BN_3\Search_1
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0073 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.01894635097944879
# batch_size: 64
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# units_9: 112
# units_10: 16
# units_11: 16
# units_12: 48
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0071
# Score: 1.2988340854644775
#
# Trial 0177 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.028
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 48
# units_3: 80
# units_4: 16
# units_5: 112
# units_6: 16
# units_7: 16
# units_8: 112
# units_9: 16
# units_10: 80
# units_11: 16
# units_12: 112
# tuner/epochs: 70
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.2994356155395508
#
# Trial 0072 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 32
# hidden_layers: 6
# units_1: 16
# units_2: 80
# units_3: 80
# units_4: 48
# units_5: 80
# units_6: 48
# units_7: 80
# units_8: 80
# units_9: 80
# units_10: 16
# units_11: 80
# units_12: 112
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0067
# Score: 1.300879716873169
#
# Trial 0173 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 16
# units_5: 80
# units_6: 48
# units_7: 16
# units_8: 48
# units_9: 80
# units_10: 16
# units_11: 80
# units_12: 80
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0171
# Score: 1.3019524812698364
#
# Trial 0051 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 128
# hidden_layers: 6
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 80
# units_5: 48
# units_6: 112
# units_7: 112
# units_8: 48
# units_9: 48
# units_10: 112
# units_11: 48
# units_12: 16
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0048
# Score: 1.3024115562438965
#
# Trial 0088 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.028
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 80
# units_3: 80
# units_4: 112
# units_5: 16
# units_6: 80
# units_7: 48
# units_8: 48
# units_9: 48
# units_10: 80
# units_11: 48
# units_12: 80
# tuner/epochs: 70
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3027592897415161
#
# Trial 0050 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 112
# units_3: 16
# units_4: 48
# units_5: 48
# units_6: 16
# units_7: 80
# units_8: 48
# units_9: 80
# units_10: 48
# units_11: 80
# units_12: 48
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0046
# Score: 1.3058902025222778
#
# Trial 0172 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.04
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 112
# units_3: 112
# units_4: 16
# units_5: 48
# units_6: 80
# units_7: 48
# units_8: 112
# units_9: 112
# units_10: 80
# units_11: 80
# units_12: 80
# tuner/epochs: 70
# tuner/initial_epoch: 24
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0167
# Score: 1.3071918487548828
#
# Trial 0046 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 64
# hidden_layers: 6
# units_1: 16
# units_2: 112
# units_3: 16
# units_4: 48
# units_5: 48
# units_6: 16
# units_7: 80
# units_8: 48
# units_9: 80
# units_10: 48
# units_11: 80
# units_12: 48
# tuner/epochs: 24
# tuner/initial_epoch: 8
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0034
# Score: 1.3080185651779175
#
# Trial 0067 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# learning_rate: 0.009
# batch_size: 32
# hidden_layers: 6
# units_1: 16
# units_2: 80
# units_3: 80
# units_4: 48
# units_5: 80
# units_6: 48
# units_7: 80
# units_8: 80
# units_9: 80
# units_10: 16
# units_11: 80
# units_12: 112
# tuner/epochs: 24
# tuner/initial_epoch: 8
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0064
# Score: 1.3091744184494019

# %%
# Get the optimal hyperparameters
hyps_mlp_3_bn = tuner_mlp_3_bn.get_best_hyperparameters(num_trials=1)[0]
model_mlp_3_bn = tuner_mlp_3_bn.hypermodel.build(hyps_mlp_3_bn)

print(hyps_mlp_3_bn.values)
# Out:
# {'batch_norm': True, 'dropout': False, 'dropout_rate': 0.0, 'learning_rate': 0.01894635097944879, 'batch_size': 64, 'hidden_layers': 8, 'units_1': 16, 'units_2': 16, 'units_3': 16, 'units_4': 112, 'units_5': 80, 'units_6': 112, 'units_7': 16, 'units_8': 48, 'units_9': 112, 'units_10': 16, 'units_11': 16, 'units_12': 48, 'tuner/epochs': 70, 'tuner/initial_epoch': 24, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0071'}

# %%
hp_mlp_4_bn = kt.HyperParameters()

# --- Stage A2: LR & BS retune on the best deeper architecture ---
hp_mlp_4_bn.Fixed('batch_norm', True)
hp_mlp_4_bn.Fixed('dropout', False)
hp_mlp_4_bn.Fixed('dropout_rate', 0.0)

# freeze architecture from Stage A1
hp_mlp_4_bn.Fixed('hidden_layers', hyps_mlp_3_bn['hidden_layers'])
for i in range(hyps_mlp_3_bn['hidden_layers']): hp_mlp_4_bn.Fixed(f'units_{i+1}', hyps_mlp_3_bn[f'units_{i+1}'])
    
# initialize tuner
tuner_mlp_4_bn = kt.Hyperband(
    MyHyperModel(),
    objective = kt.Objective("val_loss", direction="min"),
    max_epochs = 50,                 
    factor = 3,
    hyperband_iterations = 2,        
    hyperparameters = hp_mlp_4_bn,
    tune_new_entries = True,
    seed = SEED,
    directory = "Tuners/Tuner_MLP_BN_4",
    project_name = "Search_1", # new project name
)
# Out:
# Reloading Tuner from Tuners/Tuner_MLP_BN_4\Search_1\tuner0.json

# %%
# os.makedirs("Tuners/Tuner_MLP_BN_4/checkpoints", exist_ok=True)
# 
# # Callbacks
# early_stop = keras.callbacks.EarlyStopping(
#     monitor="val_loss",          # stop based on generalization, not train loss
#     mode="min",
#     patience=8,                 # lenient so deeper nets get time to learn
#     min_delta=1e-4,              # require a *meaningful* improvement
#     restore_best_weights=True    # roll back to best epoch within this trial
# )
# 
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor="val_loss",
#     mode="min",
#     factor=0.5,                  # halve LR on plateau
#     patience=4,                  # wait a few epochs before reducing
#     min_lr=1e-5                  # don't shrink LR to near-zero
# )
# 
# # Directory path => SavedModel format (no `.keras` extension)
# ckpt = keras.callbacks.ModelCheckpoint(
#     filepath=os.path.join("Tuners/Tuner_MLP_BN_4/checkpoints", "best_mlp4"),
#     monitor="val_loss", mode="min",
#     save_best_only=True
# )
# 
# 
# # IMPORTANT: epochs should match max_epochs for Hyperband’s rung budgets
# tuner_mlp_4_bn.search(
#     X_train_L1reg_np, y_train,
#     validation_data=(X_valid_L1reg_np, y_valid),
#     epochs=50,                   # matches max_epochs in the tuner
#     callbacks=[early_stop, reduce_lr, ckpt],
#     verbose=1
# )

# %%
tuner_mlp_4_bn.results_summary()
# Out:
# Results summary
# Results in Tuners/Tuner_MLP_BN_4\Search_1
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0162 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.007134642978148089
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0160
# Score: 1.2983157634735107
#
# Trial 0087 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.042489322542059005
# batch_size: 256
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.2996224164962769
#
# Trial 0179 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.0035236792798913996
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.3001530170440674
#
# Trial 0050 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.001681154540009978
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0046
# Score: 1.3047960996627808
#
# Trial 0140 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.0024685778932152635
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0138
# Score: 1.309185266494751
#
# Trial 0051 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.001544502838339863
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0048
# Score: 1.313938856124878
#
# Trial 0141 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.0015513195830172601
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0137
# Score: 1.3159358501434326
#
# Trial 0072 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.0016506110681584517
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0069
# Score: 1.3226650953292847
#
# Trial 0083 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.0009859078787732482
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0078
# Score: 1.324050784111023
#
# Trial 0082 summary
# Hyperparameters:
# batch_norm: True
# dropout: False
# dropout_rate: 0.0
# hidden_layers: 8
# units_1: 16
# units_2: 16
# units_3: 16
# units_4: 112
# units_5: 80
# units_6: 112
# units_7: 16
# units_8: 48
# learning_rate: 0.000845090356944702
# batch_size: 32
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0077
# Score: 1.3244078159332275

# %%
# Get the optimal hyperparameters
hyps_mlp_4_bn = tuner_mlp_4_bn.get_best_hyperparameters(num_trials=1)[0]
model_mlp_4_bn = tuner_mlp_4_bn.hypermodel.build(hyps_mlp_4_bn)

print(hyps_mlp_4_bn.values)
# Out:
# {'batch_norm': True, 'dropout': False, 'dropout_rate': 0.0, 'hidden_layers': 8, 'units_1': 16, 'units_2': 16, 'units_3': 16, 'units_4': 112, 'units_5': 80, 'units_6': 112, 'units_7': 16, 'units_8': 48, 'learning_rate': 0.007134642978148089, 'batch_size': 64, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0160'}

# %%
# sched = keras.callbacks.ReduceLROnPlateau(monitor="loss", mode="min",
#                                           factor=0.5, patience=8, min_lr=1e-6)
# es_train = keras.callbacks.EarlyStopping(
#     monitor="loss", mode="min",
#     patience=30, min_delta=1e-4, restore_best_weights=True
# )
# #217: Very Good/ 180
# history_model_mlp_4_bn = model_mlp_4_bn.fit(x=X_train_L1reg_np, y=y_train, 
#                                       epochs=217,
#                                       validation_data=(X_valid_L1reg_np, y_valid), 
#                                       callbacks = [sched, es_train],
#                                      )
# Out:
# Epoch 1/217
# 1114/1114 [==============================] - 6s 3ms/step - loss: 1.5749 - accuracy: 0.4210 - QuadraticWeightedKappa: 0.3989 - val_loss: 1.5348 - val_accuracy: 0.4309 - val_QuadraticWeightedKappa: 0.4784 - lr: 0.0071
# Epoch 2/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.4593 - accuracy: 0.4664 - QuadraticWeightedKappa: 0.4428 - val_loss: 1.4303 - val_accuracy: 0.4678 - val_QuadraticWeightedKappa: 0.4686 - lr: 0.0071
# Epoch 3/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.4302 - accuracy: 0.4708 - QuadraticWeightedKappa: 0.4563 - val_loss: 1.4265 - val_accuracy: 0.4848 - val_QuadraticWeightedKappa: 0.5127 - lr: 0.0071
# Epoch 4/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.4128 - accuracy: 0.4801 - QuadraticWeightedKappa: 0.4644 - val_loss: 1.4557 - val_accuracy: 0.4635 - val_QuadraticWeightedKappa: 0.4983 - lr: 0.0071
# Epoch 5/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.3997 - accuracy: 0.4857 - QuadraticWeightedKappa: 0.4648 - val_loss: 1.3919 - val_accuracy: 0.4943 - val_QuadraticWeightedKappa: 0.5059 - lr: 0.0071
# Epoch 6/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.3912 - accuracy: 0.4870 - QuadraticWeightedKappa: 0.4685 - val_loss: 1.4003 - val_accuracy: 0.4774 - val_QuadraticWeightedKappa: 0.4381 - lr: 0.0071
# Epoch 7/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.3870 - accuracy: 0.4911 - QuadraticWeightedKappa: 0.4705 - val_loss: 1.3998 - val_accuracy: 0.4981 - val_QuadraticWeightedKappa: 0.5152 - lr: 0.0071
# Epoch 8/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.3798 - accuracy: 0.4910 - QuadraticWeightedKappa: 0.4709 - val_loss: 1.3717 - val_accuracy: 0.4977 - val_QuadraticWeightedKappa: 0.5094 - lr: 0.0071
# Epoch 9/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.3791 - accuracy: 0.4938 - QuadraticWeightedKappa: 0.4701 - val_loss: 1.3695 - val_accuracy: 0.5010 - val_QuadraticWeightedKappa: 0.5040 - lr: 0.0071
# Epoch 10/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.
217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2582 - accuracy: 0.5381 - QuadraticWeightedKappa: 0.5060 - val_loss: 1.3042 - val_accuracy: 0.5300 - val_QuadraticWeightedKappa: 0.5044 - lr: 4.4592e-04
# Epoch 205/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2623 - accuracy: 0.5379 - QuadraticWeightedKappa: 0.5000 - val_loss: 1.3043 - val_accuracy: 0.5301 - val_QuadraticWeightedKappa: 0.5009 - lr: 4.4592e-04
# Epoch 206/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2601 - accuracy: 0.5387 - QuadraticWeightedKappa: 0.5042 - val_loss: 1.3047 - val_accuracy: 0.5296 - val_QuadraticWeightedKappa: 0.5037 - lr: 4.4592e-04
# Epoch 207/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2643 - accuracy: 0.5340 - QuadraticWeightedKappa: 0.5023 - val_loss: 1.3040 - val_accuracy: 0.5296 - val_QuadraticWeightedKappa: 0.5026 - lr: 4.4592e-04
# Epoch 208/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2593 - accuracy: 0.5388 - QuadraticWeightedKappa: 0.5045 - val_loss: 1.3051 - val_accuracy: 0.5286 - val_QuadraticWeightedKappa: 0.4998 - lr: 4.4592e-04
# Epoch 209/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2614 - accuracy: 0.5345 - QuadraticWeightedKappa: 0.4950 - val_loss: 1.3033 - val_accuracy: 0.5292 - val_QuadraticWeightedKappa: 0.5024 - lr: 4.4592e-04
# Epoch 210/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2603 - accuracy: 0.5367 - QuadraticWeightedKappa: 0.5003 - val_loss: 1.3044 - val_accuracy: 0.5299 - val_QuadraticWeightedKappa: 0.5005 - lr: 4.4592e-04
# Epoch 211/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2604 - accuracy: 0.5370 - QuadraticWeightedKappa: 0.5000 - val_loss: 1.3038 - val_accuracy: 0.5291 - val_QuadraticWeightedKappa: 0.4998 - lr: 2.2296e-04
# Epoch 212/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2557 - accuracy: 0.5371 - QuadraticWeightedKappa: 0.5059 - val_loss: 1.3040 - val_accuracy: 0.5281 - val_QuadraticWeightedKappa: 0.5007 - lr: 2.2296e-04
# Epoch 213/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2596 - accuracy: 0.5387 - QuadraticWeightedKappa: 0.5056 - val_loss: 1.3037 - val_accuracy: 0.5307 - val_QuadraticWeightedKappa: 0.4991 - lr: 2.2296e-04
# Epoch 214/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2572 - accuracy: 0.5372 - QuadraticWeightedKappa: 0.5066 - val_loss: 1.3036 - val_accuracy: 0.5291 - val_QuadraticWeightedKappa: 0.5004 - lr: 2.2296e-04
# Epoch 215/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2568 - accuracy: 0.5387 - QuadraticWeightedKappa: 0.5011 - val_loss: 1.3051 - val_accuracy: 0.5307 - val_QuadraticWeightedKappa: 0.5012 - lr: 2.2296e-04
# Epoch 216/217
# 1114/1114 [==============================] - 3s 2ms/step - loss: 1.2593 - accuracy: 0.5387 - QuadraticWeightedKappa: 0.5029 - val_loss: 1.3041 - val_accuracy: 0.5300 - val_QuadraticWeightedKappa: 0.4992 - lr: 2.2296e-04
# Epoch 217/217
# 1114/1114 [==============================] - 3s 3ms/step - loss: 1.2571 - accuracy: 0.5388 - QuadraticWeightedKappa: 0.5015 - val_loss: 1.3055 - val_accuracy: 0.5301 - val_QuadraticWeightedKappa: 0.4958 - lr: 2.2296e-04

# %%
# os.makedirs("Models/model_mlp_4_bn", exist_ok=True)
# 
# model_mlp_4_bn.save("Models/model_mlp_4_bn/model.keras")
# with open('Models/model_mlp_4_bn/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_mlp_4_bn.history, file_pi)

# %%
model_mlp_4_bn = keras.models.load_model("Models/model_mlp_4_bn/model.keras", compile=False)                                                       
model_mlp_4_bn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[QuadraticWeightedKappaMetric()]
)

with open('Models/model_mlp_4_bn/trainHistoryDict', "rb") as file_pi:
    history_model_mlp_4_bn = pickle.load(file_pi)

plt.plot(history_model_mlp_4_bn['loss'])
plt.plot(history_model_mlp_4_bn['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[69], line 9
#       2 model_mlp_4_bn.compile(
#       3     optimizer='adam',
#       4     loss='sparse_categorical_crossentropy',
#       5     metrics=[QuadraticWeightedKappaMetric()]
#       6 )
#       8 with open('Models/model_mlp_4_bn/trainHistoryDict', "rb") as file_pi:
# ----> 9     history_model_mlp_4_bn = pickle.load(file_pi)
#      11 plt.plot(history_model_mlp_4_bn['loss'])
#      12 plt.plot(history_model_mlp_4_bn['val_loss'])
#
# EOFError: Ran out of input

# %%
# Performance on training set
print("Train evaluation")
print(np.shape(X_train_L1reg_np), np.size(y_train))
print("[Loss, Accuracy, Average QWK] :", model_mlp_4_bn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_mlp_4_bn = QuadraticWeightedKappa(y_train, model_mlp_4_bn.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_mlp_4_bn)
# Out:
# Train evaluation
# (35628, 57) 35628
# 1114/1114 [==============================] - 2s 1ms/step - loss: 1.2145 - quadratic_weighted_kappa: 0.7647
# [Loss, Accuracy, Average QWK] : [1.214510440826416, 0.7647058963775635]
# 1114/1114 [==============================] - 1s 925us/step
# Quadratic Weighted Kappa on training set: 0.5172162

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_mlp_4_bn.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_mlp_4_bn = QuadraticWeightedKappa(y_valid, model_mlp_4_bn.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_mlp_4_bn)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 1.3055 - quadratic_weighted_kappa: 0.8421
# [Loss, Accuracy, Average QWK]: [1.3055131435394287, 0.8421052694320679]
# 372/372 [==============================] - 0s 926us/step
# Quadratic Weighted Kappa on validation set: 0.5036478

# %%
baseline = 0.67938
model_mlp_4_bn_bias = baseline-qwk_train_model_mlp_4_bn
model_mlp_4_bn_var = qwk_train_model_mlp_4_bn-qwk_valid_model_mlp_4_bn
print("Bias / Variance of the model: ")
print(round(model_mlp_4_bn_bias,3),"/",round(model_mlp_4_bn_var,3))
# Out:
# Bias / Variance of the model:
# 0.162 / 0.014

# %% [markdown]
# The performance with more layers decreased slightly on the validation set and didn't improve significantly on the training set, so for now the version of the MLP with softmax as activation function of the last layer is the one with batch normalization and without dropout, with the hyperparameters found in the second search (model_mlp_2_bn). We select the multilayer perceptron with batch normalization as the best one so far. Now we'll explore the second model proposed, the CORN model integrated to our multilayer perceptron.
#
# <a name='3.2.2'></a>
# ### 3.2.2 Model 2: Corn Multilayer Perceptron
#
# In this section, we will discuss the process of developing and optimizing the Ordinal Multilayer Perceptron (CORN MLP). First, we construct the hypermodel of the CORN MLP model, defining the hyperparameters.

# %%
class CornHyperModel(kt.HyperModel):
    def build(self, hp):
        
        feature_size = 57
        output_size = 8
        
        model = keras.Sequential()
        
        # Hyperparams definition
        
        hp_learning_rate = hp.Float("learning_rate", min_value = 1e-4, max_value = 1e-1, sampling = "log")
        hp_layers = hp.Int('hidden_layers', 1, 5, default = 2)
        hp_bn = hp.Boolean('batch_norm', default = True)
        hp_dropout = hp.Boolean('dropout', default = False)
        hp_do_rate = hp.Float('dropout_rate', min_value = 0.1, max_value = 0.5, default = 0.2)
        hp_learning_rate = hp.Float("learning_rate", min_value = 1e-4, max_value = 1e-1, sampling = "log")

        for i in range(1,1+hp_layers):
            
             model.add(
                 keras.layers.Dense(                      
                     units = hp.Int('units_'+str(i), min_value = 2*output_size,
                     max_value = 2*feature_size, step = 32), kernel_initializer = 'he_normal'                    
                 )
             )
                
             if hp_bn:   
                model.add(
                   keras.layers.BatchNormalization()
                )
                
             model.add(
                 keras.layers.Activation('relu'),                     
                 )
               
             if hp_dropout:   
                model.add(
                   keras.layers.Dropout(rate = hp_do_rate)
                )
        
        model.add(
            coral.CornOrdinal(output_size)
        )
        
        model.compile(optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate),
                      loss = coral.CornOrdinalCrossEntropy(),
                      metrics = coral.MeanAbsoluteErrorLabels())  

        return model
    
    
    def fit(self, hp, model, *args, **kwargs):
            return model.fit(
                *args,
                batch_size = hp.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024], default= 32),               
                **kwargs,
            )

# %% [markdown]
# We will now conduct our search, just as before, starting with the learning rate and batch size.

# %%
hp_corn_only = kt.HyperParameters()
hp_corn_only.Float("learning_rate", min_value = 1e-4, max_value = 1e-1, sampling = "log")
hp_corn_only.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024])
hp_corn_only.Fixed("batch_norm", value = False)


tuner_corn_only = kt.Hyperband(
CornHyperModel(),
hyperparameters = hp_corn_only,
tune_new_entries = False,
objective = kt.Objective("val_mean_absolute_error_labels", "min"), 
directory = "Tuners/Corn_Only_Tuner",
project_name = "Search_01",
seed = 5,
)
print()
tuner_corn_only.search_space_summary()
# Out:
# Reloading Tuner from Tuners/Corn_Only_Tuner\Search_01\tuner0.json
#
# Search space summary
# Default search space size: 3
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}
# batch_norm (Fixed)
# {'conditions': [], 'value': False}

# %%
# monitor='loss', patience=10, epochs=
# tuner_corn_only.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10,restore_best_weights= True )])

# %% [markdown]
# Here the results of the hyperparameter search are displayed.

# %%
tuner_corn_only.results_summary()
# Out:
# Results summary
# Results in Tuners/Corn_Only_Tuner\Search_01
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0114 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 4
# tuner/round: 1
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0015
# Score: 1.443800449371338
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.023013853538234333
# batch_size: 64
# batch_norm: False
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0233
# Score: 1.4636163711547852
#
# Trial 0059 summary
# Hyperparameters:
# learning_rate: 0.002270897833857743
# batch_size: 16
# batch_norm: False
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 4
# tuner/round: 0
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# Score: 1.466268539428711
#
# Trial 0233 summary
# Hyperparameters:
# learning_rate: 0.023013853538234333
# batch_size: 64
# batch_norm: False
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0218
# Score: 1.4666779041290283
#
# Trial 0230 summary
# Hyperparameters:
# learning_rate: 0.01447420713186211
# batch_size: 256
# batch_norm: False
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0223
# Score: 1.4671741724014282
#
# Trial 0210 summary
# Hyperparameters:
# learning_rate: 0.0014383567347209258
# batch_size: 64
# batch_norm: False
# tuner/epochs: 12
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# Score: 1.4774399995803833
#
# Trial 0146 summary
# Hyperparameters:
# learning_rate: 0.001681154540009978
# batch_size: 32
# batch_norm: False
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0143
# Score: 1.479082703590393
#
# Trial 0235 summary
# Hyperparameters:
# learning_rate: 0.01447420713186211
# batch_size: 256
# batch_norm: False
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0230
# Score: 1.47921884059906
#
# Trial 0140 summary
# Hyperparameters:
# learning_rate: 0.003680880592024201
# batch_size: 32
# batch_norm: False
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 4
# tuner/round: 2
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0106
# Score: 1.4834508895874023
#
# Trial 0125 summary
# Hyperparameters:
# learning_rate: 0.020643000310335155
# batch_size: 128
# batch_norm: False
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 4
# tuner/round: 1
# hidden_layers: 2
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0045
# Score: 1.488534927368164

# %%
# Get the optimal hyperparameters
hyps_corn_only = tuner_corn_only.get_best_hyperparameters()[0]
print(hyps_corn_only.values)
# Out:
# {'learning_rate': 0.0031089211420179527, 'batch_size': 32, 'batch_norm': False, 'tuner/epochs': 4, 'tuner/initial_epoch': 2, 'tuner/bracket': 4, 'tuner/round': 1, 'hidden_layers': 2, 'dropout': False, 'dropout_rate': 0.2, 'units_1': 16, 'units_2': 16, 'tuner/trial_id': '0015'}

# %% [markdown]
# We will proceed with tuning the number of layers and units per layer of the CORN Multilayer Perceptron (CORN MLP), using the learning rate and batch size identified in our previous search.

# %%
hp_corn_no_bn_2 = kt.HyperParameters()

# Fix

hp_corn_no_bn_2.Fixed("learning_rate", value = hyps_corn_only["learning_rate"])
hp_corn_no_bn_2.Fixed("batch_size", value = hyps_corn_only["batch_size"])
hp_corn_no_bn_2.Fixed("batch_norm", value = False)
hp_corn_no_bn_2.Fixed("dropout", value = False)
hp_corn_no_bn_2.Fixed("dropout_rate", value = 0.2)

tuner_corn_only_2 = kt.Hyperband(
CornHyperModel(),
hyperparameters = hp_corn_no_bn_2,
tune_new_entries = True,
objective = kt.Objective("val_mean_absolute_error_labels", "min"), 
directory = "Tuners/Corn_Only_Tuner",
project_name = "Search_02",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Corn_Only_Tuner\Search_02\tuner0.json

# %%
tuner_corn_only_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# learning_rate (Fixed)
# {'conditions': [], 'value': 0.0031089211420179527}
# batch_size (Fixed)
# {'conditions': [], 'value': 32}
# batch_norm (Fixed)
# {'conditions': [], 'value': False}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.2}
# hidden_layers (Int)
# {'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# tuner_corn_only_2.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights= True)])

# %%
tuner_corn_only_2.results_summary()
# Out:
# Results summary
# Results in Tuners/Corn_Only_Tuner\Search_02
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0241 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 16
# units_3: 112
# units_4: 16
# units_5: 48
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 1.4579132795333862
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 16
# units_5: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0228
# Score: 1.4688340425491333
#
# Trial 0172 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 16
# units_3: 48
# units_4: 112
# units_5: 112
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.469338059425354
#
# Trial 0226 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 16
# units_5: 16
# tuner/epochs: 12
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 1.4698420763015747
#
# Trial 0235 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 1
# units_1: 112
# units_2: 112
# units_3: 80
# units_4: 16
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0229
# Score: 1.4705140590667725
#
# Trial 0150 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 48
# units_3: 48
# units_4: 112
# units_5: 48
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.470682144165039
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 3
# units_1: 80
# units_2: 80
# units_3: 16
# units_4: 80
# units_5: 112
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0144
# Score: 1.470682144165039
#
# Trial 0141 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 4
# units_1: 80
# units_2: 16
# units_3: 80
# units_4: 48
# units_5: 80
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 4
# tuner/round: 2
# tuner/trial_id: 0127
# Score: 1.4736223220825195
#
# Trial 0208 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 48
# units_5: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0204
# Score: 1.475050449371338
#
# Trial 0204 summary
# Hyperparameters:
# learning_rate: 0.0031089211420179527
# batch_size: 32
# batch_norm: False
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 112
# units_2: 16
# units_3: 48
# units_4: 48
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0193
# Score: 1.4755544662475586

# %%
# Get the optimal hyperparameters
hyps_corn_only_2 = tuner_corn_only_2.get_best_hyperparameters()[0]
model_corn_only_2 = tuner_corn_only_2.hypermodel.build(hyps_corn_only_2)
print(hyps_corn_only_2.values)
# Out:
# {'learning_rate': 0.0031089211420179527, 'batch_size': 32, 'batch_norm': False, 'dropout': False, 'dropout_rate': 0.2, 'hidden_layers': 2, 'units_1': 80, 'units_2': 16, 'units_3': 112, 'units_4': 16, 'units_5': 48, 'tuner/epochs': 34, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}

# %% [markdown]
# The optimized model is now deeper and wider, with three hidden layers. Let's fit the fully optimized CORN MLP.

# %%
# monitor='loss', patience=20, Epochs: 300
# history_model_corn_only_2 = model_corn_only_2.fit(x=X_train_L1reg_np, y=y_train, epochs=300, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
# Save training history
model_corn_only_2.save_weights("Models/model_corn_only_2/weights.h5")
with open("Models/model_corn_only_2/trainHistoryDict.pkl", "wb") as file_pi:
    pickle.dump(history_model_corn_only_2.history, file_pi)

# %%
model_corn_only_2.load_weights("Models/model_corn_only_2/weights.h5")

# Load training history
with open("Models/model_corn_only_2/trainHistoryDict.pkl", "rb") as file_pi:
    history_model_corn_only_2 = pickle.load(file_pi)

# %%
# monitor='loss', patience=20, Epochs: 300
plt.plot(history_model_corn_only_2['mean_absolute_error_labels'])
plt.plot(history_model_corn_only_2['val_mean_absolute_error_labels'])
plt.title('Model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
only_ordinal_logits_train_2 = model_corn_only_2.predict(X_train_L1reg_np)
only_ordinal_logits_valid_2 = model_corn_only_2.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
only_tensor_probs_train_2 = coral.corn_ordinal_softmax(only_ordinal_logits_train_2)
only_tensor_probs_valid_2 = coral.corn_ordinal_softmax(only_ordinal_logits_valid_2)

# Obtain labels from probabilities
only_labels_train_2 = coral.cumprobs_to_label(only_tensor_probs_train_2)
only_labels_valid_2 = coral.cumprobs_to_label(only_tensor_probs_valid_2)
# Out:
# 1114/1114 [==============================] - 1s 630us/step
# 372/372 [==============================] - 0s 602us/step

# %%
# In train
# monitor='loss', patience=20, Took Epochs: 68
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_only_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_only_2=QuadraticWeightedKappa(y_train, only_tensor_probs_train_2).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_only_2)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 789us/step - loss: 0.1437 - mean_absolute_error_labels: 1.5105
# [Loss, Mean Absolute Error Labels] : [0.14368993043899536, 1.5104540586471558]
# Quadratic Weighted Kappa on training set: 0.5812943

# %%
# In validation
# monitor='loss', patience=20, Took Epochs: 68

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_only_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_only_2 = QuadraticWeightedKappa(y_valid, only_tensor_probs_valid_2).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_only_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 0.1935 - mean_absolute_error_labels: 1.5670
# [Loss, Mean Absolute Error Labels] : [0.19349756836891174, 1.5669522285461426]
# Quadratic Weighted Kappa on validation set: 0.496782

# %%
model_corn_only_2_bias = baseline-qwk_train_model_corn_only_2
model_corn_only_2_var = qwk_train_model_corn_only_2-qwk_valid_model_mlp_3_bn
print("Bias / Variance of the model: ")
print(round(model_corn_only_2_bias,3),"/",round(model_corn_only_2_var,3))
# Out:
# Bias / Variance of the model:
# 0.098 / 0.081

# %% [markdown]
# For now, we observe that the CORN model presents higher bias than variance. Let's try training it longer, we won't try a deeper arquitecture since in the conducted search where the space allowed for up to 5 hidden layers, the optimal value found was 2.

# %%
# monitor='loss', patience=20, Epochs: 300
history_model_corn_only_2 = model_corn_only_2.fit(x=X_train_L1reg_np, y=y_train, epochs=100, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
#with open('Models/model_corn_only_2/trainHistoryDict', 'wb') as file_pi:
#    pickle.dump(history_model_corn_only_2.history, file_pi)
# Out:
# Epoch 1/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.5118 - val_loss: 0.1921 - val_mean_absolute_error_labels: 1.5762
# Epoch 2/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.5115 - val_loss: 0.1927 - val_mean_absolute_error_labels: 1.5580
# Epoch 3/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1459 - mean_absolute_error_labels: 1.5071 - val_loss: 0.1924 - val_mean_absolute_error_labels: 1.5596
# Epoch 4/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1459 - mean_absolute_error_labels: 1.5045 - val_loss: 0.1932 - val_mean_absolute_error_labels: 1.5361
# Epoch 5/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4965 - val_loss: 0.1944 - val_mean_absolute_error_labels: 1.5580
# Epoch 6/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1459 - mean_absolute_error_labels: 1.4958 - val_loss: 0.1943 - val_mean_absolute_error_labels: 1.5617
# Epoch 7/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1459 - mean_absolute_error_labels: 1.4937 - val_loss: 0.1924 - val_mean_absolute_error_labels: 1.5380
# Epoch 8/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4923 - val_loss: 0.1940 - val_mean_absolute_error_labels: 1.5422
# Epoch 9/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4958 - val_loss: 0.1940 - val_mean_absolute_error_labels: 1.5593
# Epoch 10/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.4931 - val_loss: 0.1912 - val_mean_absolute_error_labels: 1.5697
# Epoch 11/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4985 - val_loss: 0.1947 - val_mean_absolute_error_labels: 1.5643
# Epoch 12/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.5090 - val_loss: 0.1950 - val_mean_absolute_error_labels: 1.5535
# Epoch 13/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.5076 - val_loss: 0.1980 - val_mean_absolute_error_labels: 1.5473
# Epoch 14/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.5064 - val_loss: 0.1963 - val_mean_absolute_error_labels: 1.5361
# Epoch 15/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.5076 - val_loss: 0.1960 - val_mean_absolute_error_labels: 1.5667
# Epoch 16/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.5078 - val_loss: 0.1957 - val_mean_absolute_error_labels: 1.5790
# Epoch 17/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.4974 - val_loss: 0.1932 - val_mean_absolute_error_labels: 1.5355
# Epoch 18/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4911 - val_loss: 0.1939 - val_mean_absolute_error_labels: 1.5675
# Epoch 19/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.4917 - val_loss: 0.1920 - val_mean_absolute_error_labels: 1.5388
# Epoch 20/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4960 - val_loss: 0.1939 - val_mean_absolute_error_labels: 1.5551
# Epoch 21/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4924 - val_loss: 0.1965 - val_mean_absolute_error_labels: 1.5152
# Epoch 22/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4992 - val_loss: 0.1979 - val_mean_absolute_error_labels: 1.5220
# Epoch 23/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4994 - val_loss: 0.1968 - val_mean_absolute_error_labels: 1.5362
# Epoch 24/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4993 - val_loss: 0.1969 - val_mean_absolute_error_labels: 1.5702
# Epoch 25/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4955 - val_loss: 0.1951 - val_mean_absolute_error_labels: 1.5460
# Epoch 26/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.4953 - val_loss: 0.1949 - val_mean_absolute_error_labels: 1.5370
# Epoch 27/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.4990 - val_loss: 0.1956 - val_mean_absolute_error_labels: 1.5641
# Epoch 28/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.5067 - val_loss: 0.1934 - val_mean_absolute_error_labels: 1.5641
# Epoch 29/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4958 - val_loss: 0.1962 - val_mean_absolute_error_labels: 1.5811
# Epoch 30/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.5018 - val_loss: 0.1922 - val_mean_absolute_error_labels: 1.5407
# Epoch 31/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1458 - mean_absolute_error_labels: 1.5024 - val_loss: 0.1970 - val_mean_absolute_error_labels: 1.5891
# Epoch 32/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.5038 - val_loss: 0.1986 - val_mean_absolute_error_labels: 1.5511
# Epoch 33/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.4993 - val_loss: 0.1969 - val_mean_absolute_error_labels: 1.5317
# Epoch 34/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4916 - val_loss: 0.1931 - val_mean_absolute_error_labels: 1.5485
# Epoch 35/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.4926 - val_loss: 0.1972 - val_mean_absolute_error_labels: 1.5923
# Epoch 36/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4969 - val_loss: 0.1920 - val_mean_absolute_error_labels: 1.5730
# Epoch 37/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.5013 - val_loss: 0.1947 - val_mean_absolute_error_labels: 1.5537
# Epoch 38/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.5018 - val_loss: 0.1936 - val_mean_absolute_error_labels: 1.5733
# Epoch 39/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.5075 - val_loss: 0.1956 - val_mean_absolute_error_labels: 1.5769
# Epoch 40/100
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1457 - mean_absolute_error_labels: 1.5161 - val_loss: 0.1962 - val_mean_absolute_error_labels: 1.5598
# Epoch 41/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.5142 - val_loss: 0.2014 - val_mean_absolute_error_labels: 1.5568
# Epoch 42/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.5110 - val_loss: 0.1993 - val_mean_absolute_error_labels: 1.5933
# Epoch 43/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4996 - val_loss: 0.1973 - val_mean_absolute_error_labels: 1.5798
# Epoch 44/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4962 - val_loss: 0.1939 - val_mean_absolute_error_labels: 1.5395
# Epoch 45/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4942 - val_loss: 0.1946 - val_mean_absolute_error_labels: 1.5584
# Epoch 46/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4968 - val_loss: 0.1950 - val_mean_absolute_error_labels: 1.5651
# Epoch 47/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.4917 - val_loss: 0.1976 - val_mean_absolute_error_labels: 1.5421
# Epoch 48/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.4924 - val_loss: 0.1997 - val_mean_absolute_error_labels: 1.5339
# Epoch 49/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4946 - val_loss: 0.1983 - val_mean_absolute_error_labels: 1.5618
# Epoch 50/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4978 - val_loss: 0.1940 - val_mean_absolute_error_labels: 1.5439
# Epoch 51/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.4933 - val_loss: 0.1953 - val_mean_absolute_error_labels: 1.5582
# Epoch 52/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4881 - val_loss: 0.1958 - val_mean_absolute_error_labels: 1.5334
# Epoch 53/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4974 - val_loss: 0.1932 - val_mean_absolute_error_labels: 1.5406
# Epoch 54/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.4946 - val_loss: 0.1952 - val_mean_absolute_error_labels: 1.5439
# Epoch 55/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4946 - val_loss: 0.1966 - val_mean_absolute_error_labels: 1.5455
# Epoch 56/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4997 - val_loss: 0.1946 - val_mean_absolute_error_labels: 1.5817
# Epoch 57/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.5012 - val_loss: 0.1950 - val_mean_absolute_error_labels: 1.5443
# Epoch 58/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error_labels: 1.4991 - val_loss: 0.1958 - val_mean_absolute_error_labels: 1.5868
# Epoch 59/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.4930 - val_loss: 0.1967 - val_mean_absolute_error_labels: 1.5552
# Epoch 60/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.4906 - val_loss: 0.1921 - val_mean_absolute_error_labels: 1.5536
# Epoch 61/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.4942 - val_loss: 0.1998 - val_mean_absolute_error_labels: 1.5612
# Epoch 62/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4907 - val_loss: 0.1959 - val_mean_absolute_error_labels: 1.5330
# Epoch 63/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4983 - val_loss: 0.1988 - val_mean_absolute_error_labels: 1.5670
# Epoch 64/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4951 - val_loss: 0.1989 - val_mean_absolute_error_labels: 1.5507
# Epoch 65/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.5076 - val_loss: 0.2007 - val_mean_absolute_error_labels: 1.5508
# Epoch 66/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4980 - val_loss: 0.2002 - val_mean_absolute_error_labels: 1.5651
# Epoch 67/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1454 - mean_absolute_error_labels: 1.5053 - val_loss: 0.1984 - val_mean_absolute_error_labels: 1.5563
# Epoch 68/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5113 - val_loss: 0.1953 - val_mean_absolute_error_labels: 1.5736
# Epoch 69/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1455 - mean_absolute_error_labels: 1.5076 - val_loss: 0.1950 - val_mean_absolute_error_labels: 1.5635
# Epoch 70/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5006 - val_loss: 0.1967 - val_mean_absolute_error_labels: 1.5339
# Epoch 71/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.4987 - val_loss: 0.1970 - val_mean_absolute_error_labels: 1.5629
# Epoch 72/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.5016 - val_loss: 0.1957 - val_mean_absolute_error_labels: 1.5384
# Epoch 73/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5004 - val_loss: 0.1956 - val_mean_absolute_error_labels: 1.5447
# Epoch 74/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.5067 - val_loss: 0.1971 - val_mean_absolute_error_labels: 1.5542
# Epoch 75/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.5010 - val_loss: 0.1971 - val_mean_absolute_error_labels: 1.5817
# Epoch 76/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.5036 - val_loss: 0.1991 - val_mean_absolute_error_labels: 1.5369
# Epoch 77/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.4944 - val_loss: 0.1972 - val_mean_absolute_error_labels: 1.5676
# Epoch 78/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5043 - val_loss: 0.1946 - val_mean_absolute_error_labels: 1.5609
# Epoch 79/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.4996 - val_loss: 0.1947 - val_mean_absolute_error_labels: 1.5364
# Epoch 80/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4961 - val_loss: 0.1956 - val_mean_absolute_error_labels: 1.5550
# Epoch 81/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5024 - val_loss: 0.1953 - val_mean_absolute_error_labels: 1.5705
# Epoch 82/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1453 - mean_absolute_error_labels: 1.5107 - val_loss: 0.1981 - val_mean_absolute_error_labels: 1.5372
# Epoch 83/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.4970 - val_loss: 0.1976 - val_mean_absolute_error_labels: 1.5335
# Epoch 84/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1452 - mean_absolute_error_labels: 1.5015 - val_loss: 0.1951 - val_mean_absolute_error_labels: 1.5809
# Epoch 85/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5108 - val_loss: 0.1963 - val_mean_absolute_error_labels: 1.5785
# Epoch 86/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.5063 - val_loss: 0.1995 - val_mean_absolute_error_labels: 1.5427
# Epoch 87/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5082 - val_loss: 0.1952 - val_mean_absolute_error_labels: 1.5949
# Epoch 88/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5139 - val_loss: 0.1994 - val_mean_absolute_error_labels: 1.5942
# Epoch 89/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1448 - mean_absolute_error_labels: 1.5159 - val_loss: 0.1974 - val_mean_absolute_error_labels: 1.5986
# Epoch 90/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5032 - val_loss: 0.1973 - val_mean_absolute_error_labels: 1.5813
# Epoch 91/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1446 - mean_absolute_error_labels: 1.5057 - val_loss: 0.1974 - val_mean_absolute_error_labels: 1.5730
# Epoch 92/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5087 - val_loss: 0.1994 - val_mean_absolute_error_labels: 1.5302
# Epoch 93/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1450 - mean_absolute_error_labels: 1.4986 - val_loss: 0.2003 - val_mean_absolute_error_labels: 1.5537
# Epoch 94/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1448 - mean_absolute_error_labels: 1.5092 - val_loss: 0.2015 - val_mean_absolute_error_labels: 1.5521
# Epoch 95/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.5036 - val_loss: 0.1969 - val_mean_absolute_error_labels: 1.5305
# Epoch 96/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1449 - mean_absolute_error_labels: 1.5028 - val_loss: 0.1999 - val_mean_absolute_error_labels: 1.5662
# Epoch 97/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1446 - mean_absolute_error_labels: 1.5022 - val_loss: 0.1968 - val_mean_absolute_error_labels: 1.5591
# Epoch 98/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4952 - val_loss: 0.1986 - val_mean_absolute_error_labels: 1.5932
# Epoch 99/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1448 - mean_absolute_error_labels: 1.4992 - val_loss: 0.1994 - val_mean_absolute_error_labels: 1.5326
# Epoch 100/100
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error_labels: 1.4960 - val_loss: 0.2014 - val_mean_absolute_error_labels: 1.5547

# %%
history_model_corn_only_2=history_model_corn_only_2.history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 history_model_corn_only_2=history_model_corn_only_2.history
#
# AttributeError: 'dict' object has no attribute 'history'

# %%
plt.plot(history_model_corn_only_2['mean_absolute_error_labels'])
plt.plot(history_model_corn_only_2['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
only_ordinal_logits_train_2 = model_corn_only_2.predict(X_train_L1reg_np)
only_ordinal_logits_valid_2 = model_corn_only_2.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
only_tensor_probs_train_2 = coral.corn_ordinal_softmax(only_ordinal_logits_train_2)
only_tensor_probs_valid_2 = coral.corn_ordinal_softmax(only_ordinal_logits_valid_2)

# Obtain labels from probabilities
only_labels_train_2 = coral.cumprobs_to_label(only_tensor_probs_train_2)
only_labels_valid_2 = coral.cumprobs_to_label(only_tensor_probs_valid_2)
# Out:
# 1114/1114 [==============================] - 1s 634us/step
# 372/372 [==============================] - 0s 677us/step

# %%
# In train
# monitor='loss', patience=20, Took Epochs: 68
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_only_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_only_2=QuadraticWeightedKappa(y_train, only_tensor_probs_train_2).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_only_2)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 797us/step - loss: 0.1447 - mean_absolute_error_labels: 1.4934
# [Loss, Mean Absolute Error Labels] : [0.14473776519298553, 1.4933797121047974]
# Quadratic Weighted Kappa on training set: 0.57993376

# %%
# In validation
# monitor='loss', patience=20, Took Epochs: 68

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_only_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_only_2 = QuadraticWeightedKappa(y_valid, only_tensor_probs_valid_2).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_only_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 804us/step - loss: 0.2014 - mean_absolute_error_labels: 1.5547
# [Loss, Mean Absolute Error Labels] : [0.20137985050678253, 1.5546875]
# Quadratic Weighted Kappa on validation set: 0.49626046

# %%
model_corn_only_2_bias = baseline-qwk_train_model_corn_only_2
model_corn_only_2_var = qwk_train_model_corn_only_2-qwk_valid_model_mlp_3_bn
print("Bias / Variance of the model: ")
print(round(model_corn_only_2_bias,3),"/",round(model_corn_only_2_var,3))
# Out:
# Bias / Variance of the model:
# 0.099 / 0.079

# %% [markdown]
# Let's explore the model's performance when adding batch normalization.
#
# ### CORN + Batch Normalization
# Next, we will adjust and evaluate the CORN model with the addition of batch normalization layers. Similar to before, we will begin by tuning the learning rate and batch size hyperparameters.

# %%
# Tune only the learning rate and the mini-batch size hyperparameters

hp_corn_1 = kt.HyperParameters()
hp_corn_1.Float("learning_rate", min_value=1e-4, max_value=1e-1, sampling="log")
hp_corn_1.Choice("batch_size", [16, 32, 64, 128, 256, 512, 1024])

tuner_corn_1 = kt.Hyperband(
hypermodel = CornHyperModel(),
hyperparameters = hp_corn_1,
tune_new_entries = False,
objective = kt.Objective("mean_absolute_error_labels", "min"),
directory = "Tuners/Corn_Tuner_1",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Corn_Tuner_1\Search_1\tuner0.json

# %%
tuner_corn_1.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}

# %%
# tuner_corn_1.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_corn_1.results_summary()
# Out:
# Results summary
# Results in Tuners/Corn_Tuner_1\Search_1
# Showing 10 best trials
# Objective(name="mean_absolute_error_labels", direction="min")
#
# Trial 0208 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0204
# Score: 1.494624376296997
#
# Trial 0204 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0198
# Score: 1.5036402940750122
#
# Trial 0146 summary
# Hyperparameters:
# learning_rate: 0.00683801702224548
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0142
# Score: 1.51447594165802
#
# Trial 0245 summary
# Hyperparameters:
# learning_rate: 0.030889743851785296
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0241
# Score: 1.5154345035552979
#
# Trial 0209 summary
# Hyperparameters:
# learning_rate: 0.012435697835677923
# batch_size: 512
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0203
# Score: 1.5160211324691772
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.0430822173317454
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0143
# Score: 1.5168932676315308
#
# Trial 0203 summary
# Hyperparameters:
# learning_rate: 0.012435697835677923
# batch_size: 512
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0189
# Score: 1.5177849531173706
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.004655643424928699
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0231
# Score: 1.5183358192443848
#
# Trial 0235 summary
# Hyperparameters:
# learning_rate: 0.0012366265065771383
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0233
# Score: 1.5190645456314087
#
# Trial 0246 summary
# Hyperparameters:
# learning_rate: 0.015816941776291463
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# hidden_layers: 2
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# units_1: 16
# units_2: 16
# tuner/trial_id: 0238
# Score: 1.5190823078155518

# %%
# Get and display the optimal hyperparameters of first search
hyps_corn_1 = tuner_corn_1.get_best_hyperparameters(num_trials=1)[0]
print(hyps_corn_1.values)
# Out:
# {'learning_rate': 0.08589776192716679, 'batch_size': 1024, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 3, 'tuner/round': 3, 'hidden_layers': 2, 'batch_norm': True, 'dropout': False, 'dropout_rate': 0.2, 'units_1': 16, 'units_2': 16, 'tuner/trial_id': '0204'}

# %%
hp_corn_2 = kt.HyperParameters()

# Fix

hp_corn_2.Fixed("learning_rate", value = hyps_corn_1["learning_rate"])
hp_corn_2.Fixed("batch_size", value = hyps_corn_1["batch_size"])
hp_corn_2.Fixed("batch_norm", value = True)
hp_corn_2.Fixed("dropout", value = False)
hp_corn_2.Fixed("dropout_rate", value = 0.2)

tuner_corn_2 = kt.Hyperband(
CornHyperModel(),
hyperparameters = hp_corn_2,
tune_new_entries = True,
objective = kt.Objective("val_mean_absolute_error_labels", "min"),
directory = "Tuners/Corn_Tuner_2",
project_name = "Search_1",
seed = 5,
)
# Out:
# Reloading Tuner from Tuners/Corn_Tuner_2\Search_1\tuner0.json

# %%
tuner_corn_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# learning_rate (Fixed)
# {'conditions': [], 'value': 0.08589776192716679}
# batch_size (Fixed)
# {'conditions': [], 'value': 1024}
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# dropout (Fixed)
# {'conditions': [], 'value': False}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.2}
# hidden_layers (Int)
# {'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
# tuner_corn_2.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])

# %%
tuner_corn_2.results_summary()
# Out:
# Results summary
# Results in Tuners/Corn_Tuner_2\Search_1
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0234 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 4
# units_1: 112
# units_2: 112
# units_3: 112
# units_4: 48
# units_5: 80
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0229
# Score: 1.4245988130569458
#
# Trial 0238 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 48
# units_2: 48
# units_3: 48
# units_4: 80
# units_5: 80
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 1.4344884157180786
#
# Trial 0203 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 3
# units_1: 48
# units_2: 80
# units_3: 48
# units_4: 80
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0192
# Score: 1.4465422630310059
#
# Trial 0192 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 3
# units_1: 48
# units_2: 80
# units_3: 48
# units_4: 80
# units_5: 16
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 0149
# Score: 1.4474406242370605
#
# Trial 0229 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 4
# units_1: 112
# units_2: 112
# units_3: 112
# units_4: 48
# units_5: 80
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0219
# Score: 1.45168936252594
#
# Trial 0205 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 80
# units_3: 16
# units_4: 48
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0199
# Score: 1.4518399238586426
#
# Trial 0147 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 5
# units_1: 16
# units_2: 80
# units_3: 16
# units_4: 48
# units_5: 80
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0145
# Score: 1.4519022703170776
#
# Trial 0246 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 16
# units_3: 112
# units_4: 16
# units_5: 48
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0241
# Score: 1.45289146900177
#
# Trial 0241 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 2
# units_1: 80
# units_2: 16
# units_3: 112
# units_4: 16
# units_5: 48
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 1.4532546997070312
#
# Trial 0233 summary
# Hyperparameters:
# learning_rate: 0.08589776192716679
# batch_size: 1024
# batch_norm: True
# dropout: False
# dropout_rate: 0.2
# hidden_layers: 3
# units_1: 48
# units_2: 16
# units_3: 80
# units_4: 16
# units_5: 16
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0214
# Score: 1.458295464515686

# %%
# Get the optimal model and hyperparameters
hyps_corn_2 = tuner_corn_2.get_best_hyperparameters(num_trials=1)[0]
model_corn_2 = tuner_corn_2.hypermodel.build(hyps_corn_2)
print(hyps_corn_2.values)
# Out:
# {'learning_rate': 0.08589776192716679, 'batch_size': 1024, 'batch_norm': True, 'dropout': False, 'dropout_rate': 0.2, 'hidden_layers': 4, 'units_1': 112, 'units_2': 112, 'units_3': 112, 'units_4': 48, 'units_5': 80, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0229'}

# %% [markdown]
# We observe that the optimized learning rate and batch size hyperparameters of the network with batch normalization have increased. This is consistent with the known effects of batch normalization, as a higher learning rate allows for faster convergence. Now, let's fit and evaluate the model's performance.

# %%
# monitor='loss', patience=20, Epochs: 136
history_model_corn_2 = model_corn_2.fit(x=X_train_L1reg_np, y=y_train, epochs=300, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
# Out:
# Epoch 1/300
# 1114/1114 [==============================] - 4s 2ms/step - loss: 0.1914 - mean_absolute_error_labels: 1.7015 - val_loss: 0.1915 - val_mean_absolute_error_labels: 1.6755
# Epoch 2/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1831 - mean_absolute_error_labels: 1.6202 - val_loss: 0.1805 - val_mean_absolute_error_labels: 1.5153
# Epoch 3/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1808 - mean_absolute_error_labels: 1.6293 - val_loss: 0.1779 - val_mean_absolute_error_labels: 1.7085
# Epoch 4/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1795 - mean_absolute_error_labels: 1.6293 - val_loss: 0.1850 - val_mean_absolute_error_labels: 1.4633
# Epoch 5/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1783 - mean_absolute_error_labels: 1.6111 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5260
# Epoch 6/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1776 - mean_absolute_error_labels: 1.6200 - val_loss: 0.1819 - val_mean_absolute_error_labels: 1.6780
# Epoch 7/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1776 - mean_absolute_error_labels: 1.6165 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5603
# Epoch 8/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1762 - mean_absolute_error_labels: 1.6050 - val_loss: 0.1809 - val_mean_absolute_error_labels: 1.6980
# Epoch 9/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1759 - mean_absolute_error_labels: 1.6150 - val_loss: 0.1769 - val_mean_absolute_error_labels: 1.6321
# Epoch 10/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1760 - mean_absolute_error_labels: 1.6125 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.4558
# Epoch 11/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1751 - mean_absolute_error_labels: 1.6013 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5387
# Epoch 12/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1748 - mean_absolute_error_labels: 1.6115 - val_loss: 0.1774 - val_mean_absolute_error_labels: 1.4870
# Epoch 13/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5869 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.6130
# Epoch 14/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5954 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.6256
# Epoch 15/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5806 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.4950
# Epoch 16/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5889 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6809
# Epoch 17/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5851 - val_loss: 0.1783 - val_mean_absolute_error_labels: 1.4841
# Epoch 18/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5784 - val_loss: 0.1763 - val_mean_absolute_error_labels: 1.6429
# Epoch 19/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1723 - mean_absolute_error_labels: 1.5730 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5517
# Epoch 20/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5646 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5810
# Epoch 21/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1714 - mean_absolute_error_labels: 1.5729 - val_loss: 0.1756 - val_mean_absolute_error_labels: 1.4283
# Epoch 22/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5739 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5137
# Epoch 23/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.5753 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5545
# Epoch 24/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1708 - mean_absolute_error_labels: 1.5691 - val_loss: 0.1780 - val_mean_absolute_error_labels: 1.4578
# Epoch 25/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1705 - mean_absolute_error_labels: 1.5604 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.6026
# Epoch 26/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1702 - mean_absolute_error_labels: 1.5559 - val_loss: 0.1771 - val_mean_absolute_error_labels: 1.5143
# Epoch 27/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1702 - mean_absolute_error_labels: 1.5644 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5011
# Epoch 28/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5633 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.4640
# Epoch 29/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1699 - mean_absolute_error_labels: 1.5601 - val_loss: 0.1866 - val_mean_absolute_error_labels: 1.6801
# Epoch 30/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1697 - mean_absolute_error_labels: 1.5669 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5767
# Epoch 31/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1695 - mean_absolute_error_labels: 1.5498 - val_loss: 0.1750 - val_mean_absolute_error_labels: 1.7004
# Epoch 32/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1698 - mean_absolute_error_labels: 1.5593 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5029
# Epoch 33/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1696 - mean_absolute_error_labels: 1.5552 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5544
# Epoch 34/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5548 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5391
# Epoch 35/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5533 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.6060
# Epoch 36/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1691 - mean_absolute_error_labels: 1.5488 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4500
# Epoch 37/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1685 - mean_absolute_error_labels: 1.5500 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5732
# Epoch 38/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1680 - mean_absolute_error_labels: 1.5482 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.6085
# Epoch 39/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1688 - mean_absolute_error_labels: 1.5464 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.5811
# Epoch 40/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1688 - mean_absolute_error_labels: 1.5490 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.4673
# Epoch 41/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1681 - mean_absolute_error_labels: 1.5653 - val_loss: 0.1749 - val_mean_absolute_error_labels: 1.5498
# Epoch 42/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5551 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5267
# Epoch 43/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5498 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5321
# Epoch 44/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1680 - mean_absolute_error_labels: 1.5551 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5801
# Epoch 45/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5537 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.4655
# Epoch 46/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5384 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.4947
# Epoch 47/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1676 - mean_absolute_error_labels: 1.5475 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5549
# Epoch 48/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5359 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5670
# Epoch 49/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5497 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5791
# Epoch 50/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5368 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.5880
# Epoch 51/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5364 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.5062
# Epoch 52/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5458 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.5264
# Epoch 53/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5475 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5622
# Epoch 54/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1662 - mean_absolute_error_labels: 1.5268 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5188
# Epoch 55/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5457 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.6377
# Epoch 56/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5422 - val_loss: 0.1779 - val_mean_absolute_error_labels: 1.5896
# Epoch 57/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5505 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.5012
# Epoch 58/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5346 - val_loss: 0.1786 - val_mean_absolute_error_labels: 1.6215
# Epoch 59/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5363 - val_loss: 0.1768 - val_mean_absolute_error_labels: 1.4840
# Epoch 60/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1656 - mean_absolute_error_labels: 1.5413 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.6352
# Epoch 61/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5423 - val_loss: 0.1744 - val_mean_absolute_error_labels: 1.5465
# Epoch 62/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5396 - val_loss: 0.1841 - val_mean_absolute_error_labels: 1.4598
# Epoch 63/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5341 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.5366
# Epoch 64/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5260 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.5596
# Epoch 65/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1656 - mean_absolute_error_labels: 1.5342 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.5965
# Epoch 66/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1655 - mean_absolute_error_labels: 1.5360 - val_loss: 0.1764 - val_mean_absolute_error_labels: 1.4496
# Epoch 67/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1654 - mean_absolute_error_labels: 1.5223 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.4770
# Epoch 68/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1650 - mean_absolute_error_labels: 1.5281 - val_loss: 0.1765 - val_mean_absolute_error_labels: 1.5265
# Epoch 69/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5336 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.5266
# Epoch 70/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1644 - mean_absolute_error_labels: 1.5288 - val_loss: 0.1736 - val_mean_absolute_error_labels: 1.5008
# Epoch 71/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1653 - mean_absolute_error_labels: 1.5292 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.5213
# Epoch 72/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1653 - mean_absolute_error_labels: 1.5380 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.4442
# Epoch 73/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1648 - mean_absolute_error_labels: 1.5301 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.6102
# Epoch 74/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1650 - mean_absolute_error_labels: 1.5204 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.4895
# Epoch 75/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1640 - mean_absolute_error_labels: 1.5220 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5228
# Epoch 76/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1651 - mean_absolute_error_labels: 1.5339 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.4198
# Epoch 77/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1646 - mean_absolute_error_labels: 1.5177 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5046
# Epoch 78/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1646 - mean_absolute_error_labels: 1.5246 - val_loss: 0.1859 - val_mean_absolute_error_labels: 1.4506
# Epoch 79/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1644 - mean_absolute_error_labels: 1.5432 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.4325
# Epoch 80/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1646 - mean_absolute_error_labels: 1.5338 - val_loss: 0.1744 - val_mean_absolute_error_labels: 1.5596
# Epoch 81/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1642 - mean_absolute_error_labels: 1.5209 - val_loss: 0.1736 - val_mean_absolute_error_labels: 1.5360
# Epoch 82/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1649 - mean_absolute_error_labels: 1.5338 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.4987
# Epoch 83/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1641 - mean_absolute_error_labels: 1.5269 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5219
# Epoch 84/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1637 - mean_absolute_error_labels: 1.5257 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5218
# Epoch 85/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1646 - mean_absolute_error_labels: 1.5333 - val_loss: 0.1745 - val_mean_absolute_error_labels: 1.5803
# Epoch 86/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1638 - mean_absolute_error_labels: 1.5263 - val_loss: 0.1772 - val_mean_absolute_error_labels: 1.4425
# Epoch 87/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1645 - mean_absolute_error_labels: 1.5318 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.5176
# Epoch 88/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1639 - mean_absolute_error_labels: 1.5156 - val_loss: 0.1760 - val_mean_absolute_error_labels: 1.6384
# Epoch 89/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1633 - mean_absolute_error_labels: 1.5137 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.4928
# Epoch 90/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1637 - mean_absolute_error_labels: 1.5159 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5853
# Epoch 91/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1636 - mean_absolute_error_labels: 1.5263 - val_loss: 0.1790 - val_mean_absolute_error_labels: 1.5285
# Epoch 92/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1635 - mean_absolute_error_labels: 1.5169 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.5142
# Epoch 93/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1633 - mean_absolute_error_labels: 1.5256 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.5426
# Epoch 94/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1640 - mean_absolute_error_labels: 1.5361 - val_loss: 0.1783 - val_mean_absolute_error_labels: 1.4653
# Epoch 95/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1631 - mean_absolute_error_labels: 1.5128 - val_loss: 0.1791 - val_mean_absolute_error_labels: 1.4275
# Epoch 96/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1633 - mean_absolute_error_labels: 1.5102 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.5066
# Epoch 97/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1632 - mean_absolute_error_labels: 1.5095 - val_loss: 0.1822 - val_mean_absolute_error_labels: 1.6589
# Epoch 98/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1634 - mean_absolute_error_labels: 1.5093 - val_loss: 0.1763 - val_mean_absolute_error_labels: 1.5151
# Epoch 99/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1634 - mean_absolute_error_labels: 1.5129 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5311
# Epoch 100/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1633 - mean_absolute_error_labels: 1.5213 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5836
# Epoch 101/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1630 - mean_absolute_error_labels: 1.5324 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.5309
# Epoch 102/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1628 - mean_absolute_error_labels: 1.5241 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5900
# Epoch 103/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1630 - mean_absolute_error_labels: 1.5134 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5174
# Epoch 104/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1634 - mean_absolute_error_labels: 1.5191 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.5523
# Epoch 105/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1627 - mean_absolute_error_labels: 1.5076 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.4567
# Epoch 106/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1630 - mean_absolute_error_labels: 1.5041 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.6067
# Epoch 107/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1625 - mean_absolute_error_labels: 1.5141 - val_loss: 0.1779 - val_mean_absolute_error_labels: 1.5332
# Epoch 108/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1624 - mean_absolute_error_labels: 1.5213 - val_loss: 0.1858 - val_mean_absolute_error_labels: 1.3973
# Epoch 109/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1626 - mean_absolute_error_labels: 1.5122 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5488
# Epoch 110/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1622 - mean_absolute_error_labels: 1.5125 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5525
# Epoch 111/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1627 - mean_absolute_error_labels: 1.5228 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5606
# Epoch 112/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1622 - mean_absolute_error_labels: 1.5134 - val_loss: 0.1804 - val_mean_absolute_error_labels: 1.6476
# Epoch 113/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1627 - mean_absolute_error_labels: 1.5082 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.7029
# Epoch 114/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1627 - mean_absolute_error_labels: 1.5106 - val_loss: 0.1830 - val_mean_absolute_error_labels: 1.5938
# Epoch 115/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1624 - mean_absolute_error_labels: 1.5247 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.4575
# Epoch 116/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1623 - mean_absolute_error_labels: 1.5071 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.6274
# Epoch 117/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1614 - mean_absolute_error_labels: 1.5051 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.6025
# Epoch 118/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1624 - mean_absolute_error_labels: 1.5099 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.6647
# Epoch 119/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1623 - mean_absolute_error_labels: 1.5222 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.4579
# Epoch 120/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1618 - mean_absolute_error_labels: 1.5159 - val_loss: 0.1759 - val_mean_absolute_error_labels: 1.5863
# Epoch 121/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1622 - mean_absolute_error_labels: 1.5252 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.4924
# Epoch 122/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1620 - mean_absolute_error_labels: 1.5050 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5613
# Epoch 123/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1619 - mean_absolute_error_labels: 1.5081 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.6192
# Epoch 124/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1615 - mean_absolute_error_labels: 1.5158 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5510
# Epoch 125/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1616 - mean_absolute_error_labels: 1.5070 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5090
# Epoch 126/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1622 - mean_absolute_error_labels: 1.5204 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.6724
# Epoch 127/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1625 - mean_absolute_error_labels: 1.5160 - val_loss: 0.1751 - val_mean_absolute_error_labels: 1.5640
# Epoch 128/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1619 - mean_absolute_error_labels: 1.5134 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.5260
# Epoch 129/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1616 - mean_absolute_error_labels: 1.5249 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.6328
# Epoch 130/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1618 - mean_absolute_error_labels: 1.5037 - val_loss: 0.1748 - val_mean_absolute_error_labels: 1.5154
# Epoch 131/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1620 - mean_absolute_error_labels: 1.5113 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5533
# Epoch 132/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1617 - mean_absolute_error_labels: 1.5042 - val_loss: 0.1780 - val_mean_absolute_error_labels: 1.5439
# Epoch 133/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1613 - mean_absolute_error_labels: 1.5011 - val_loss: 0.1795 - val_mean_absolute_error_labels: 1.6331
# Epoch 134/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1618 - mean_absolute_error_labels: 1.5212 - val_loss: 0.1759 - val_mean_absolute_error_labels: 1.4971
# Epoch 135/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1609 - mean_absolute_error_labels: 1.5113 - val_loss: 0.1772 - val_mean_absolute_error_labels: 1.5803
# Epoch 136/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1614 - mean_absolute_error_labels: 1.5062 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.4669
# Epoch 137/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1616 - mean_absolute_error_labels: 1.5111 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.4741
# Epoch 138/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1617 - mean_absolute_error_labels: 1.5063 - val_loss: 0.1768 - val_mean_absolute_error_labels: 1.4747
# Epoch 139/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1613 - mean_absolute_error_labels: 1.5085 - val_loss: 0.1747 - val_mean_absolute_error_labels: 1.5326
# Epoch 140/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1611 - mean_absolute_error_labels: 1.4966 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5391
# Epoch 141/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1615 - mean_absolute_error_labels: 1.5047 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.5819
# Epoch 142/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1604 - mean_absolute_error_labels: 1.4921 - val_loss: 0.1797 - val_mean_absolute_error_labels: 1.6023
# Epoch 143/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1610 - mean_absolute_error_labels: 1.5103 - val_loss: 0.1810 - val_mean_absolute_error_labels: 1.6398
# Epoch 144/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1619 - mean_absolute_error_labels: 1.5141 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.5506
# Epoch 145/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1609 - mean_absolute_error_labels: 1.5130 - val_loss: 0.1788 - val_mean_absolute_error_labels: 1.5250
# Epoch 146/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1608 - mean_absolute_error_labels: 1.4954 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5469
# Epoch 147/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1613 - mean_absolute_error_labels: 1.5004 - val_loss: 0.1792 - val_mean_absolute_error_labels: 1.5249
# Epoch 148/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1607 - mean_absolute_error_labels: 1.4986 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.5053
# Epoch 149/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1612 - mean_absolute_error_labels: 1.5072 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5559
# Epoch 150/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1605 - mean_absolute_error_labels: 1.5075 - val_loss: 0.1774 - val_mean_absolute_error_labels: 1.5099
# Epoch 151/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1605 - mean_absolute_error_labels: 1.4894 - val_loss: 0.1786 - val_mean_absolute_error_labels: 1.5488
# Epoch 152/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1610 - mean_absolute_error_labels: 1.5201 - val_loss: 0.1791 - val_mean_absolute_error_labels: 1.6427
# Epoch 153/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1609 - mean_absolute_error_labels: 1.5067 - val_loss: 0.1745 - val_mean_absolute_error_labels: 1.5962
# Epoch 154/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1605 - mean_absolute_error_labels: 1.5095 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.5420
# Epoch 155/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1609 - mean_absolute_error_labels: 1.5061 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.6395
# Epoch 156/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1610 - mean_absolute_error_labels: 1.5267 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5759
# Epoch 157/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1607 - mean_absolute_error_labels: 1.4972 - val_loss: 0.1793 - val_mean_absolute_error_labels: 1.6835
# Epoch 158/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1613 - mean_absolute_error_labels: 1.5062 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.5090
# Epoch 159/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1607 - mean_absolute_error_labels: 1.5037 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5722
# Epoch 160/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.5066 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.5617
# Epoch 161/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1600 - mean_absolute_error_labels: 1.4946 - val_loss: 0.1774 - val_mean_absolute_error_labels: 1.4973
# Epoch 162/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1608 - mean_absolute_error_labels: 1.5110 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.5283
# Epoch 163/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.5066 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.5903
# Epoch 164/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1604 - mean_absolute_error_labels: 1.5098 - val_loss: 0.1808 - val_mean_absolute_error_labels: 1.4947
# Epoch 165/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1605 - mean_absolute_error_labels: 1.4945 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.5648
# Epoch 166/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1611 - mean_absolute_error_labels: 1.4988 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.5577
# Epoch 167/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1598 - mean_absolute_error_labels: 1.5035 - val_loss: 0.1768 - val_mean_absolute_error_labels: 1.5528
# Epoch 168/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.4963 - val_loss: 0.1798 - val_mean_absolute_error_labels: 1.5435
# Epoch 169/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1597 - mean_absolute_error_labels: 1.5026 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.5371
# Epoch 170/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1604 - mean_absolute_error_labels: 1.4953 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.4980
# Epoch 171/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1607 - mean_absolute_error_labels: 1.5161 - val_loss: 0.1762 - val_mean_absolute_error_labels: 1.5087
# Epoch 172/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.5069 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.6606
# Epoch 173/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1604 - mean_absolute_error_labels: 1.5063 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.5358
# Epoch 174/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1604 - mean_absolute_error_labels: 1.5088 - val_loss: 0.1763 - val_mean_absolute_error_labels: 1.5285
# Epoch 175/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1597 - mean_absolute_error_labels: 1.5015 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.5082
# Epoch 176/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1602 - mean_absolute_error_labels: 1.4976 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.4787
# Epoch 177/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.4992 - val_loss: 0.1787 - val_mean_absolute_error_labels: 1.4706
# Epoch 178/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.4881 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.5676
# Epoch 179/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1599 - mean_absolute_error_labels: 1.5071 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.5880
# Epoch 180/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1602 - mean_absolute_error_labels: 1.5093 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.5094
# Epoch 181/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.4993 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.5286
# Epoch 182/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1599 - mean_absolute_error_labels: 1.5016 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.5249
# Epoch 183/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1602 - mean_absolute_error_labels: 1.4950 - val_loss: 0.1785 - val_mean_absolute_error_labels: 1.4576
# Epoch 184/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1592 - mean_absolute_error_labels: 1.4932 - val_loss: 0.1765 - val_mean_absolute_error_labels: 1.5296
# Epoch 185/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.5004 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.5092
# Epoch 186/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1599 - mean_absolute_error_labels: 1.4945 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.5104
# Epoch 187/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1597 - mean_absolute_error_labels: 1.5014 - val_loss: 0.1788 - val_mean_absolute_error_labels: 1.6382
# Epoch 188/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.5130 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.4973
# Epoch 189/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1598 - mean_absolute_error_labels: 1.4959 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.6384
# Epoch 190/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1600 - mean_absolute_error_labels: 1.5029 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.5381
# Epoch 191/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.5122 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.6148
# Epoch 192/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1598 - mean_absolute_error_labels: 1.5193 - val_loss: 0.1834 - val_mean_absolute_error_labels: 1.5461
# Epoch 193/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4956 - val_loss: 0.1840 - val_mean_absolute_error_labels: 1.5260
# Epoch 194/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.4900 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.5688
# Epoch 195/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.5003 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.5007
# Epoch 196/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1596 - mean_absolute_error_labels: 1.4986 - val_loss: 0.1778 - val_mean_absolute_error_labels: 1.5943
# Epoch 197/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1598 - mean_absolute_error_labels: 1.5051 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.5181
# Epoch 198/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1596 - mean_absolute_error_labels: 1.4994 - val_loss: 0.1800 - val_mean_absolute_error_labels: 1.6219
# Epoch 199/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1600 - mean_absolute_error_labels: 1.5052 - val_loss: 0.1778 - val_mean_absolute_error_labels: 1.5077
# Epoch 200/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.5049 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5610
# Epoch 201/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.4892 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.5533
# Epoch 202/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4917 - val_loss: 0.1783 - val_mean_absolute_error_labels: 1.5958
# Epoch 203/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.5065 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5223
# Epoch 204/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5025 - val_loss: 0.1797 - val_mean_absolute_error_labels: 1.4748
# Epoch 205/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.4858 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5050
# Epoch 206/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.4934 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.4246
# Epoch 207/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1599 - mean_absolute_error_labels: 1.4930 - val_loss: 0.1837 - val_mean_absolute_error_labels: 1.6325
# Epoch 208/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1592 - mean_absolute_error_labels: 1.5020 - val_loss: 0.1785 - val_mean_absolute_error_labels: 1.4775
# Epoch 209/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4905 - val_loss: 0.1786 - val_mean_absolute_error_labels: 1.5383
# Epoch 210/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.5075 - val_loss: 0.1790 - val_mean_absolute_error_labels: 1.6195
# Epoch 211/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1602 - mean_absolute_error_labels: 1.5046 - val_loss: 0.1796 - val_mean_absolute_error_labels: 1.5171
# Epoch 212/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.5020 - val_loss: 0.1808 - val_mean_absolute_error_labels: 1.5754
# Epoch 213/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4971 - val_loss: 0.1806 - val_mean_absolute_error_labels: 1.7704
# Epoch 214/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1588 - mean_absolute_error_labels: 1.4922 - val_loss: 0.1769 - val_mean_absolute_error_labels: 1.5942
# Epoch 215/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.4951 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.6104
# Epoch 216/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.5104 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.5039
# Epoch 217/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.5017 - val_loss: 0.1791 - val_mean_absolute_error_labels: 1.5528
# Epoch 218/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4976 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.4743
# Epoch 219/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1594 - mean_absolute_error_labels: 1.4974 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.4924
# Epoch 220/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5020 - val_loss: 0.1884 - val_mean_absolute_error_labels: 1.5647
# Epoch 221/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5001 - val_loss: 0.1833 - val_mean_absolute_error_labels: 1.5783
# Epoch 222/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.5105 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5504
# Epoch 223/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5060 - val_loss: 0.1797 - val_mean_absolute_error_labels: 1.5743
# Epoch 224/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.5008 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5277
# Epoch 225/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1588 - mean_absolute_error_labels: 1.4875 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.5293
# Epoch 226/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.5032 - val_loss: 0.1769 - val_mean_absolute_error_labels: 1.5031
# Epoch 227/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5006 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.5551
# Epoch 228/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1597 - mean_absolute_error_labels: 1.4988 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.5268
# Epoch 229/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.4925 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.5479
# Epoch 230/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1587 - mean_absolute_error_labels: 1.4963 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.5565
# Epoch 231/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1588 - mean_absolute_error_labels: 1.4858 - val_loss: 0.1778 - val_mean_absolute_error_labels: 1.6043
# Epoch 232/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.4990 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5052
# Epoch 233/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1593 - mean_absolute_error_labels: 1.5039 - val_loss: 0.1800 - val_mean_absolute_error_labels: 1.5880
# Epoch 234/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.4857 - val_loss: 0.1807 - val_mean_absolute_error_labels: 1.5141
# Epoch 235/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.4791 - val_loss: 0.1797 - val_mean_absolute_error_labels: 1.4826
# Epoch 236/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.4952 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.6724
# Epoch 237/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.4873 - val_loss: 0.1790 - val_mean_absolute_error_labels: 1.5732
# Epoch 238/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1582 - mean_absolute_error_labels: 1.4880 - val_loss: 0.1798 - val_mean_absolute_error_labels: 1.5498
# Epoch 239/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4856 - val_loss: 0.1847 - val_mean_absolute_error_labels: 1.5383
# Epoch 240/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1581 - mean_absolute_error_labels: 1.4937 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.5134
# Epoch 241/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1584 - mean_absolute_error_labels: 1.4811 - val_loss: 0.1863 - val_mean_absolute_error_labels: 1.6630
# Epoch 242/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4860 - val_loss: 0.1792 - val_mean_absolute_error_labels: 1.4958
# Epoch 243/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1592 - mean_absolute_error_labels: 1.5043 - val_loss: 0.1871 - val_mean_absolute_error_labels: 1.6518
# Epoch 244/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1589 - mean_absolute_error_labels: 1.4959 - val_loss: 0.1853 - val_mean_absolute_error_labels: 1.5176
# Epoch 245/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4903 - val_loss: 0.1791 - val_mean_absolute_error_labels: 1.5381
# Epoch 246/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1587 - mean_absolute_error_labels: 1.4976 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.5016
# Epoch 247/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1595 - mean_absolute_error_labels: 1.4966 - val_loss: 0.1774 - val_mean_absolute_error_labels: 1.5378
# Epoch 248/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.5073 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.6094
# Epoch 249/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.4971 - val_loss: 0.1759 - val_mean_absolute_error_labels: 1.4813
# Epoch 250/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1582 - mean_absolute_error_labels: 1.4933 - val_loss: 0.1781 - val_mean_absolute_error_labels: 1.4726
# Epoch 251/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4895 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.4806
# Epoch 252/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1584 - mean_absolute_error_labels: 1.4912 - val_loss: 0.1793 - val_mean_absolute_error_labels: 1.4709
# Epoch 253/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1584 - mean_absolute_error_labels: 1.4877 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5498
# Epoch 254/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1589 - mean_absolute_error_labels: 1.4990 - val_loss: 0.1805 - val_mean_absolute_error_labels: 1.6746
# Epoch 255/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.5085 - val_loss: 0.1780 - val_mean_absolute_error_labels: 1.5073
# Epoch 256/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.4915 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.4690
# Epoch 257/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1588 - mean_absolute_error_labels: 1.5019 - val_loss: 0.1791 - val_mean_absolute_error_labels: 1.5326
# Epoch 258/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4909 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.6473
# Epoch 259/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4979 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.6210
# Epoch 260/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.5195 - val_loss: 0.1794 - val_mean_absolute_error_labels: 1.5582
# Epoch 261/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4956 - val_loss: 0.1806 - val_mean_absolute_error_labels: 1.5263
# Epoch 262/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.5008 - val_loss: 0.1782 - val_mean_absolute_error_labels: 1.5470
# Epoch 263/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4828 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.5558
# Epoch 264/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4879 - val_loss: 0.1851 - val_mean_absolute_error_labels: 1.6734
# Epoch 265/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.4869 - val_loss: 0.1841 - val_mean_absolute_error_labels: 1.5738
# Epoch 266/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4978 - val_loss: 0.1807 - val_mean_absolute_error_labels: 1.5202
# Epoch 267/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1587 - mean_absolute_error_labels: 1.4839 - val_loss: 0.1795 - val_mean_absolute_error_labels: 1.4733
# Epoch 268/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.4935 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.4996
# Epoch 269/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1577 - mean_absolute_error_labels: 1.4852 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.5123
# Epoch 270/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1589 - mean_absolute_error_labels: 1.5012 - val_loss: 0.1778 - val_mean_absolute_error_labels: 1.5433
# Epoch 271/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4955 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.4707
# Epoch 272/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4925 - val_loss: 0.1768 - val_mean_absolute_error_labels: 1.5057
# Epoch 273/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.5040 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.6031
# Epoch 274/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.4979 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.5458
# Epoch 275/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1588 - mean_absolute_error_labels: 1.4954 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.5488
# Epoch 276/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4923 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.6135
# Epoch 277/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4996 - val_loss: 0.1787 - val_mean_absolute_error_labels: 1.5036
# Epoch 278/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1585 - mean_absolute_error_labels: 1.4953 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.5190
# Epoch 279/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4948 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.5286
# Epoch 280/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1581 - mean_absolute_error_labels: 1.4794 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.5290
# Epoch 281/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4969 - val_loss: 0.1762 - val_mean_absolute_error_labels: 1.5172
# Epoch 282/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.5007 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.5357
# Epoch 283/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1582 - mean_absolute_error_labels: 1.4872 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.5765
# Epoch 284/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1574 - mean_absolute_error_labels: 1.4887 - val_loss: 0.1833 - val_mean_absolute_error_labels: 1.4913
# Epoch 285/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.4913 - val_loss: 0.1811 - val_mean_absolute_error_labels: 1.5003
# Epoch 286/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1583 - mean_absolute_error_labels: 1.5044 - val_loss: 0.1792 - val_mean_absolute_error_labels: 1.4946
# Epoch 287/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4881 - val_loss: 0.1843 - val_mean_absolute_error_labels: 1.4408
# Epoch 288/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4886 - val_loss: 0.1802 - val_mean_absolute_error_labels: 1.5202
# Epoch 289/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4991 - val_loss: 0.1828 - val_mean_absolute_error_labels: 1.4599
# Epoch 290/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4834 - val_loss: 0.1839 - val_mean_absolute_error_labels: 1.6030
# Epoch 291/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1587 - mean_absolute_error_labels: 1.4866 - val_loss: 0.1836 - val_mean_absolute_error_labels: 1.4787
# Epoch 292/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.4830 - val_loss: 0.1833 - val_mean_absolute_error_labels: 1.4676
# Epoch 293/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4794 - val_loss: 0.1763 - val_mean_absolute_error_labels: 1.5275
# Epoch 294/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1577 - mean_absolute_error_labels: 1.4894 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.4694
# Epoch 295/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.4811 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.5032
# Epoch 296/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1574 - mean_absolute_error_labels: 1.4855 - val_loss: 0.1784 - val_mean_absolute_error_labels: 1.4817
# Epoch 297/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4841 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.6289
# Epoch 298/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1575 - mean_absolute_error_labels: 1.4964 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.4882
# Epoch 299/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.4810 - val_loss: 0.1777 - val_mean_absolute_error_labels: 1.5134
# Epoch 300/300
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4934 - val_loss: 0.1783 - val_mean_absolute_error_labels: 1.5520

# %%
# Save training history
model_corn_2.save_weights("Models/model_corn_2/weights.h5")
with open("Models/model_corn_2/trainHistoryDict.pkl", "wb") as file_pi:
    pickle.dump(history_model_corn_2.history, file_pi)

# %%
model_corn_2.load_weights("Models/model_corn_2/weights.h5")

# Load training history
with open("Models/model_corn_2/trainHistoryDict.pkl", "rb") as file_pi:
    history_model_corn_2 = pickle.load(file_pi)

# %%
plt.plot(history_model_corn_2['mean_absolute_error_labels'])
plt.plot(history_model_corn_2['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
ordinal_logits_train = model_corn_2.predict(X_train_L1reg_np)
ordinal_logits_valid = model_corn_2.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
tensor_probs_train = coral.corn_ordinal_softmax(ordinal_logits_train)
tensor_probs_valid = coral.corn_ordinal_softmax(ordinal_logits_valid)

# Obtain labels from probabilities
labels_train = coral.cumprobs_to_label(tensor_probs_train)
labels_valid = coral.cumprobs_to_label(tensor_probs_valid)
# Out:
# 1114/1114 [==============================] - 1s 728us/step
# 372/372 [==============================] - 0s 702us/step

# %%
#In train
# monitor='loss', patience=20, Epochs: 136
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_2 = QuadraticWeightedKappa(y_train, tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_2)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 925us/step - loss: 0.1440 - mean_absolute_error_labels: 1.4737
# [Loss, Mean Absolute Error Labels] : [0.1440013349056244, 1.4736964702606201]
# Quadratic Weighted Kappa on training set: 0.57709783

# %%
#In validation
# monitor='loss', patience=20, Epochs: 136

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_2 = QuadraticWeightedKappa(y_valid, tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 911us/step - loss: 0.1783 - mean_absolute_error_labels: 1.5520
# [Loss, Mean Absolute Error Labels] : [0.1782803237438202, 1.5519993305206299]
# Quadratic Weighted Kappa on validation set: 0.48942423

# %%
baseline = 0.67938
model_corn_2_bias = baseline-qwk_train_model_corn_2
model_corn_2_var = qwk_train_model_corn_2-qwk_valid_model_corn_2
print("Bias / Variance of the model: ")
print(round(model_corn_2_bias,3),"/",round(model_corn_2_var,3))
# Out:
# Bias / Variance of the model:
# 0.102 / 0.088

# %%
# monitor='loss', patience=20, Epochs: 300
history_model_corn_2 = model_corn_2.fit(x=X_train_L1reg_np, y=y_train, epochs=100, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
#with open('Models/model_corn_only_2/trainHistoryDict', 'wb') as file_pi:
#    pickle.dump(history_model_corn_only_2.history, file_pi)
# Out:
# Epoch 1/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4851 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5269
# Epoch 2/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4947 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.5305
# Epoch 3/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4849 - val_loss: 0.1782 - val_mean_absolute_error_labels: 1.5964
# Epoch 4/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.4947 - val_loss: 0.1828 - val_mean_absolute_error_labels: 1.4709
# Epoch 5/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1568 - mean_absolute_error_labels: 1.4846 - val_loss: 0.1880 - val_mean_absolute_error_labels: 1.4764
# Epoch 6/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4982 - val_loss: 0.1849 - val_mean_absolute_error_labels: 1.6365
# Epoch 7/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4952 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.5380
# Epoch 8/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1574 - mean_absolute_error_labels: 1.4829 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5662
# Epoch 9/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.5028 - val_loss: 0.1795 - val_mean_absolute_error_labels: 1.5309
# Epoch 10/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4925 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5040
# Epoch 11/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1577 - mean_absolute_error_labels: 1.4881 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.4786
# Epoch 12/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4999 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.4929
# Epoch 13/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1566 - mean_absolute_error_labels: 1.4756 - val_loss: 0.1807 - val_mean_absolute_error_labels: 1.5255
# Epoch 14/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1574 - mean_absolute_error_labels: 1.4894 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5221
# Epoch 15/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4786 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.5342
# Epoch 16/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4869 - val_loss: 0.1874 - val_mean_absolute_error_labels: 1.5837
# Epoch 17/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1572 - mean_absolute_error_labels: 1.4791 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.5263
# Epoch 18/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1569 - mean_absolute_error_labels: 1.4827 - val_loss: 0.1848 - val_mean_absolute_error_labels: 1.6100
# Epoch 19/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.4856 - val_loss: 0.1807 - val_mean_absolute_error_labels: 1.5223
# Epoch 20/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.4778 - val_loss: 0.1810 - val_mean_absolute_error_labels: 1.5060
# Epoch 21/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1575 - mean_absolute_error_labels: 1.5078 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.4575
# Epoch 22/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1580 - mean_absolute_error_labels: 1.4964 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.4901
# Epoch 23/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.4918 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.5007
# Epoch 24/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.4729 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.4853
# Epoch 25/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1568 - mean_absolute_error_labels: 1.4861 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.6127
# Epoch 26/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.4926 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.5071
# Epoch 27/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1567 - mean_absolute_error_labels: 1.4754 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.5471
# Epoch 28/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.4965 - val_loss: 0.1809 - val_mean_absolute_error_labels: 1.5241
# Epoch 29/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1574 - mean_absolute_error_labels: 1.4945 - val_loss: 0.1943 - val_mean_absolute_error_labels: 1.6389
# Epoch 30/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.4851 - val_loss: 0.1780 - val_mean_absolute_error_labels: 1.5744
# Epoch 31/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1572 - mean_absolute_error_labels: 1.4764 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.6603
# Epoch 32/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.4849 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.5342
# Epoch 33/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.4819 - val_loss: 0.1785 - val_mean_absolute_error_labels: 1.5244

# %%
# Save training history
model_corn_2.save_weights("Models/model_corn_2/weights_search2.h5")
with open("Models/model_corn_2/trainHistoryDict_search2.pkl", "wb") as file_pi:
    pickle.dump(history_model_corn_2.history, file_pi)

# %%
model_corn_2.load_weights("Models/model_corn_2/weights_search2.h5")

# Load training history
with open("Models/model_corn_2/trainHistoryDict_search2.pkl", "rb") as file_pi:
    history_model_corn_2 = pickle.load(file_pi)

# %%
plt.plot(history_model_corn_2['mean_absolute_error_labels'])
plt.plot(history_model_corn_2['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
ordinal_logits_train = model_corn_2.predict(X_train_L1reg_np)
ordinal_logits_valid = model_corn_2.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
tensor_probs_train = coral.corn_ordinal_softmax(ordinal_logits_train)
tensor_probs_valid = coral.corn_ordinal_softmax(ordinal_logits_valid)

# Obtain labels from probabilities
labels_train = coral.cumprobs_to_label(tensor_probs_train)
labels_valid = coral.cumprobs_to_label(tensor_probs_valid)
# Out:
# 1114/1114 [==============================] - 1s 783us/step
# 372/372 [==============================] - 0s 809us/step

# %%
#In train
# monitor='loss', patience=20, Epochs: 136
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_2.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_2 = QuadraticWeightedKappa(y_train, tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_2)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 919us/step - loss: 0.1466 - mean_absolute_error_labels: 1.4457
# [Loss, Mean Absolute Error Labels] : [0.1465744525194168, 1.4457472562789917]
# Quadratic Weighted Kappa on training set: 0.532285

# %%
#In validation
# monitor='loss', patience=20, Epochs: 136

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_2 = QuadraticWeightedKappa(y_valid, tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 929us/step - loss: 0.1807 - mean_absolute_error_labels: 1.5255
# [Loss, Mean Absolute Error Labels] : [0.18073111772537231, 1.5254536867141724]
# Quadratic Weighted Kappa on validation set: 0.4596336

# %%
baseline = 0.67938
model_corn_2_bias = baseline-qwk_train_model_corn_2
model_corn_2_var = qwk_train_model_corn_2-qwk_valid_model_corn_2
print("Bias / Variance of the model: ")
print(round(model_corn_2_bias,3),"/",round(model_corn_2_var,3))
# Out:
# Bias / Variance of the model:
# 0.147 / 0.073

# %% [markdown]
# The CORN multilayer perceptron with batch normalization layers showed significant improvement on the training set. However, it still presents significant variance. To address this, we will add dropout layers to the model, starting with a dropout rate of 0.2 and adjusting it as needed. Since we can see graphically that this model cam have a better performance on the validation set using early stopping, we will select it to test that later.
#
# ### CORN + Batch Normalization + 0.2 Dropout
#
# Since dropout layers can affect optimal learning rates and mini-batch sizes, we will tune them accordingly. Additionally, we will increase the network's size in proportion to the dropout rate, following recommendations from [(#)].

# %%
hp_corn_do = kt.HyperParameters()

# Fix

hp_corn_do.Fixed("batch_norm", value = True)
hp_corn_do.Fixed("hidden_layers", value = hyps_corn_2["hidden_layers"])
for i in range(hyps_corn_2["hidden_layers"]):
    hp_corn_do.Fixed("units_"+str(i+1),  value = int(hyps_corn_2["units_"+str(i+1)]/0.8))
hp_corn_do.Fixed("dropout", value = True)
hp_corn_do.Fixed("dropout_rate", value = 0.2)


tuner_corn_do_02 = kt.Hyperband(
CornHyperModel(),
hyperparameters = hp_corn_do,
tune_new_entries = True,
objective = kt.Objective("val_mean_absolute_error_labels", "min"), 
directory = "Tuners/Corn_Do_Tuner",
project_name = "DO_0.2",
seed = 5,
)
# Out:
# Reloading Tuner from Corn_Do_Tuner\DO_0.2\tuner0.json

# %%
tuner_corn_do_02.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# hidden_layers (Fixed)
# {'conditions': [], 'value': 5}
# units_1 (Fixed)
# {'conditions': [], 'value': 140}
# units_2 (Fixed)
# {'conditions': [], 'value': 140}
# units_3 (Fixed)
# {'conditions': [], 'value': 140}
# units_4 (Fixed)
# {'conditions': [], 'value': 20}
# units_5 (Fixed)
# {'conditions': [], 'value': 140}
# dropout (Fixed)
# {'conditions': [], 'value': True}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.2}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 32, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}

# %%
tuner_corn_do_02.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)])

# %%
tuner_corn_do_02.results_summary()
# Out:
# Results summary
# Results in Corn_Do_Tuner\DO_0.2
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0253 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.0862237597677526
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.4072712659835815
#
# Trial 0146 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.056639330364712887
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0143
# Score: 1.4168548583984375
#
# Trial 0235 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.07233914158355592
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0228
# Score: 1.4246575832366943
#
# Trial 0156 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.005116797900233467
# batch_size: 64
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.4279699325561523
#
# Trial 0246 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.04782793101066708
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0241
# Score: 1.4376670122146606
#
# Trial 0179 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.0027236569910991755
# batch_size: 512
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.4477896690368652
#
# Trial 0155 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.006671558563163474
# batch_size: 512
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.4517675638198853
#
# Trial 0143 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.056639330364712887
# batch_size: 128
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0134
# Score: 1.4547781944274902
#
# Trial 0208 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.01442914665091062
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0206
# Score: 1.4550503492355347
#
# Trial 0213 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 140
# units_2: 140
# units_3: 140
# units_4: 20
# units_5: 140
# dropout: True
# dropout_rate: 0.2
# learning_rate: 0.07233914158355592
# batch_size: 256
# tuner/epochs: 12
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 1.4572772979736328

# %%
# Get the optimal hyperparameters
hyps_corn_do_02 = tuner_corn_do_02.get_best_hyperparameters(num_trials=1)[0]
model_corn_do_02 = tuner_corn_do_02.hypermodel.build(hyps_corn_do_02)

print(hyps_corn_do_02.values)
# Out:
# {'batch_norm': True, 'hidden_layers': 5, 'units_1': 140, 'units_2': 140, 'units_3': 140, 'units_4': 20, 'units_5': 140, 'dropout': True, 'dropout_rate': 0.2, 'learning_rate': 0.0862237597677526, 'batch_size': 1024, 'tuner/epochs': 100, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}

# %% [markdown]
# We can observe changes in the optimal learning rate and batch size hyperparameters compared to the same model without dropout regularization. Now, we will fit and evaluate the model's performance on the training and validation sets.

# %%
# monitor='loss', patience=20, Epochs=150
history_model_corn_do_02=model_corn_do_02.fit(x=X_train_L1reg_np, y=y_train, epochs=300, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
# Out:
# Epoch 1/300
# 1114/1114 [==============================] - 6s 3ms/step - loss: 0.2065 - mean_absolute_error_labels: 1.9012 - val_loss: 0.1921 - val_mean_absolute_error_labels: 1.6935
# Epoch 2/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1990 - mean_absolute_error_labels: 1.8247 - val_loss: 0.1903 - val_mean_absolute_error_labels: 1.5512
# Epoch 3/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1977 - mean_absolute_error_labels: 1.8243 - val_loss: 0.1914 - val_mean_absolute_error_labels: 1.7334
# Epoch 4/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1971 - mean_absolute_error_labels: 1.8106 - val_loss: 0.1873 - val_mean_absolute_error_labels: 1.5550
# Epoch 5/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1965 - mean_absolute_error_labels: 1.8035 - val_loss: 0.1859 - val_mean_absolute_error_labels: 1.6134
# Epoch 6/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1963 - mean_absolute_error_labels: 1.8135 - val_loss: 0.1893 - val_mean_absolute_error_labels: 1.7828
# Epoch 7/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1958 - mean_absolute_error_labels: 1.8083 - val_loss: 0.1900 - val_mean_absolute_error_labels: 1.7775
# Epoch 8/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1951 - mean_absolute_error_labels: 1.8271 - val_loss: 0.1876 - val_mean_absolute_error_labels: 1.7862
# Epoch 9/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1955 - mean_absolute_error_labels: 1.8170 - val_loss: 0.1867 - val_mean_absolute_error_labels: 1.8711
# Epoch 10/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1956 - mean_absolute_error_labels: 1.8218 - val_loss: 0.1840 - val_mean_absolute_error_labels: 1.6838
# Epoch 11/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1954 - mean_absolute_error_labels: 1.8014 - val_loss: 0.1848 - val_mean_absolute_error_labels: 1.5325
# Epoch 12/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1947 - mean_absolute_error_labels: 1.7865 - val_loss: 0.1883 - val_mean_absolute_error_labels: 1.6857
# Epoch 13/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1946 - mean_absolute_error_labels: 1.8041 - val_loss: 0.1869 - val_mean_absolute_error_labels: 1.7654
# Epoch 14/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1946 - mean_absolute_error_labels: 1.7939 - val_loss: 0.1860 - val_mean_absolute_error_labels: 1.6658
# Epoch 15/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1935 - mean_absolute_error_labels: 1.7965 - val_loss: 0.1839 - val_mean_absolute_error_labels: 1.6237
# Epoch 16/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1940 - mean_absolute_error_labels: 1.7871 - val_loss: 0.1937 - val_mean_absolute_error_labels: 1.8515
# Epoch 17/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1939 - mean_absolute_error_labels: 1.7940 - val_loss: 0.1885 - val_mean_absolute_error_labels: 1.6755
# Epoch 18/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1935 - mean_absolute_error_labels: 1.7882 - val_loss: 0.1874 - val_mean_absolute_error_labels: 1.7047
# Epoch 19/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1938 - mean_absolute_error_labels: 1.7880 - val_loss: 0.1901 - val_mean_absolute_error_labels: 1.5387
# Epoch 20/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1932 - mean_absolute_error_labels: 1.7893 - val_loss: 0.1841 - val_mean_absolute_error_labels: 1.6886
# Epoch 21/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1931 - mean_absolute_error_labels: 1.7700 - val_loss: 0.1841 - val_mean_absolute_error_labels: 1.5799
# Epoch 22/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1933 - mean_absolute_error_labels: 1.7585 - val_loss: 0.1843 - val_mean_absolute_error_labels: 1.5723
# Epoch 23/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1930 - mean_absolute_error_labels: 1.7798 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6520
# Epoch 24/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1925 - mean_absolute_error_labels: 1.7596 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.5726
# Epoch 25/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1929 - mean_absolute_error_labels: 1.7742 - val_loss: 0.1929 - val_mean_absolute_error_labels: 1.7762
# Epoch 26/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1928 - mean_absolute_error_labels: 1.7744 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.5562
# Epoch 27/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1923 - mean_absolute_error_labels: 1.7499 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.6363
# Epoch 28/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1929 - mean_absolute_error_labels: 1.7634 - val_loss: 0.1822 - val_mean_absolute_error_labels: 1.5754
# Epoch 29/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1927 - mean_absolute_error_labels: 1.7534 - val_loss: 0.1877 - val_mean_absolute_error_labels: 1.7566
# Epoch 30/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1920 - mean_absolute_error_labels: 1.7694 - val_loss: 0.1893 - val_mean_absolute_error_labels: 1.7907
# Epoch 31/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1921 - mean_absolute_error_labels: 1.7466 - val_loss: 0.1909 - val_mean_absolute_error_labels: 1.9947
# Epoch 32/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1926 - mean_absolute_error_labels: 1.7695 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.5523
# Epoch 33/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1923 - mean_absolute_error_labels: 1.7629 - val_loss: 0.1848 - val_mean_absolute_error_labels: 1.7228
# Epoch 34/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1924 - mean_absolute_error_labels: 1.7718 - val_loss: 0.1819 - val_mean_absolute_error_labels: 1.7076
# Epoch 35/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1921 - mean_absolute_error_labels: 1.7531 - val_loss: 0.1807 - val_mean_absolute_error_labels: 1.5768
# Epoch 36/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1919 - mean_absolute_error_labels: 1.7617 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.5522
# Epoch 37/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1912 - mean_absolute_error_labels: 1.7530 - val_loss: 0.1837 - val_mean_absolute_error_labels: 1.7320
# Epoch 38/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1913 - mean_absolute_error_labels: 1.7403 - val_loss: 0.1847 - val_mean_absolute_error_labels: 1.6614
# Epoch 39/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1922 - mean_absolute_error_labels: 1.7510 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.6776
# Epoch 40/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1920 - mean_absolute_error_labels: 1.7565 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.5621
# Epoch 41/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1920 - mean_absolute_error_labels: 1.7389 - val_loss: 0.1868 - val_mean_absolute_error_labels: 1.7639
# Epoch 42/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1919 - mean_absolute_error_labels: 1.7350 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6347
# Epoch 43/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1914 - mean_absolute_error_labels: 1.7488 - val_loss: 0.1844 - val_mean_absolute_error_labels: 1.7524
# Epoch 44/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1920 - mean_absolute_error_labels: 1.7465 - val_loss: 0.1866 - val_mean_absolute_error_labels: 1.7760
# Epoch 45/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1914 - mean_absolute_error_labels: 1.7461 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.5197
# Epoch 46/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1915 - mean_absolute_error_labels: 1.7350 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.6852
# Epoch 47/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1910 - mean_absolute_error_labels: 1.7319 - val_loss: 0.1834 - val_mean_absolute_error_labels: 1.6168
# Epoch 48/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1911 - mean_absolute_error_labels: 1.7385 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.6282
# Epoch 49/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1920 - mean_absolute_error_labels: 1.7499 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.7205
# Epoch 50/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1911 - mean_absolute_error_labels: 1.7472 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.7608
# Epoch 51/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1910 - mean_absolute_error_labels: 1.7468 - val_loss: 0.1802 - val_mean_absolute_error_labels: 1.6098
# Epoch 52/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1910 - mean_absolute_error_labels: 1.7218 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.5394
# Epoch 53/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1909 - mean_absolute_error_labels: 1.7453 - val_loss: 0.1819 - val_mean_absolute_error_labels: 1.7120
# Epoch 54/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7287 - val_loss: 0.1856 - val_mean_absolute_error_labels: 1.7860
# Epoch 55/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1906 - mean_absolute_error_labels: 1.7180 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6720
# Epoch 56/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1911 - mean_absolute_error_labels: 1.7316 - val_loss: 0.1854 - val_mean_absolute_error_labels: 1.5634
# Epoch 57/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1910 - mean_absolute_error_labels: 1.7415 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.6337
# Epoch 58/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1908 - mean_absolute_error_labels: 1.7304 - val_loss: 0.1869 - val_mean_absolute_error_labels: 1.7365
# Epoch 59/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1913 - mean_absolute_error_labels: 1.7366 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.5298
# Epoch 60/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7237 - val_loss: 0.1862 - val_mean_absolute_error_labels: 1.6995
# Epoch 61/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7269 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5865
# Epoch 62/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1912 - mean_absolute_error_labels: 1.7279 - val_loss: 0.1898 - val_mean_absolute_error_labels: 1.5770
# Epoch 63/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7377 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.6430
# Epoch 64/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7250 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6569
# Epoch 65/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1906 - mean_absolute_error_labels: 1.7324 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.5913
# Epoch 66/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1902 - mean_absolute_error_labels: 1.7210 - val_loss: 0.1870 - val_mean_absolute_error_labels: 1.5455
# Epoch 67/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1900 - mean_absolute_error_labels: 1.7223 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.5553
# Epoch 68/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1898 - mean_absolute_error_labels: 1.7136 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.5511
# Epoch 69/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1908 - mean_absolute_error_labels: 1.7266 - val_loss: 0.1849 - val_mean_absolute_error_labels: 1.7039
# Epoch 70/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7308 - val_loss: 0.1840 - val_mean_absolute_error_labels: 1.5424
# Epoch 71/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7271 - val_loss: 0.1858 - val_mean_absolute_error_labels: 1.7093
# Epoch 72/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1905 - mean_absolute_error_labels: 1.7277 - val_loss: 0.1910 - val_mean_absolute_error_labels: 1.5596
# Epoch 73/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7173 - val_loss: 0.1852 - val_mean_absolute_error_labels: 1.7181
# Epoch 74/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7436 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.6134
# Epoch 75/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1900 - mean_absolute_error_labels: 1.7212 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.6648
# Epoch 76/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1904 - mean_absolute_error_labels: 1.7354 - val_loss: 0.1900 - val_mean_absolute_error_labels: 1.4977
# Epoch 77/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1908 - mean_absolute_error_labels: 1.7343 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.5932
# Epoch 78/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1898 - mean_absolute_error_labels: 1.7179 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.5824
# Epoch 79/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7375 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.5181
# Epoch 80/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7322 - val_loss: 0.1852 - val_mean_absolute_error_labels: 1.6917
# Epoch 81/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1905 - mean_absolute_error_labels: 1.7354 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.6711
# Epoch 82/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1904 - mean_absolute_error_labels: 1.7280 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.6557
# Epoch 83/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1902 - mean_absolute_error_labels: 1.7257 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.6396
# Epoch 84/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1899 - mean_absolute_error_labels: 1.7196 - val_loss: 0.1863 - val_mean_absolute_error_labels: 1.7510
# Epoch 85/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1898 - mean_absolute_error_labels: 1.7150 - val_loss: 0.1842 - val_mean_absolute_error_labels: 1.6768
# Epoch 86/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7333 - val_loss: 0.1793 - val_mean_absolute_error_labels: 1.5639
# Epoch 87/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1900 - mean_absolute_error_labels: 1.7230 - val_loss: 0.1810 - val_mean_absolute_error_labels: 1.6208
# Epoch 88/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7192 - val_loss: 0.1808 - val_mean_absolute_error_labels: 1.6463
# Epoch 89/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1904 - mean_absolute_error_labels: 1.7322 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.6290
# Epoch 90/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7224 - val_loss: 0.1846 - val_mean_absolute_error_labels: 1.6039
# Epoch 91/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1905 - mean_absolute_error_labels: 1.7181 - val_loss: 0.1849 - val_mean_absolute_error_labels: 1.7189
# Epoch 92/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1902 - mean_absolute_error_labels: 1.7174 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.6568
# Epoch 93/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1900 - mean_absolute_error_labels: 1.7244 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.5965
# Epoch 94/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7183 - val_loss: 0.1892 - val_mean_absolute_error_labels: 1.4763
# Epoch 95/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7111 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.5346
# Epoch 96/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1901 - mean_absolute_error_labels: 1.7300 - val_loss: 0.1890 - val_mean_absolute_error_labels: 1.7241
# Epoch 97/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7097 - val_loss: 0.1858 - val_mean_absolute_error_labels: 1.7022
# Epoch 98/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1901 - mean_absolute_error_labels: 1.7190 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.6422
# Epoch 99/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7251 - val_loss: 0.1838 - val_mean_absolute_error_labels: 1.6826
# Epoch 100/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1898 - mean_absolute_error_labels: 1.7283 - val_loss: 0.1849 - val_mean_absolute_error_labels: 1.7516
# Epoch 101/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1894 - mean_absolute_error_labels: 1.7245 - val_loss: 0.1833 - val_mean_absolute_error_labels: 1.7231
# Epoch 102/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1907 - mean_absolute_error_labels: 1.7254 - val_loss: 0.1896 - val_mean_absolute_error_labels: 1.6880
# Epoch 103/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7191 - val_loss: 0.1839 - val_mean_absolute_error_labels: 1.6459
# Epoch 104/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1902 - mean_absolute_error_labels: 1.7217 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6489
# Epoch 105/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1903 - mean_absolute_error_labels: 1.7258 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.5777
# Epoch 106/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1901 - mean_absolute_error_labels: 1.7220 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.6928
# Epoch 107/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7191 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.5351
# Epoch 108/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1897 - mean_absolute_error_labels: 1.7027 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.5344
# Epoch 109/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7188 - val_loss: 0.1828 - val_mean_absolute_error_labels: 1.6531
# Epoch 110/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1894 - mean_absolute_error_labels: 1.7149 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.6865
# Epoch 111/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1901 - mean_absolute_error_labels: 1.7203 - val_loss: 0.1828 - val_mean_absolute_error_labels: 1.6952
# Epoch 112/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.7048 - val_loss: 0.1885 - val_mean_absolute_error_labels: 1.8409
# Epoch 113/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7019 - val_loss: 0.1859 - val_mean_absolute_error_labels: 1.7638
# Epoch 114/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1899 - mean_absolute_error_labels: 1.7254 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6592
# Epoch 115/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7160 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.5780
# Epoch 116/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1894 - mean_absolute_error_labels: 1.7053 - val_loss: 0.1867 - val_mean_absolute_error_labels: 1.7394
# Epoch 117/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1894 - mean_absolute_error_labels: 1.7037 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.6163
# Epoch 118/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7100 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.5928
# Epoch 119/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1900 - mean_absolute_error_labels: 1.7074 - val_loss: 0.1843 - val_mean_absolute_error_labels: 1.5506
# Epoch 120/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7129 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.7203
# Epoch 121/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7234 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.5934
# Epoch 122/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7187 - val_loss: 0.1844 - val_mean_absolute_error_labels: 1.7422
# Epoch 123/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.6989 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6808
# Epoch 124/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.7000 - val_loss: 0.1808 - val_mean_absolute_error_labels: 1.5738
# Epoch 125/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.7029 - val_loss: 0.1882 - val_mean_absolute_error_labels: 1.6436
# Epoch 126/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7113 - val_loss: 0.1898 - val_mean_absolute_error_labels: 1.7786
# Epoch 127/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.7172 - val_loss: 0.1837 - val_mean_absolute_error_labels: 1.6521
# Epoch 128/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.7063 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5827
# Epoch 129/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7153 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.6398
# Epoch 130/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1897 - mean_absolute_error_labels: 1.7006 - val_loss: 0.1830 - val_mean_absolute_error_labels: 1.6581
# Epoch 131/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1894 - mean_absolute_error_labels: 1.7190 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.6233
# Epoch 132/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1885 - mean_absolute_error_labels: 1.7027 - val_loss: 0.1838 - val_mean_absolute_error_labels: 1.6686
# Epoch 133/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7130 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.6547
# Epoch 134/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.7115 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.5085
# Epoch 135/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.6998 - val_loss: 0.1871 - val_mean_absolute_error_labels: 1.8382
# Epoch 136/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1896 - mean_absolute_error_labels: 1.7202 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.5559
# Epoch 137/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.7150 - val_loss: 0.1830 - val_mean_absolute_error_labels: 1.5443
# Epoch 138/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7117 - val_loss: 0.1841 - val_mean_absolute_error_labels: 1.6420
# Epoch 139/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.7118 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.5202
# Epoch 140/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7047 - val_loss: 0.1819 - val_mean_absolute_error_labels: 1.6455
# Epoch 141/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7198 - val_loss: 0.1842 - val_mean_absolute_error_labels: 1.6050
# Epoch 142/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.7026 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6683
# Epoch 143/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.7077 - val_loss: 0.1872 - val_mean_absolute_error_labels: 1.8074
# Epoch 144/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1897 - mean_absolute_error_labels: 1.7163 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6796
# Epoch 145/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7123 - val_loss: 0.1850 - val_mean_absolute_error_labels: 1.6943
# Epoch 146/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1895 - mean_absolute_error_labels: 1.7110 - val_loss: 0.1804 - val_mean_absolute_error_labels: 1.6618
# Epoch 147/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7081 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6303
# Epoch 148/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.7104 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6011
# Epoch 149/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.6979 - val_loss: 0.1802 - val_mean_absolute_error_labels: 1.6188
# Epoch 150/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.7029 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.6635
# Epoch 151/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7075 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.5529
# Epoch 152/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.6975 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.7263
# Epoch 153/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7065 - val_loss: 0.1850 - val_mean_absolute_error_labels: 1.7249
# Epoch 154/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7056 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.5181
# Epoch 155/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1885 - mean_absolute_error_labels: 1.6995 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.7226
# Epoch 156/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.6910 - val_loss: 0.1879 - val_mean_absolute_error_labels: 1.4807
# Epoch 157/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1892 - mean_absolute_error_labels: 1.7157 - val_loss: 0.1862 - val_mean_absolute_error_labels: 1.6353
# Epoch 158/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1893 - mean_absolute_error_labels: 1.7035 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.5762
# Epoch 159/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.6957 - val_loss: 0.1816 - val_mean_absolute_error_labels: 1.5988
# Epoch 160/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.6866 - val_loss: 0.1845 - val_mean_absolute_error_labels: 1.6443
# Epoch 161/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7173 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.6265
# Epoch 162/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1897 - mean_absolute_error_labels: 1.7282 - val_loss: 0.1810 - val_mean_absolute_error_labels: 1.6290
# Epoch 163/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.7001 - val_loss: 0.1879 - val_mean_absolute_error_labels: 1.7019
# Epoch 164/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.7008 - val_loss: 0.1835 - val_mean_absolute_error_labels: 1.6405
# Epoch 165/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7123 - val_loss: 0.1827 - val_mean_absolute_error_labels: 1.6444
# Epoch 166/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7030 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.6295
# Epoch 167/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7096 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.6802
# Epoch 168/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7026 - val_loss: 0.1805 - val_mean_absolute_error_labels: 1.6519
# Epoch 169/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1882 - mean_absolute_error_labels: 1.6896 - val_loss: 0.1886 - val_mean_absolute_error_labels: 1.6650
# Epoch 170/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7093 - val_loss: 0.1823 - val_mean_absolute_error_labels: 1.6089
# Epoch 171/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7202 - val_loss: 0.1872 - val_mean_absolute_error_labels: 1.6107
# Epoch 172/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.6997 - val_loss: 0.1857 - val_mean_absolute_error_labels: 1.6415
# Epoch 173/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1882 - mean_absolute_error_labels: 1.7051 - val_loss: 0.1873 - val_mean_absolute_error_labels: 1.7469
# Epoch 174/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1884 - mean_absolute_error_labels: 1.6913 - val_loss: 0.1842 - val_mean_absolute_error_labels: 1.5805
# Epoch 175/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.7083 - val_loss: 0.1915 - val_mean_absolute_error_labels: 1.6114
# Epoch 176/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.6984 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.6751
# Epoch 177/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7009 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5819
# Epoch 178/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1882 - mean_absolute_error_labels: 1.6912 - val_loss: 0.1846 - val_mean_absolute_error_labels: 1.6242
# Epoch 179/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.6998 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.6282
# Epoch 180/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.6970 - val_loss: 0.1831 - val_mean_absolute_error_labels: 1.6093
# Epoch 181/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.7025 - val_loss: 0.1808 - val_mean_absolute_error_labels: 1.6187
# Epoch 182/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7034 - val_loss: 0.1836 - val_mean_absolute_error_labels: 1.5591
# Epoch 183/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7084 - val_loss: 0.1842 - val_mean_absolute_error_labels: 1.5360
# Epoch 184/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.6919 - val_loss: 0.1822 - val_mean_absolute_error_labels: 1.5281
# Epoch 185/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1877 - mean_absolute_error_labels: 1.6920 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5822
# Epoch 186/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7026 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.5903
# Epoch 187/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1884 - mean_absolute_error_labels: 1.6948 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.6661
# Epoch 188/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7134 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.6725
# Epoch 189/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.7182 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.6719
# Epoch 190/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1889 - mean_absolute_error_labels: 1.7030 - val_loss: 0.1822 - val_mean_absolute_error_labels: 1.6473
# Epoch 191/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1874 - mean_absolute_error_labels: 1.6872 - val_loss: 0.1803 - val_mean_absolute_error_labels: 1.5892
# Epoch 192/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.6972 - val_loss: 0.1802 - val_mean_absolute_error_labels: 1.5788
# Epoch 193/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1885 - mean_absolute_error_labels: 1.6914 - val_loss: 0.1816 - val_mean_absolute_error_labels: 1.5780
# Epoch 194/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.6981 - val_loss: 0.1829 - val_mean_absolute_error_labels: 1.6863
# Epoch 195/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.7080 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.5398
# Epoch 196/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1878 - mean_absolute_error_labels: 1.6891 - val_loss: 0.1861 - val_mean_absolute_error_labels: 1.7250
# Epoch 197/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.7021 - val_loss: 0.1815 - val_mean_absolute_error_labels: 1.5804
# Epoch 198/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1890 - mean_absolute_error_labels: 1.7182 - val_loss: 0.1868 - val_mean_absolute_error_labels: 1.7707
# Epoch 199/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.7025 - val_loss: 0.1818 - val_mean_absolute_error_labels: 1.6846
# Epoch 200/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7078 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.5811
# Epoch 201/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1882 - mean_absolute_error_labels: 1.6980 - val_loss: 0.1908 - val_mean_absolute_error_labels: 1.7568
# Epoch 202/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1880 - mean_absolute_error_labels: 1.6948 - val_loss: 0.1847 - val_mean_absolute_error_labels: 1.6595
# Epoch 203/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.7001 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6570
# Epoch 204/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.6957 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.5068
# Epoch 205/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1888 - mean_absolute_error_labels: 1.7076 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.5627
# Epoch 206/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.7119 - val_loss: 0.1809 - val_mean_absolute_error_labels: 1.5138
# Epoch 207/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.7007 - val_loss: 0.1867 - val_mean_absolute_error_labels: 1.7291
# Epoch 208/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1883 - mean_absolute_error_labels: 1.6983 - val_loss: 0.1832 - val_mean_absolute_error_labels: 1.5538
# Epoch 209/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.6847 - val_loss: 0.1839 - val_mean_absolute_error_labels: 1.6436
# Epoch 210/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1881 - mean_absolute_error_labels: 1.7043 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.6205
# Epoch 211/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1886 - mean_absolute_error_labels: 1.7132 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.6211

# %%
history_model_corn_do_02=history_model_corn_do_02.history

# %%
plt.plot(history_model_corn_do_02['mean_absolute_error_labels'])
plt.plot(history_model_corn_do_02['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
print("Performance on datasets")

# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
do_ordinal_logits_train_02 = model_corn_do_02.predict(X_train_L1reg_np)
do_ordinal_logits_valid_02 = model_corn_do_02.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
do_tensor_probs_train_02 = coral.corn_ordinal_softmax(do_ordinal_logits_train_02)
do_tensor_probs_valid_02 = coral.corn_ordinal_softmax(do_ordinal_logits_valid_02)

# Convert the tensor into a pandas dataframe.
do_labels_train_02 = coral.cumprobs_to_label(do_tensor_probs_train_02)
do_labels_valid_02 = coral.cumprobs_to_label(do_tensor_probs_valid_02)
# Out:
# Performance on datasets
# 1114/1114 [==============================] - 1s 877us/step
# 372/372 [==============================] - 0s 854us/step

# %%
#In train
# monitor='loss', patience=20, Epochs=150
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_02.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_do_02 = QuadraticWeightedKappa(y_train, do_tensor_probs_train_02).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_do_02)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5548
# [Loss, Mean Absolute Error Labels] : [0.17013007402420044, 1.5547857284545898]
# Quadratic Weighted Kappa on training set: 0.4257272

# %%
#In validation
# monitor='loss', patience=20, Epochs=150
print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_02.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_do_02 = QuadraticWeightedKappa(y_valid, do_tensor_probs_valid_02).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_do_02)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 0.1803 - mean_absolute_error_labels: 1.5892
# [Loss, Mean Absolute Error Labels] : [0.18027986586093903, 1.5892137289047241]
# Quadratic Weighted Kappa on validation set: 0.41253316

# %%
model_corn_do_02_bias = baseline-qwk_train_model_corn_do_02
model_corn_do_02_var = qwk_train_model_corn_do_02-qwk_valid_model_corn_do_02
print("Bias / Variance of the model: ")
print(round(model_corn_do_02_bias,3),"/",round(model_corn_do_02_var,3))
# Out:
# Bias / Variance of the model:
# 0.254 / 0.013

# %% [markdown]
# After observing the regularization effects of the dropout layers, we noticed a larger bias than variance. Therefore, we will try a lower regularizing effect for the model.
#
# ### CORN + BN + 0.1 Dropout
#
# Similar to before, we will tune the learning rates and mini-batch sizes and increase the network's size in proportion to the dropout rate.

# %%
hp_corn_do = kt.HyperParameters()

# Fix
hp_corn_do.Fixed("batch_norm", value = True)
hp_corn_do.Fixed("hidden_layers", value = hyps_corn_2["hidden_layers"])
for i in range(hyps_corn_2["hidden_layers"]):
    hp_corn_do.Fixed("units_"+str(i+1),  value = int(hyps_corn_2["units_"+str(i+1)]/0.9))
hp_corn_do.Fixed("dropout", value = True)
hp_corn_do.Fixed("dropout_rate", value = 0.1)


tuner_corn_do_01 = kt.Hyperband(
CornHyperModel(),
hyperparameters = hp_corn_do,
tune_new_entries = True,
objective = kt.Objective("val_mean_absolute_error_labels", "min"), 
directory = "Tuners/Corn_Do_Tuner",
project_name = "DO_0.1",
seed = 5,
)
# Out:
# Reloading Tuner from Corn_Do_Tuner\DO_0.1\tuner0.json

# %%
tuner_corn_do_01.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# hidden_layers (Fixed)
# {'conditions': [], 'value': 5}
# units_1 (Fixed)
# {'conditions': [], 'value': 124}
# units_2 (Fixed)
# {'conditions': [], 'value': 124}
# units_3 (Fixed)
# {'conditions': [], 'value': 124}
# units_4 (Fixed)
# {'conditions': [], 'value': 17}
# units_5 (Fixed)
# {'conditions': [], 'value': 124}
# dropout (Fixed)
# {'conditions': [], 'value': True}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.1}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# batch_size (Choice)
# {'default': 32, 'conditions': [], 'values': [16, 32, 64, 128, 256, 512, 1024], 'ordered': True}

# %%
tuner_corn_do_01.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)])

# %%
tuner_corn_do_01.results_summary()
# Out:
# Results summary
# Results in Corn_Do_Tuner\DO_0.1
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0147 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.04621726369179639
# batch_size: 64
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0142
# Score: 1.4079020023345947
#
# Trial 0222 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.030567566286461307
# batch_size: 32
# tuner/epochs: 12
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 1.4173387289047241
#
# Trial 0146 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.08369614236184733
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0144
# Score: 1.4212837219238281
#
# Trial 0234 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.07233914158355592
# batch_size: 256
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0229
# Score: 1.4270577430725098
#
# Trial 0246 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.04782793101066708
# batch_size: 1024
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0241
# Score: 1.4349313974380493
#
# Trial 0203 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.03658271153864743
# batch_size: 32
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0196
# Score: 1.434979796409607
#
# Trial 0134 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.04621726369179639
# batch_size: 64
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 4
# tuner/round: 2
# tuner/trial_id: 0105
# Score: 1.4389933347702026
#
# Trial 0144 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.08369614236184733
# batch_size: 128
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0141
# Score: 1.439213752746582
#
# Trial 0209 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.023435289854752822
# batch_size: 128
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0204
# Score: 1.4428023099899292
#
# Trial 0142 summary
# Hyperparameters:
# batch_norm: True
# hidden_layers: 5
# units_1: 124
# units_2: 124
# units_3: 124
# units_4: 17
# units_5: 124
# dropout: True
# dropout_rate: 0.1
# learning_rate: 0.04621726369179639
# batch_size: 64
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0134
# Score: 1.4436417818069458

# %%
# Get the optimal hyperparameters
hyps_corn_do_01 = tuner_corn_do_01.get_best_hyperparameters(num_trials=1)[0]
model_corn_do_01 = tuner_corn_do_01.hypermodel.build(hyps_corn_do_01)
print(hyps_corn_do_01.values)
# Out:
# {'batch_norm': True, 'hidden_layers': 5, 'units_1': 124, 'units_2': 124, 'units_3': 124, 'units_4': 17, 'units_5': 124, 'dropout': True, 'dropout_rate': 0.1, 'learning_rate': 0.04621726369179639, 'batch_size': 64, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 4, 'tuner/round': 4, 'tuner/trial_id': '0142'}

# %%
# monitor='loss', patience=20, Epochs= 118
history_model_corn_do_01=model_corn_do_01.fit(x=X_train_L1reg_np, y=y_train, epochs=300, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
# Out:
# Epoch 1/300
# 1114/1114 [==============================] - 6s 3ms/step - loss: 0.1989 - mean_absolute_error_labels: 1.7964 - val_loss: 0.1882 - val_mean_absolute_error_labels: 1.5490
# Epoch 2/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1887 - mean_absolute_error_labels: 1.6948 - val_loss: 0.1821 - val_mean_absolute_error_labels: 1.5916
# Epoch 3/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1873 - mean_absolute_error_labels: 1.6956 - val_loss: 0.1825 - val_mean_absolute_error_labels: 1.5808
# Epoch 4/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1860 - mean_absolute_error_labels: 1.6835 - val_loss: 0.1839 - val_mean_absolute_error_labels: 1.5998
# Epoch 5/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1852 - mean_absolute_error_labels: 1.6721 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5628
# Epoch 6/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1842 - mean_absolute_error_labels: 1.6831 - val_loss: 0.1842 - val_mean_absolute_error_labels: 1.7294
# Epoch 7/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1834 - mean_absolute_error_labels: 1.6652 - val_loss: 0.1777 - val_mean_absolute_error_labels: 1.5709
# Epoch 8/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1823 - mean_absolute_error_labels: 1.6516 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.6841
# Epoch 9/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1827 - mean_absolute_error_labels: 1.6587 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.6595
# Epoch 10/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1820 - mean_absolute_error_labels: 1.6489 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.4798
# Epoch 11/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1814 - mean_absolute_error_labels: 1.6470 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5468
# Epoch 12/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1811 - mean_absolute_error_labels: 1.6342 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.6071
# Epoch 13/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1800 - mean_absolute_error_labels: 1.6486 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5932
# Epoch 14/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1797 - mean_absolute_error_labels: 1.6459 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5307
# Epoch 15/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1791 - mean_absolute_error_labels: 1.6327 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5361
# Epoch 16/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1793 - mean_absolute_error_labels: 1.6344 - val_loss: 0.1759 - val_mean_absolute_error_labels: 1.6907
# Epoch 17/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6369 - val_loss: 0.1779 - val_mean_absolute_error_labels: 1.5496
# Epoch 18/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1782 - mean_absolute_error_labels: 1.6237 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.6778
# Epoch 19/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1783 - mean_absolute_error_labels: 1.6395 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5580
# Epoch 20/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1779 - mean_absolute_error_labels: 1.6264 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.5467
# Epoch 21/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1777 - mean_absolute_error_labels: 1.6352 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.4934
# Epoch 22/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1779 - mean_absolute_error_labels: 1.6331 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5512
# Epoch 23/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1773 - mean_absolute_error_labels: 1.6293 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.5333
# Epoch 24/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1769 - mean_absolute_error_labels: 1.6201 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.5412
# Epoch 25/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1763 - mean_absolute_error_labels: 1.6199 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5633
# Epoch 26/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1766 - mean_absolute_error_labels: 1.6147 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5410
# Epoch 27/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1765 - mean_absolute_error_labels: 1.6031 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5406
# Epoch 28/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1764 - mean_absolute_error_labels: 1.6075 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5044
# Epoch 29/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1765 - mean_absolute_error_labels: 1.6108 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.6195
# Epoch 30/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1757 - mean_absolute_error_labels: 1.6109 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.6173
# Epoch 31/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1758 - mean_absolute_error_labels: 1.6119 - val_loss: 0.1828 - val_mean_absolute_error_labels: 1.8183
# Epoch 32/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1754 - mean_absolute_error_labels: 1.6161 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5223
# Epoch 33/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.5914 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.6140
# Epoch 34/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1758 - mean_absolute_error_labels: 1.6119 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.6006
# Epoch 35/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.5989 - val_loss: 0.1690 - val_mean_absolute_error_labels: 1.5334
# Epoch 36/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1758 - mean_absolute_error_labels: 1.6158 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.5680
# Epoch 37/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1747 - mean_absolute_error_labels: 1.6096 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.6405
# Epoch 38/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1749 - mean_absolute_error_labels: 1.6115 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5801
# Epoch 39/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1751 - mean_absolute_error_labels: 1.6040 - val_loss: 0.1689 - val_mean_absolute_error_labels: 1.6015
# Epoch 40/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.6223 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.4670
# Epoch 41/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.6082 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.6814
# Epoch 42/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.6088 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5375
# Epoch 43/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1745 - mean_absolute_error_labels: 1.5985 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5282
# Epoch 44/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.6214 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5872
# Epoch 45/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.6041 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5077
# Epoch 46/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.5948 - val_loss: 0.1686 - val_mean_absolute_error_labels: 1.4742
# Epoch 47/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1745 - mean_absolute_error_labels: 1.6018 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.6352
# Epoch 48/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1738 - mean_absolute_error_labels: 1.5921 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.6136
# Epoch 49/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.6192 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5460
# Epoch 50/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.5948 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5074
# Epoch 51/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5878 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.5675
# Epoch 52/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5955 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.4990
# Epoch 53/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5967 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5851
# Epoch 54/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5833 - val_loss: 0.1687 - val_mean_absolute_error_labels: 1.5279
# Epoch 55/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.5775 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.6268
# Epoch 56/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5912 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5827
# Epoch 57/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5861 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5320
# Epoch 58/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5956 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.6918
# Epoch 59/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5970 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5424
# Epoch 60/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5964 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.6482
# Epoch 61/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5981 - val_loss: 0.1679 - val_mean_absolute_error_labels: 1.5336
# Epoch 62/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5859 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5234
# Epoch 63/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1723 - mean_absolute_error_labels: 1.5849 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.6342
# Epoch 64/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5925 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5489
# Epoch 65/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5963 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5323
# Epoch 66/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5931 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.4722
# Epoch 67/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5868 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5466
# Epoch 68/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5678 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.4986
# Epoch 69/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5841 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.7003
# Epoch 70/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5931 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.4554
# Epoch 71/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5845 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5444
# Epoch 72/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5858 - val_loss: 0.1756 - val_mean_absolute_error_labels: 1.4712
# Epoch 73/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5768 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5822
# Epoch 74/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.5876 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5085
# Epoch 75/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.5720 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5848
# Epoch 76/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5787 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.4535
# Epoch 77/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5836 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5167
# Epoch 78/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5750 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5763
# Epoch 79/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5938 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.4399
# Epoch 80/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5800 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5291
# Epoch 81/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5949 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5701
# Epoch 82/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5892 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5029
# Epoch 83/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1709 - mean_absolute_error_labels: 1.5615 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5310
# Epoch 84/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1713 - mean_absolute_error_labels: 1.5824 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5616
# Epoch 85/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5717 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.5348
# Epoch 86/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1713 - mean_absolute_error_labels: 1.5796 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.4514
# Epoch 87/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5815 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5786
# Epoch 88/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.5716 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.6381
# Epoch 89/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1712 - mean_absolute_error_labels: 1.5818 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5932
# Epoch 90/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1714 - mean_absolute_error_labels: 1.5833 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5234
# Epoch 91/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5774 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5685
# Epoch 92/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5738 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.4824
# Epoch 93/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1708 - mean_absolute_error_labels: 1.5782 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5740
# Epoch 94/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5905 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.4780
# Epoch 95/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1708 - mean_absolute_error_labels: 1.5689 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.4622
# Epoch 96/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1713 - mean_absolute_error_labels: 1.5680 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5455
# Epoch 97/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1710 - mean_absolute_error_labels: 1.5753 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.5833
# Epoch 98/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5740 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.6242
# Epoch 99/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1709 - mean_absolute_error_labels: 1.5763 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.4919
# Epoch 100/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1705 - mean_absolute_error_labels: 1.5914 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.6422
# Epoch 101/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5800 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5609
# Epoch 102/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5763 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5255
# Epoch 103/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1702 - mean_absolute_error_labels: 1.5642 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5181
# Epoch 104/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1704 - mean_absolute_error_labels: 1.5690 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.5371
# Epoch 105/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5679 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.4308
# Epoch 106/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1703 - mean_absolute_error_labels: 1.5673 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5862
# Epoch 107/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1704 - mean_absolute_error_labels: 1.5729 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.6204
# Epoch 108/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5672 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.4784
# Epoch 109/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1699 - mean_absolute_error_labels: 1.5662 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5976
# Epoch 110/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1698 - mean_absolute_error_labels: 1.5630 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5370
# Epoch 111/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1700 - mean_absolute_error_labels: 1.5804 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5362
# Epoch 112/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5812 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.6148
# Epoch 113/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1703 - mean_absolute_error_labels: 1.5682 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.6851
# Epoch 114/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1700 - mean_absolute_error_labels: 1.5675 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.5934
# Epoch 115/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5597 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.4751
# Epoch 116/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1695 - mean_absolute_error_labels: 1.5650 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5127
# Epoch 117/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1697 - mean_absolute_error_labels: 1.5641 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5960
# Epoch 118/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5592 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5221
# Epoch 119/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1708 - mean_absolute_error_labels: 1.5774 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4884
# Epoch 120/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1695 - mean_absolute_error_labels: 1.5625 - val_loss: 0.1748 - val_mean_absolute_error_labels: 1.5769
# Epoch 121/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1698 - mean_absolute_error_labels: 1.5643 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.4814
# Epoch 122/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1700 - mean_absolute_error_labels: 1.5660 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5168
# Epoch 123/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1696 - mean_absolute_error_labels: 1.5579 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.6158
# Epoch 124/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1698 - mean_absolute_error_labels: 1.5652 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5134
# Epoch 125/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1691 - mean_absolute_error_labels: 1.5546 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5157
# Epoch 126/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1698 - mean_absolute_error_labels: 1.5654 - val_loss: 0.1777 - val_mean_absolute_error_labels: 1.6436
# Epoch 127/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1694 - mean_absolute_error_labels: 1.5515 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5553
# Epoch 128/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1691 - mean_absolute_error_labels: 1.5499 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.4803
# Epoch 129/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5614 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.5324
# Epoch 130/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1697 - mean_absolute_error_labels: 1.5512 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5935
# Epoch 131/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1694 - mean_absolute_error_labels: 1.5515 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5285
# Epoch 132/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1689 - mean_absolute_error_labels: 1.5550 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.5255
# Epoch 133/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5533 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.6253
# Epoch 134/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1696 - mean_absolute_error_labels: 1.5757 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.4808
# Epoch 135/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5471 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5796
# Epoch 136/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1691 - mean_absolute_error_labels: 1.5521 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.4614
# Epoch 137/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5511 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.4976
# Epoch 138/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1690 - mean_absolute_error_labels: 1.5516 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.5041
# Epoch 139/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1690 - mean_absolute_error_labels: 1.5727 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5365
# Epoch 140/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5493 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5037
# Epoch 141/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1690 - mean_absolute_error_labels: 1.5525 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5697
# Epoch 142/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1681 - mean_absolute_error_labels: 1.5535 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.6167
# Epoch 143/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1691 - mean_absolute_error_labels: 1.5574 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5858
# Epoch 144/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1688 - mean_absolute_error_labels: 1.5578 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5553
# Epoch 145/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5553 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5536
# Epoch 146/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5422 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5178
# Epoch 147/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1685 - mean_absolute_error_labels: 1.5430 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5486
# Epoch 148/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1692 - mean_absolute_error_labels: 1.5603 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.4925
# Epoch 149/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5541 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5074
# Epoch 150/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5473 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.5572
# Epoch 151/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5522 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.4734
# Epoch 152/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5624 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5466
# Epoch 153/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5575 - val_loss: 0.1747 - val_mean_absolute_error_labels: 1.6637
# Epoch 154/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5509 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.4982
# Epoch 155/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5430 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.6109
# Epoch 156/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5594 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.4432
# Epoch 157/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1679 - mean_absolute_error_labels: 1.5524 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5471
# Epoch 158/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5423 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5494
# Epoch 159/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1681 - mean_absolute_error_labels: 1.5419 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5489
# Epoch 160/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5412 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5794
# Epoch 161/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1677 - mean_absolute_error_labels: 1.5423 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.4631
# Epoch 162/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5548 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5017
# Epoch 163/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5544 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.6268
# Epoch 164/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5650 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5088
# Epoch 165/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5400 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5024
# Epoch 166/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5438 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5325
# Epoch 167/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5433 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.6069
# Epoch 168/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5529 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5635
# Epoch 169/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1677 - mean_absolute_error_labels: 1.5478 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5456
# Epoch 170/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1681 - mean_absolute_error_labels: 1.5417 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.4875
# Epoch 171/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1679 - mean_absolute_error_labels: 1.5581 - val_loss: 0.1749 - val_mean_absolute_error_labels: 1.6397
# Epoch 172/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1676 - mean_absolute_error_labels: 1.5368 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.5784
# Epoch 173/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1682 - mean_absolute_error_labels: 1.5615 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5275
# Epoch 174/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1680 - mean_absolute_error_labels: 1.5458 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5312
# Epoch 175/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5432 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.5047
# Epoch 176/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5608 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4546
# Epoch 177/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5507 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5056
# Epoch 178/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5386 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.5087
# Epoch 179/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5492 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.4569
# Epoch 180/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5477 - val_loss: 0.1763 - val_mean_absolute_error_labels: 1.5937
# Epoch 181/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5347 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5123
# Epoch 182/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5403 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.4959
# Epoch 183/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5410 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.4914
# Epoch 184/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5387 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5435
# Epoch 185/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5481 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5209
# Epoch 186/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5497 - val_loss: 0.1736 - val_mean_absolute_error_labels: 1.5496
# Epoch 187/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5390 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.6400
# Epoch 188/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1677 - mean_absolute_error_labels: 1.5418 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5492
# Epoch 189/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5447 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.6286
# Epoch 190/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5451 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.4932
# Epoch 191/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1666 - mean_absolute_error_labels: 1.5321 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5634
# Epoch 192/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1671 - mean_absolute_error_labels: 1.5512 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5818
# Epoch 193/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1671 - mean_absolute_error_labels: 1.5411 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5141
# Epoch 194/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5608 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5570
# Epoch 195/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5366 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.4570
# Epoch 196/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1676 - mean_absolute_error_labels: 1.5453 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.4981
# Epoch 197/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1676 - mean_absolute_error_labels: 1.5566 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.4832
# Epoch 198/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5453 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5587
# Epoch 199/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5559 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.4916
# Epoch 200/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1670 - mean_absolute_error_labels: 1.5348 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.4888
# Epoch 201/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5337 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5916
# Epoch 202/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5309 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.5605
# Epoch 203/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5369 - val_loss: 0.1749 - val_mean_absolute_error_labels: 1.6122
# Epoch 204/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5556 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5403
# Epoch 205/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1677 - mean_absolute_error_labels: 1.5483 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.4761
# Epoch 206/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1671 - mean_absolute_error_labels: 1.5454 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.4417
# Epoch 207/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5361 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5868
# Epoch 208/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5292 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.4804
# Epoch 209/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1673 - mean_absolute_error_labels: 1.5409 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.5604
# Epoch 210/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5350 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.5778
# Epoch 211/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5389 - val_loss: 0.1736 - val_mean_absolute_error_labels: 1.5459
# Epoch 212/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5346 - val_loss: 0.1751 - val_mean_absolute_error_labels: 1.5990
# Epoch 213/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1664 - mean_absolute_error_labels: 1.5166 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5730
# Epoch 214/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5330 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5790
# Epoch 215/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1676 - mean_absolute_error_labels: 1.5375 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.4854
# Epoch 216/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5401 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.5359
# Epoch 217/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5368 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4916
# Epoch 218/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5316 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.4575
# Epoch 219/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5358 - val_loss: 0.1745 - val_mean_absolute_error_labels: 1.5281
# Epoch 220/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5267 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.5677
# Epoch 221/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5381 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.4803
# Epoch 222/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5363 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.4746
# Epoch 223/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5343 - val_loss: 0.1804 - val_mean_absolute_error_labels: 1.6853
# Epoch 224/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5330 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5558
# Epoch 225/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5444 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5526
# Epoch 226/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5484 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.4907
# Epoch 227/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1674 - mean_absolute_error_labels: 1.5499 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.5135
# Epoch 228/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1666 - mean_absolute_error_labels: 1.5428 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5773
# Epoch 229/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1666 - mean_absolute_error_labels: 1.5313 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5518
# Epoch 230/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5353 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5451
# Epoch 231/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5434 - val_loss: 0.1749 - val_mean_absolute_error_labels: 1.7119
# Epoch 232/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5501 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.5523
# Epoch 233/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5325 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5471
# Epoch 234/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5418 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5208
# Epoch 235/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5311 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.4910
# Epoch 236/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1670 - mean_absolute_error_labels: 1.5485 - val_loss: 0.1796 - val_mean_absolute_error_labels: 1.6475
# Epoch 237/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5299 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5905
# Epoch 238/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5280 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.4991
# Epoch 239/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1662 - mean_absolute_error_labels: 1.5337 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.5456
# Epoch 240/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1664 - mean_absolute_error_labels: 1.5319 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.4934
# Epoch 241/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5210 - val_loss: 0.1768 - val_mean_absolute_error_labels: 1.6106
# Epoch 242/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1661 - mean_absolute_error_labels: 1.5308 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5094
# Epoch 243/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5333 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.5528
# Epoch 244/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1670 - mean_absolute_error_labels: 1.5323 - val_loss: 0.1811 - val_mean_absolute_error_labels: 1.4611
# Epoch 245/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1664 - mean_absolute_error_labels: 1.5330 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.5537
# Epoch 246/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5186 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.4870
# Epoch 247/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1672 - mean_absolute_error_labels: 1.5360 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5234
# Epoch 248/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5307 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.6380
# Epoch 249/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5408 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.4589
# Epoch 250/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1651 - mean_absolute_error_labels: 1.5343 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5458
# Epoch 251/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1661 - mean_absolute_error_labels: 1.5305 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5301
# Epoch 252/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1657 - mean_absolute_error_labels: 1.5223 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5284
# Epoch 253/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1658 - mean_absolute_error_labels: 1.5334 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5291
# Epoch 254/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1661 - mean_absolute_error_labels: 1.5399 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.5497
# Epoch 255/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5322 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5527
# Epoch 256/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5349 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.4754
# Epoch 257/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5427 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5105
# Epoch 258/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1653 - mean_absolute_error_labels: 1.5498 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5763
# Epoch 259/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1658 - mean_absolute_error_labels: 1.5367 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5721
# Epoch 260/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1665 - mean_absolute_error_labels: 1.5494 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.5063
# Epoch 261/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1656 - mean_absolute_error_labels: 1.5264 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5260
# Epoch 262/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1662 - mean_absolute_error_labels: 1.5317 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5460
# Epoch 263/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1661 - mean_absolute_error_labels: 1.5340 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5041
# Epoch 264/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1661 - mean_absolute_error_labels: 1.5569 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.5785
# Epoch 265/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1657 - mean_absolute_error_labels: 1.5366 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5709
# Epoch 266/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1662 - mean_absolute_error_labels: 1.5271 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5221
# Epoch 267/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5392 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.5013
# Epoch 268/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5311 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.5431
# Epoch 269/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1654 - mean_absolute_error_labels: 1.5285 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.5180
# Epoch 270/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1659 - mean_absolute_error_labels: 1.5293 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5191

# %%
history_model_corn_do_01=history_model_corn_do_01.history

# %%
plt.plot(history_model_corn_do_01['mean_absolute_error_labels'])
plt.plot(history_model_corn_do_01['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
print("Performance on datasets")

# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
do_ordinal_logits_train_01 = model_corn_do_01.predict(X_train_L1reg_np)
do_ordinal_logits_valid_01 = model_corn_do_01.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
do_tensor_probs_train_01 = coral.corn_ordinal_softmax(do_ordinal_logits_train_01)
do_tensor_probs_valid_01 = coral.corn_ordinal_softmax(do_ordinal_logits_valid_01)

# Convert the tensor into a pandas dataframe.
do_labels_train_01 = coral.cumprobs_to_label(do_tensor_probs_train_01)
do_labels_valid_01 = coral.cumprobs_to_label(do_tensor_probs_valid_01)
# Out:
# Performance on datasets
# 1114/1114 [==============================] - 1s 921us/step
# 372/372 [==============================] - 0s 878us/step

# %%
#In train
# monitor='loss', patience=20, Epochs= 118
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_01.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_do_01 = QuadraticWeightedKappa(y_train, do_tensor_probs_train_01).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_do_01)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1449 - mean_absolute_error_labels: 1.4574
# [Loss, Mean Absolute Error Labels] : [0.14494802057743073, 1.4573888778686523]
# Quadratic Weighted Kappa on training set: 0.63123035

# %%
#In validation
# monitor='loss', patience=20, Epochs= 118

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_01.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_do_01 = QuadraticWeightedKappa(y_valid, do_tensor_probs_valid_01).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_valid_model_corn_do_01)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5458
# [Loss, Mean Absolute Error Labels] : [0.1720687597990036, 1.5457829236984253]
# Quadratic Weighted Kappa on training set: 0.5125713

# %% [markdown]
# This model has shown the best performance so far on the validation set. Next, we will try to further reduce bias by increasing the size of the network.
#
# ### Larger CORN + BN + 0.1 Dropout
#
# In this iteration, we will keep all hyperparameters the same as the previous model, except for the number of hidden layers and units. The search space for hidden layers will be set between 6 and 8.

# %%
bigger_corn_hp = kt.HyperParameters()

# Fix

bigger_corn_hp.Int("hidden_layers", min_value = 6, max_value = 8)
bigger_corn_hp.Fixed("learning_rate", value = hyps_corn_do_01["learning_rate"])
bigger_corn_hp.Fixed("batch_size", value = hyps_corn_do_01["batch_size"])
bigger_corn_hp.Fixed("dropout_rate", value = 0.1)
bigger_corn_hp.Fixed("dropout", value = True)
bigger_corn_hp.Fixed("batch_norm", value = True)


tuner_bigger_corn = kt.Hyperband(
CornHyperModel(),
hyperparameters = bigger_corn_hp,
tune_new_entries = True,
objective = kt.Objective("val_mean_absolute_error_labels", "min"),
directory = "Tuners/Tuner_Big_Corn",
project_name = "Search_6To8",
seed = 5,
)
# Out:
# Reloading Tuner from Tuner_Big_Corn\Search_6To8\tuner0.json

# %%
tuner_bigger_corn.search_space_summary()
# Out:
# Search space summary
# Default search space size: 14
# hidden_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 6, 'max_value': 8, 'step': 1, 'sampling': 'linear'}
# learning_rate (Fixed)
# {'conditions': [], 'value': 0.04621726369179639}
# batch_size (Fixed)
# {'conditions': [], 'value': 64}
# dropout_rate (Fixed)
# {'conditions': [], 'value': 0.1}
# dropout (Fixed)
# {'conditions': [], 'value': True}
# batch_norm (Fixed)
# {'conditions': [], 'value': True}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 114, 'step': 32, 'sampling': 'linear'}

# %%
tuner_bigger_corn.search(X_train_L1reg_np, y_train, validation_data=(X_valid_L1reg_np, y_valid), callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights= True)])

# %%
tuner_bigger_corn.results_summary()
# Out:
# Results summary
# Results in Tuner_Big_Corn\Search_6To8
# Showing 10 best trials
# Objective(name="val_mean_absolute_error_labels", direction="min")
#
# Trial 0211 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 80
# units_2: 112
# units_3: 80
# units_4: 80
# units_5: 48
# units_6: 16
# units_7: 16
# units_8: 80
# tuner/epochs: 12
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 1.3881235122680664
#
# Trial 0205 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 48
# units_2: 80
# units_3: 16
# units_4: 112
# units_5: 112
# units_6: 16
# units_7: 48
# units_8: 112
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 0191
# Score: 1.3913156986236572
#
# Trial 0155 summary
# Hyperparameters:
# hidden_layers: 6
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 16
# units_2: 80
# units_3: 80
# units_4: 80
# units_5: 16
# units_6: 112
# units_7: 16
# units_8: 16
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.4011815786361694
#
# Trial 0247 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 112
# units_2: 80
# units_3: 112
# units_4: 48
# units_5: 48
# units_6: 16
# units_7: 48
# units_8: 112
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0241
# Score: 1.4061100482940674
#
# Trial 0209 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 112
# units_2: 112
# units_3: 112
# units_4: 48
# units_5: 112
# units_6: 16
# units_7: 112
# units_8: 16
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0204
# Score: 1.4137824773788452
#
# Trial 0185 summary
# Hyperparameters:
# hidden_layers: 6
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 112
# units_2: 80
# units_3: 112
# units_4: 48
# units_5: 16
# units_6: 16
# units_7: 80
# units_8: 16
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.4163306951522827
#
# Trial 0156 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 48
# units_2: 80
# units_3: 16
# units_4: 112
# units_5: 112
# units_6: 16
# units_7: 48
# units_8: 112
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 1.421286940574646
#
# Trial 0200 summary
# Hyperparameters:
# hidden_layers: 6
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 80
# units_2: 112
# units_3: 80
# units_4: 16
# units_5: 112
# units_6: 48
# units_7: 80
# units_8: 48
# tuner/epochs: 12
# tuner/initial_epoch: 4
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 0172
# Score: 1.421837568283081
#
# Trial 0251 summary
# Hyperparameters:
# hidden_layers: 7
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 112
# units_2: 80
# units_3: 48
# units_4: 48
# units_5: 48
# units_6: 112
# units_7: 48
# units_8: 112
# tuner/epochs: 100
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 1.4221177101135254
#
# Trial 0011 summary
# Hyperparameters:
# hidden_layers: 8
# learning_rate: 0.04621726369179639
# batch_size: 64
# dropout_rate: 0.1
# dropout: True
# batch_norm: True
# units_1: 48
# units_2: 16
# units_3: 80
# units_4: 16
# units_5: 80
# units_6: 16
# units_7: 16
# units_8: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 4
# tuner/round: 0
# Score: 1.4264578819274902

# %%
# Get the optimal hyperparameters
hyps_bigger_corn = tuner_bigger_corn.get_best_hyperparameters(num_trials=1)[0]
model_bigger_corn = tuner_bigger_corn.hypermodel.build(hyps_bigger_corn)

print(hyps_bigger_corn.values)
# Out:
# {'hidden_layers': 7, 'learning_rate': 0.04621726369179639, 'batch_size': 64, 'dropout_rate': 0.1, 'dropout': True, 'batch_norm': True, 'units_1': 80, 'units_2': 112, 'units_3': 80, 'units_4': 80, 'units_5': 48, 'units_6': 16, 'units_7': 16, 'units_8': 80, 'tuner/epochs': 12, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}

# %%
# monitor='loss', patience=20, epochs=57
history_model_bigger_corn=model_bigger_corn.fit(x=X_train_L1reg_np, y=y_train, epochs=300, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights= True)])
# Out:
# Epoch 1/300
# 1114/1114 [==============================] - 7s 3ms/step - loss: 0.1995 - mean_absolute_error_labels: 1.8031 - val_loss: 0.2316 - val_mean_absolute_error_labels: 1.8400
# Epoch 2/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1914 - mean_absolute_error_labels: 1.6978 - val_loss: 0.1830 - val_mean_absolute_error_labels: 1.5688
# Epoch 3/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1902 - mean_absolute_error_labels: 1.6805 - val_loss: 0.2027 - val_mean_absolute_error_labels: 1.5370
# Epoch 4/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1891 - mean_absolute_error_labels: 1.6877 - val_loss: 0.1918 - val_mean_absolute_error_labels: 1.5161
# Epoch 5/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1882 - mean_absolute_error_labels: 1.6685 - val_loss: 0.1811 - val_mean_absolute_error_labels: 1.5421
# Epoch 6/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1872 - mean_absolute_error_labels: 1.6547 - val_loss: 0.1848 - val_mean_absolute_error_labels: 1.5439
# Epoch 7/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1868 - mean_absolute_error_labels: 1.6532 - val_loss: 0.1817 - val_mean_absolute_error_labels: 1.5721
# Epoch 8/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1853 - mean_absolute_error_labels: 1.6436 - val_loss: 0.1863 - val_mean_absolute_error_labels: 1.7560
# Epoch 9/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1852 - mean_absolute_error_labels: 1.6485 - val_loss: 0.1830 - val_mean_absolute_error_labels: 1.6311
# Epoch 10/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1855 - mean_absolute_error_labels: 1.6322 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5843
# Epoch 11/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1847 - mean_absolute_error_labels: 1.6391 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.5275
# Epoch 12/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1847 - mean_absolute_error_labels: 1.6349 - val_loss: 0.1798 - val_mean_absolute_error_labels: 1.6106
# Epoch 13/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1837 - mean_absolute_error_labels: 1.6387 - val_loss: 0.1756 - val_mean_absolute_error_labels: 1.5864
# Epoch 14/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1837 - mean_absolute_error_labels: 1.6429 - val_loss: 0.1762 - val_mean_absolute_error_labels: 1.6069
# Epoch 15/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1827 - mean_absolute_error_labels: 1.6250 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.5380
# Epoch 16/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1829 - mean_absolute_error_labels: 1.6368 - val_loss: 0.1801 - val_mean_absolute_error_labels: 1.6820
# Epoch 17/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1821 - mean_absolute_error_labels: 1.6279 - val_loss: 0.1814 - val_mean_absolute_error_labels: 1.5554
# Epoch 18/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1816 - mean_absolute_error_labels: 1.6294 - val_loss: 0.1765 - val_mean_absolute_error_labels: 1.6981
# Epoch 19/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1820 - mean_absolute_error_labels: 1.6276 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5510
# Epoch 20/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1812 - mean_absolute_error_labels: 1.6316 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5405
# Epoch 21/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1811 - mean_absolute_error_labels: 1.6242 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5013
# Epoch 22/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1815 - mean_absolute_error_labels: 1.6280 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.5276
# Epoch 23/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1810 - mean_absolute_error_labels: 1.6241 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.6080
# Epoch 24/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1808 - mean_absolute_error_labels: 1.6296 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.5223
# Epoch 25/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1804 - mean_absolute_error_labels: 1.6211 - val_loss: 0.1744 - val_mean_absolute_error_labels: 1.6317
# Epoch 26/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1801 - mean_absolute_error_labels: 1.6279 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5137
# Epoch 27/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1804 - mean_absolute_error_labels: 1.6242 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5286
# Epoch 28/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1804 - mean_absolute_error_labels: 1.6187 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5532
# Epoch 29/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1802 - mean_absolute_error_labels: 1.6274 - val_loss: 0.1756 - val_mean_absolute_error_labels: 1.6551
# Epoch 30/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1797 - mean_absolute_error_labels: 1.6247 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.6258
# Epoch 31/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1798 - mean_absolute_error_labels: 1.6195 - val_loss: 0.1824 - val_mean_absolute_error_labels: 1.8736
# Epoch 32/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1797 - mean_absolute_error_labels: 1.6259 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.4896
# Epoch 33/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1798 - mean_absolute_error_labels: 1.6288 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.5644
# Epoch 34/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1800 - mean_absolute_error_labels: 1.6340 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.5652
# Epoch 35/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1794 - mean_absolute_error_labels: 1.6315 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.6104
# Epoch 36/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1794 - mean_absolute_error_labels: 1.6268 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.5979
# Epoch 37/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6283 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.6358
# Epoch 38/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1787 - mean_absolute_error_labels: 1.6119 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.6142
# Epoch 39/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1786 - mean_absolute_error_labels: 1.6068 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.6148
# Epoch 40/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6120 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5061
# Epoch 41/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1784 - mean_absolute_error_labels: 1.6275 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.5555
# Epoch 42/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6238 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.5580
# Epoch 43/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6319 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5706
# Epoch 44/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6224 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5603
# Epoch 45/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1787 - mean_absolute_error_labels: 1.6170 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5061
# Epoch 46/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1780 - mean_absolute_error_labels: 1.6099 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5800
# Epoch 47/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1781 - mean_absolute_error_labels: 1.6138 - val_loss: 0.1773 - val_mean_absolute_error_labels: 1.6066
# Epoch 48/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1775 - mean_absolute_error_labels: 1.5926 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5571
# Epoch 49/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1789 - mean_absolute_error_labels: 1.6387 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5386
# Epoch 50/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1774 - mean_absolute_error_labels: 1.6077 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.6076
# Epoch 51/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1772 - mean_absolute_error_labels: 1.6064 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.6318
# Epoch 52/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1781 - mean_absolute_error_labels: 1.6129 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.4786
# Epoch 53/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1776 - mean_absolute_error_labels: 1.6066 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5830
# Epoch 54/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1774 - mean_absolute_error_labels: 1.5939 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.5476
# Epoch 55/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1775 - mean_absolute_error_labels: 1.6043 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.6160
# Epoch 56/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1775 - mean_absolute_error_labels: 1.6044 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.6220
# Epoch 57/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1775 - mean_absolute_error_labels: 1.6100 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5056
# Epoch 58/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1773 - mean_absolute_error_labels: 1.6100 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.7046
# Epoch 59/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1771 - mean_absolute_error_labels: 1.6126 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5759
# Epoch 60/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1766 - mean_absolute_error_labels: 1.5969 - val_loss: 0.1732 - val_mean_absolute_error_labels: 1.6773
# Epoch 61/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1776 - mean_absolute_error_labels: 1.6183 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5896
# Epoch 62/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1766 - mean_absolute_error_labels: 1.6059 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5215
# Epoch 63/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1765 - mean_absolute_error_labels: 1.6120 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.5839
# Epoch 64/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1767 - mean_absolute_error_labels: 1.6174 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.6059
# Epoch 65/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1768 - mean_absolute_error_labels: 1.6184 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5329
# Epoch 66/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1764 - mean_absolute_error_labels: 1.6090 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.5574
# Epoch 67/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1763 - mean_absolute_error_labels: 1.6016 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5329
# Epoch 68/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1767 - mean_absolute_error_labels: 1.6062 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.4646
# Epoch 69/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1776 - mean_absolute_error_labels: 1.6170 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5293
# Epoch 70/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1763 - mean_absolute_error_labels: 1.5966 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.5001
# Epoch 71/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1769 - mean_absolute_error_labels: 1.6095 - val_loss: 0.1742 - val_mean_absolute_error_labels: 1.5810
# Epoch 72/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1766 - mean_absolute_error_labels: 1.6094 - val_loss: 0.1754 - val_mean_absolute_error_labels: 1.4735
# Epoch 73/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1759 - mean_absolute_error_labels: 1.6040 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5343
# Epoch 74/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1754 - mean_absolute_error_labels: 1.5993 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.4617
# Epoch 75/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.6066 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.5775
# Epoch 76/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1759 - mean_absolute_error_labels: 1.6049 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.4930
# Epoch 77/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1759 - mean_absolute_error_labels: 1.6036 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5808
# Epoch 78/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1760 - mean_absolute_error_labels: 1.6095 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.6069
# Epoch 79/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.5981 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.4139
# Epoch 80/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1760 - mean_absolute_error_labels: 1.6082 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5559
# Epoch 81/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1760 - mean_absolute_error_labels: 1.6090 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5995
# Epoch 82/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6045 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5884
# Epoch 83/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1753 - mean_absolute_error_labels: 1.5916 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.4910
# Epoch 84/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.6072 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.6256
# Epoch 85/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1758 - mean_absolute_error_labels: 1.6047 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5542
# Epoch 86/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6121 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.4393
# Epoch 87/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1760 - mean_absolute_error_labels: 1.6048 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5458
# Epoch 88/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.6029 - val_loss: 0.1752 - val_mean_absolute_error_labels: 1.7681
# Epoch 89/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1753 - mean_absolute_error_labels: 1.6034 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5770
# Epoch 90/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.5943 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5470
# Epoch 91/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.6061 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5505
# Epoch 92/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1748 - mean_absolute_error_labels: 1.5937 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.4762
# Epoch 93/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1751 - mean_absolute_error_labels: 1.6027 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.6702
# Epoch 94/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6129 - val_loss: 0.1748 - val_mean_absolute_error_labels: 1.4362
# Epoch 95/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.5856 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.4775
# Epoch 96/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1749 - mean_absolute_error_labels: 1.5910 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5034
# Epoch 97/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6010 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.6185
# Epoch 98/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1751 - mean_absolute_error_labels: 1.6051 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5924
# Epoch 99/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1749 - mean_absolute_error_labels: 1.6027 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5213
# Epoch 100/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1749 - mean_absolute_error_labels: 1.6024 - val_loss: 0.1713 - val_mean_absolute_error_labels: 1.6305
# Epoch 101/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.6056 - val_loss: 0.1686 - val_mean_absolute_error_labels: 1.5452
# Epoch 102/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1748 - mean_absolute_error_labels: 1.5941 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.5244
# Epoch 103/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.5925 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5544
# Epoch 104/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.6039 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5405
# Epoch 105/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.5975 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.4294
# Epoch 106/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.5993 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5706
# Epoch 107/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1744 - mean_absolute_error_labels: 1.5992 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5911
# Epoch 108/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.5938 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.4528
# Epoch 109/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1744 - mean_absolute_error_labels: 1.5963 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.6045
# Epoch 110/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1738 - mean_absolute_error_labels: 1.6012 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5907
# Epoch 111/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1745 - mean_absolute_error_labels: 1.6102 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.6429
# Epoch 112/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1744 - mean_absolute_error_labels: 1.6030 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.6459
# Epoch 113/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1741 - mean_absolute_error_labels: 1.5991 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.7235
# Epoch 114/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1744 - mean_absolute_error_labels: 1.5922 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.6225
# Epoch 115/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.5911 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.4745
# Epoch 116/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1740 - mean_absolute_error_labels: 1.5889 - val_loss: 0.1687 - val_mean_absolute_error_labels: 1.5575
# Epoch 117/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5896 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.6794
# Epoch 118/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.5944 - val_loss: 0.1685 - val_mean_absolute_error_labels: 1.4842
# Epoch 119/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1739 - mean_absolute_error_labels: 1.5908 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5498
# Epoch 120/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.5927 - val_loss: 0.1750 - val_mean_absolute_error_labels: 1.6400
# Epoch 121/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1745 - mean_absolute_error_labels: 1.5968 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5060
# Epoch 122/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.5919 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.6163
# Epoch 123/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1741 - mean_absolute_error_labels: 1.6003 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.6273
# Epoch 124/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1736 - mean_absolute_error_labels: 1.5853 - val_loss: 0.1679 - val_mean_absolute_error_labels: 1.5267
# Epoch 125/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1741 - mean_absolute_error_labels: 1.5935 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5334
# Epoch 126/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1739 - mean_absolute_error_labels: 1.6039 - val_loss: 0.1777 - val_mean_absolute_error_labels: 1.6797
# Epoch 127/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.5948 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5186
# Epoch 128/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1737 - mean_absolute_error_labels: 1.5949 - val_loss: 0.1679 - val_mean_absolute_error_labels: 1.5156
# Epoch 129/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.6059 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.4707
# Epoch 130/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1740 - mean_absolute_error_labels: 1.5860 - val_loss: 0.1739 - val_mean_absolute_error_labels: 1.6462
# Epoch 131/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1740 - mean_absolute_error_labels: 1.5889 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5389
# Epoch 132/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1733 - mean_absolute_error_labels: 1.5902 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5473
# Epoch 133/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1738 - mean_absolute_error_labels: 1.5883 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.6774
# Epoch 134/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5973 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5355
# Epoch 135/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5848 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.6429
# Epoch 136/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5897 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.4907
# Epoch 137/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5918 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5206
# Epoch 138/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1733 - mean_absolute_error_labels: 1.5790 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.5297
# Epoch 139/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1736 - mean_absolute_error_labels: 1.5969 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5034
# Epoch 140/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5837 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5385
# Epoch 141/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1736 - mean_absolute_error_labels: 1.5944 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5449
# Epoch 142/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5802 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.6079
# Epoch 143/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5862 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5378
# Epoch 144/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5844 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.6259
# Epoch 145/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1734 - mean_absolute_error_labels: 1.5910 - val_loss: 0.1736 - val_mean_absolute_error_labels: 1.5995
# Epoch 146/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1734 - mean_absolute_error_labels: 1.5751 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5286
# Epoch 147/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5765 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5186
# Epoch 148/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5832 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5006
# Epoch 149/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5804 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5071
# Epoch 150/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5900 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5698
# Epoch 151/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5834 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5104
# Epoch 152/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1737 - mean_absolute_error_labels: 1.6029 - val_loss: 0.1722 - val_mean_absolute_error_labels: 1.5743
# Epoch 153/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5791 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.6843
# Epoch 154/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5780 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.4776
# Epoch 155/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5900 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5866
# Epoch 156/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1732 - mean_absolute_error_labels: 1.5910 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.4657
# Epoch 157/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5774 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5500
# Epoch 158/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1725 - mean_absolute_error_labels: 1.5921 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5351
# Epoch 159/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5774 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5370
# Epoch 160/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1725 - mean_absolute_error_labels: 1.5807 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5416
# Epoch 161/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5909 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5055
# Epoch 162/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1734 - mean_absolute_error_labels: 1.5851 - val_loss: 0.1680 - val_mean_absolute_error_labels: 1.5412
# Epoch 163/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5964 - val_loss: 0.1751 - val_mean_absolute_error_labels: 1.7119
# Epoch 164/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.6059 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5282
# Epoch 165/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5927 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5218
# Epoch 166/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5776 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.6236
# Epoch 167/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5784 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.6554
# Epoch 168/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.6006 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.6268
# Epoch 169/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5852 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.5743
# Epoch 170/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5796 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4523
# Epoch 171/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1725 - mean_absolute_error_labels: 1.5804 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.6326
# Epoch 172/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5800 - val_loss: 0.1745 - val_mean_absolute_error_labels: 1.7051
# Epoch 173/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1726 - mean_absolute_error_labels: 1.5973 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5696
# Epoch 174/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5857 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5793
# Epoch 175/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1725 - mean_absolute_error_labels: 1.5820 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5228
# Epoch 176/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1726 - mean_absolute_error_labels: 1.5820 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5403
# Epoch 177/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5919 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5501
# Epoch 178/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.5819 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.6169
# Epoch 179/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5736 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5376
# Epoch 180/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.5746 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.4719
# Epoch 181/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5755 - val_loss: 0.1685 - val_mean_absolute_error_labels: 1.5266
# Epoch 182/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5794 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5512
# Epoch 183/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5730 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.4934
# Epoch 184/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5681 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.4970
# Epoch 185/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5732 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5435
# Epoch 186/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5705 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5752
# Epoch 187/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5901 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.8095
# Epoch 188/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5812 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5319
# Epoch 189/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1723 - mean_absolute_error_labels: 1.5766 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.6447
# Epoch 190/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5886 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5543
# Epoch 191/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5762 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.6557
# Epoch 192/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5826 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.6710
# Epoch 193/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5678 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.5633
# Epoch 194/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5896 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5276
# Epoch 195/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5824 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.4677
# Epoch 196/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5827 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.5307
# Epoch 197/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5768 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5530
# Epoch 198/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5824 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5343
# Epoch 199/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5748 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5281
# Epoch 200/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5734 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.6470
# Epoch 201/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1723 - mean_absolute_error_labels: 1.5752 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.5765
# Epoch 202/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1710 - mean_absolute_error_labels: 1.5740 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.6001
# Epoch 203/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1724 - mean_absolute_error_labels: 1.5844 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5705
# Epoch 204/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5675 - val_loss: 0.1686 - val_mean_absolute_error_labels: 1.5291
# Epoch 205/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5773 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.4919
# Epoch 206/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5770 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.4285
# Epoch 207/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1725 - mean_absolute_error_labels: 1.5814 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.6179
# Epoch 208/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5863 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.4921
# Epoch 209/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5813 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.6126
# Epoch 210/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5909 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.6090
# Epoch 211/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5739 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.6216
# Epoch 212/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1714 - mean_absolute_error_labels: 1.5809 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5233
# Epoch 213/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1717 - mean_absolute_error_labels: 1.5664 - val_loss: 0.1719 - val_mean_absolute_error_labels: 1.6303
# Epoch 214/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1721 - mean_absolute_error_labels: 1.5768 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.6019
# Epoch 215/300
# 1114/1114 [==============================] - 4s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5773 - val_loss: 0.1720 - val_mean_absolute_error_labels: 1.5444
# Epoch 216/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.5738 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.5187
# Epoch 217/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1719 - mean_absolute_error_labels: 1.5802 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5840
# Epoch 218/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5881 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.4587
# Epoch 219/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1716 - mean_absolute_error_labels: 1.5747 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.5010
# Epoch 220/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5821 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5446
# Epoch 221/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5880 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.5746
# Epoch 222/300
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5979 - val_loss: 0.1692 - val_mean_absolute_error_labels: 1.5512

# %%
history_model_bigger_corn=history_model_bigger_corn.history

# %%
plt.plot(history_model_bigger_corn['mean_absolute_error_labels'])
plt.plot(history_model_bigger_corn['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
print("Performance on datasets")

# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
bigger_do_ordinal_logits_train = model_bigger_corn.predict(X_train_L1reg_np)
bigger_do_ordinal_logits_valid = model_bigger_corn.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
bigger_do_tensor_probs_train = coral.corn_ordinal_softmax(bigger_do_ordinal_logits_train)
bigger_do_tensor_probs_valid = coral.corn_ordinal_softmax(bigger_do_ordinal_logits_valid)

# Convert the tensor into a pandas dataframe.
bigger_do_labels_train = coral.cumprobs_to_label(bigger_do_tensor_probs_train)
bigger_do_labels_valid = coral.cumprobs_to_label(bigger_do_tensor_probs_valid)
# Out:
# Performance on datasets
# 1114/1114 [==============================] - 1s 871us/step
# 372/372 [==============================] - 0s 881us/step

# %%
#In train
#0.419 monitor='loss', patience=20, epochs=57

print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_bigger_corn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_bigger_corn = QuadraticWeightedKappa(y_train, bigger_do_tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_bigger_corn)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1576 - mean_absolute_error_labels: 1.5638
# [Loss, Mean Absolute Error Labels] : [0.15759222209453583, 1.563846468925476]
# Quadratic Weighted Kappa on training set: 0.46349424

# %%
#In validation
#0.411 monitor='loss', patience=20, epochs=57

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_bigger_corn.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_bigger_corn = QuadraticWeightedKappa(y_valid, bigger_do_tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_valid_model_bigger_corn)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 0.1715 - mean_absolute_error_labels: 1.6001
# [Loss, Mean Absolute Error Labels] : [0.17146699130535126, 1.600050449371338]
# Quadratic Weighted Kappa on training set: 0.42765832

# %%
model_bigger_corn_bias = baseline-qwk_train_model_bigger_corn
model_bigger_corn_var = qwk_train_model_bigger_corn-qwk_valid_model_bigger_corn
print("Bias / Variance of the model: ")
print(round(model_bigger_corn_bias,3),"/",round(model_bigger_corn_var,3))
# Out:
# Bias / Variance of the model:
# 0.216 / 0.036

# %% [markdown]
# The bias increased significantly with this larger network. The best model for the validation set so far is the CORN model with batch normalization. Now, let's try the regular MLP model with a softmax layer at its output.

# %% [markdown]
# The model with the batch normalization layer has a slightly better performance than the one without them, although not very significant. Which means that its the best model of the tested regular MLPs.
#
# ### Early Stopping
#
# #### MLP + Batch normalization

# %%
# Get the optimal hyperparameters
model_es_mlp_bn = tuner_mlp_2_bn.hypermodel.build(hyps_mlp_2_bn)

print(hyps_mlp_2_bn.values)
# Out:
# {'learning_rate': 0.01894635097944879, 'batch_size': 64, 'batch_norm': True, 'dropout': False, 'do_rate': 0.2, 'hidden_layers': 5, 'units_1': 16, 'units_2': 80, 'units_3': 16, 'units_4': 112, 'units_5': 16, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0240', 'dropout_rate': 0.2}

# %% [markdown]
# Now, we will train the model with the optimized hyperparameters.

# %%
# monitor='loss', patience=20, epochs=300
history_model_es_mlp_bn = model_es_mlp_bn.fit(x=X_train_L1reg_np, y=y_train, epochs=50, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights= True)])
model_es_mlp_bn.save("Models/model_es_mlp_bn/model.keras")
with open('Models/model_es_mlp_bn/trainHistoryDict', 'wb') as file_pi:
    pickle.dump(history_model_es_mlp_bn.history, file_pi)
# Out:
# Epoch 1/50
# 1114/1114 [==============================] - 4s 2ms/step - loss: 1.5008 - accuracy: 0.4509 - QuadraticWeightedKappa: 0.4383 - val_loss: 1.4395 - val_accuracy: 0.4778 - val_QuadraticWeightedKappa: 0.4717
# Epoch 2/50
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1
50
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.3176 - accuracy: 0.5165 - QuadraticWeightedKappa: 0.4830 - val_loss: 1.3111 - val_accuracy: 0.5288 - val_QuadraticWeightedKappa: 0.5194
# Epoch 50/50
# 1114/1114 [==============================] - 2s 2ms/step - loss: 1.3104 - accuracy: 0.5186 - QuadraticWeightedKappa: 0.4851 - val_loss: 1.3277 - val_accuracy: 0.5186 - val_QuadraticWeightedKappa: 0.4827

# %%
model_es_mlp_bn = keras.models.load_model("Models/model_es_mlp_bn/model.keras")
with open('Models/model_es_mlp_bn/trainHistoryDict', "rb") as file_pi:
    history_model_es_mlp_bn = pickle.load(file_pi)

# %%
plt.plot(history_model_es_mlp_bn['QuadraticWeightedKappa'])
plt.plot(history_model_es_mlp_bn['val_QuadraticWeightedKappa'])
plt.title('Model QuadraticWeightedKappa')
plt.ylabel('QuadraticWeightedKappa')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Performance on training set
print("Train evaluation")
print()
print("[Loss, Accuracy, Average QWK] :", model_es_mlp_bn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_es_mlp_bn = QuadraticWeightedKappa(y_train, model_es_mlp_bn.predict(X_train_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_es_mlp_bn)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 2s 943us/step - loss: 1.2778 - accuracy: 0.5359 - QuadraticWeightedKappa: 0.4756
# [Loss, Accuracy, Average QWK] : [1.277774453163147, 0.5358706712722778, 0.4756240248680115]
# 1114/1114 [==============================] - 1s 778us/step
# Quadratic Weighted Kappa on training set: 0.48602098

# %%
# Performance on validation set
print("Validation evaluation")
print()
print("[Loss, Accuracy, Average QWK]:",  model_es_mlp_bn.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_es_mlp_bn = QuadraticWeightedKappa(y_valid, model_es_mlp_bn.predict(X_valid_L1reg_np)).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_es_mlp_bn)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 978us/step - loss: 1.3277 - accuracy: 0.5186 - QuadraticWeightedKappa: 0.4827
# [Loss, Accuracy, Average QWK]: [1.3277394771575928, 0.5186089873313904, 0.4826616644859314]
# 372/372 [==============================] - 0s 782us/step
# Quadratic Weighted Kappa on validation set: 0.48866814

# %% [markdown]
# #### CORN

# %%
# Get the optimal hyperparameters
model_es_corn = tuner_corn_only_2.hypermodel.build(hyps_corn_only_2)
print(hyps_corn_only_2.values)
# Out:
# {'learning_rate': 0.0031089211420179527, 'batch_size': 32, 'batch_norm': False, 'dropout': False, 'dropout_rate': 0.2, 'hidden_layers': 2, 'units_1': 80, 'units_2': 16, 'units_3': 112, 'units_4': 16, 'units_5': 48, 'tuner/epochs': 34, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}

# %% [markdown]
# The optimized model is now deeper and wider, with three hidden layers. Let's fit the fully optimized CORN MLP.

# %%
# monitor='loss', patience=20, Epochs: 300
history_model_es_corn = model_es_corn.fit(x=X_train_L1reg_np, y=y_train, epochs=70, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=25, restore_best_weights= True)])
# model_corn_only_2.save("Models/model_corn_only_2/model.keras")
# with open('Models/model_corn_only_2/trainHistoryDict', 'wb') as file_pi:
#     pickle.dump(history_model_corn_only_2.history, file_pi)
# Out:
# Epoch 1/70
# 1114/1114 [==============================] - 3s 1ms/step - loss: 0.1910 - mean_absolute_error_labels: 1.8098 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.7193
# Epoch 2/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.5941 - val_loss: 0.1790 - val_mean_absolute_error_labels: 1.4882
# Epoch 3/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1727 - mean_absolute_error_labels: 1.5811 - val_loss: 0.1749 - val_mean_absolute_error_labels: 1.7168
# Epoch 4/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1710 - mean_absolute_error_labels: 1.5769 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.4992
# Epoch 5/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1694 - mean_absolute_error_labels: 1.5688 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5253
# Epoch 6/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1683 - mean_absolute_error_labels: 1.5631 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5904
# Epoch 7/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1677 - mean_absolute_error_labels: 1.5594 - val_loss: 0.1680 - val_mean_absolute_error_labels: 1.5418
# Epoch 8/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1667 - mean_absolute_error_labels: 1.5526 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.6407
# Epoch 9/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1660 - mean_absolute_error_labels: 1.5492 - val_loss: 0.1664 - val_mean_absolute_error_labels: 1.5591
# Epoch 10/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1656 - mean_absolute_error_labels: 1.5471 - val_loss: 0.1668 - val_mean_absolute_error_labels: 1.5300
# Epoch 11/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1647 - mean_absolute_error_labels: 1.5449 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.5124
# Epoch 12/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1639 - mean_absolute_error_labels: 1.5409 - val_loss: 0.1678 - val_mean_absolute_error_labels: 1.5843
# Epoch 13/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1634 - mean_absolute_error_labels: 1.5343 - val_loss: 0.1688 - val_mean_absolute_error_labels: 1.5456
# Epoch 14/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1629 - mean_absolute_error_labels: 1.5425 - val_loss: 0.1686 - val_mean_absolute_error_labels: 1.5433
# Epoch 15/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1624 - mean_absolute_error_labels: 1.5340 - val_loss: 0.1670 - val_mean_absolute_error_labels: 1.5171
# Epoch 16/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1623 - mean_absolute_error_labels: 1.5361 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.5911
# Epoch 17/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1620 - mean_absolute_error_labels: 1.5373 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5040
# Epoch 18/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1612 - mean_absolute_error_labels: 1.5347 - val_loss: 0.1664 - val_mean_absolute_error_labels: 1.5805
# Epoch 19/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1608 - mean_absolute_error_labels: 1.5357 - val_loss: 0.1660 - val_mean_absolute_error_labels: 1.5570
# Epoch 20/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1603 - mean_absolute_error_labels: 1.5325 - val_loss: 0.1685 - val_mean_absolute_error_labels: 1.5746
# Epoch 21/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1602 - mean_absolute_error_labels: 1.5218 - val_loss: 0.1698 - val_mean_absolute_error_labels: 1.4973
# Epoch 22/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1598 - mean_absolute_error_labels: 1.5242 - val_loss: 0.1658 - val_mean_absolute_error_labels: 1.5237
# Epoch 23/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1596 - mean_absolute_error_labels: 1.5257 - val_loss: 0.1668 - val_mean_absolute_error_labels: 1.4905
# Epoch 24/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1592 - mean_absolute_error_labels: 1.5245 - val_loss: 0.1662 - val_mean_absolute_error_labels: 1.5218
# Epoch 25/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1591 - mean_absolute_error_labels: 1.5270 - val_loss: 0.1660 - val_mean_absolute_error_labels: 1.5459
# Epoch 26/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1586 - mean_absolute_error_labels: 1.5208 - val_loss: 0.1686 - val_mean_absolute_error_labels: 1.4913
# Epoch 27/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1590 - mean_absolute_error_labels: 1.5225 - val_loss: 0.1680 - val_mean_absolute_error_labels: 1.5824
# Epoch 28/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1587 - mean_absolute_error_labels: 1.5205 - val_loss: 0.1663 - val_mean_absolute_error_labels: 1.5164
# Epoch 29/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1582 - mean_absolute_error_labels: 1.5146 - val_loss: 0.1678 - val_mean_absolute_error_labels: 1.5944
# Epoch 30/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1581 - mean_absolute_error_labels: 1.5183 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5061
# Epoch 31/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1579 - mean_absolute_error_labels: 1.5128 - val_loss: 0.1667 - val_mean_absolute_error_labels: 1.5603
# Epoch 32/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1577 - mean_absolute_error_labels: 1.5177 - val_loss: 0.1674 - val_mean_absolute_error_labels: 1.5170
# Epoch 33/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1578 - mean_absolute_error_labels: 1.5193 - val_loss: 0.1661 - val_mean_absolute_error_labels: 1.5276
# Epoch 34/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1575 - mean_absolute_error_labels: 1.5140 - val_loss: 0.1676 - val_mean_absolute_error_labels: 1.5304
# Epoch 35/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1573 - mean_absolute_error_labels: 1.5207 - val_loss: 0.1673 - val_mean_absolute_error_labels: 1.5739
# Epoch 36/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1570 - mean_absolute_error_labels: 1.5178 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5024
# Epoch 37/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1568 - mean_absolute_error_labels: 1.5116 - val_loss: 0.1677 - val_mean_absolute_error_labels: 1.5405
# Epoch 38/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1567 - mean_absolute_error_labels: 1.5143 - val_loss: 0.1700 - val_mean_absolute_error_labels: 1.5889
# Epoch 39/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1567 - mean_absolute_error_labels: 1.5093 - val_loss: 0.1676 - val_mean_absolute_error_labels: 1.5172
# Epoch 40/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1566 - mean_absolute_error_labels: 1.5104 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.4869
# Epoch 41/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1561 - mean_absolute_error_labels: 1.5075 - val_loss: 0.1676 - val_mean_absolute_error_labels: 1.5353
# Epoch 42/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1561 - mean_absolute_error_labels: 1.5088 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5434
# Epoch 43/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1562 - mean_absolute_error_labels: 1.5157 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5822
# Epoch 44/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1559 - mean_absolute_error_labels: 1.5081 - val_loss: 0.1682 - val_mean_absolute_error_labels: 1.5757
# Epoch 45/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1556 - mean_absolute_error_labels: 1.5110 - val_loss: 0.1677 - val_mean_absolute_error_labels: 1.5200
# Epoch 46/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1555 - mean_absolute_error_labels: 1.5061 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5633
# Epoch 47/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1556 - mean_absolute_error_labels: 1.5115 - val_loss: 0.1684 - val_mean_absolute_error_labels: 1.5251
# Epoch 48/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1555 - mean_absolute_error_labels: 1.5145 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5183
# Epoch 49/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1549 - mean_absolute_error_labels: 1.5078 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5954
# Epoch 50/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1552 - mean_absolute_error_labels: 1.5120 - val_loss: 0.1680 - val_mean_absolute_error_labels: 1.5557
# Epoch 51/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1549 - mean_absolute_error_labels: 1.5122 - val_loss: 0.1689 - val_mean_absolute_error_labels: 1.5506
# Epoch 52/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1549 - mean_absolute_error_labels: 1.5140 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.4918
# Epoch 53/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1550 - mean_absolute_error_labels: 1.5133 - val_loss: 0.1689 - val_mean_absolute_error_labels: 1.5157
# Epoch 54/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1546 - mean_absolute_error_labels: 1.5141 - val_loss: 0.1701 - val_mean_absolute_error_labels: 1.5415
# Epoch 55/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1545 - mean_absolute_error_labels: 1.5135 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5542
# Epoch 56/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1546 - mean_absolute_error_labels: 1.5079 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5481
# Epoch 57/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1545 - mean_absolute_error_labels: 1.5130 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5693
# Epoch 58/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1542 - mean_absolute_error_labels: 1.5126 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5889
# Epoch 59/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1542 - mean_absolute_error_labels: 1.5092 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5412
# Epoch 60/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1541 - mean_absolute_error_labels: 1.5051 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.5117
# Epoch 61/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1540 - mean_absolute_error_labels: 1.5106 - val_loss: 0.1691 - val_mean_absolute_error_labels: 1.5245
# Epoch 62/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1539 - mean_absolute_error_labels: 1.5079 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.4952
# Epoch 63/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1538 - mean_absolute_error_labels: 1.5047 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.5523
# Epoch 64/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1537 - mean_absolute_error_labels: 1.5080 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5434
# Epoch 65/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1538 - mean_absolute_error_labels: 1.5036 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.5373
# Epoch 66/70
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1536 - mean_absolute_error_labels: 1.5012 - val_loss: 0.1718 - val_mean_absolute_error_labels: 1.5458
# Epoch 67/70
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1533 - mean_absolute_error_labels: 1.5074 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5029
# Epoch 68/70
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1533 - mean_absolute_error_labels: 1.5095 - val_loss: 0.1728 - val_mean_absolute_error_labels: 1.5570
# Epoch 69/70
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1533 - mean_absolute_error_labels: 1.5118 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5235
# Epoch 70/70
# 1114/1114 [==============================] - 2s 1ms/step - loss: 0.1530 - mean_absolute_error_labels: 1.5102 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5116

# %%
# model_corn_only_2 = keras.models.load_model("Models/model_corn_only_2/model.keras")
# with open('Models/model_corn_only_2/trainHistoryDict', "rb") as file_pi:
#     history_model_corn_only_2 = pickle.load(file_pi)
history_model_es_corn = history_model_es_corn.history

# %%
# monitor='loss', patience=20, Epochs: 300
plt.plot(history_model_es_corn['mean_absolute_error_labels'])
plt.plot(history_model_es_corn['val_mean_absolute_error_labels'])
plt.title('Model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
model_es_corn_ordinal_logits_train = model_es_corn.predict(X_train_L1reg_np)
model_es_corn_ordinal_logits_valid = model_es_corn.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
model_es_corn_tensor_probs_train = coral.corn_ordinal_softmax(model_es_corn_ordinal_logits_train)
model_es_corn_tensor_probs_valid = coral.corn_ordinal_softmax(model_es_corn_ordinal_logits_valid)

# Obtain labels from probabilities
model_es_corn_labels_train = coral.cumprobs_to_label(model_es_corn_tensor_probs_train)
model_es_corn_labels_valid = coral.cumprobs_to_label(model_es_corn_tensor_probs_valid)
# Out:
# 1114/1114 [==============================] - 1s 757us/step
# 372/372 [==============================] - 0s 714us/step

# %%
# In train
# monitor='loss', patience=20, Took Epochs: 68
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_es_corn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_es_corn=QuadraticWeightedKappa(y_train, model_es_corn_tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_es_corn)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 821us/step - loss: 0.1514 - mean_absolute_error_labels: 1.4701
# [Loss, Mean Absolute Error Labels] : [0.15135325491428375, 1.470096468925476]
# Quadratic Weighted Kappa on training set: 0.55647045

# %%
# In validation
# monitor='loss', patience=20, Took Epochs: 68

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_es_corn.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_es_corn = QuadraticWeightedKappa(y_valid, model_es_corn_tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_es_corn)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 859us/step - loss: 0.1704 - mean_absolute_error_labels: 1.5116
# [Loss, Mean Absolute Error Labels] : [0.17043925821781158, 1.5115927457809448]
# Quadratic Weighted Kappa on validation set: 0.51552045

# %%
model_corn_only_2_bias = baseline-qwk_train_model_corn_only_2
model_corn_only_2_var = qwk_train_model_corn_only_2-qwk_valid_model_mlp_3_bn
print("Bias / Variance of the model: ")
print(round(model_corn_only_2_bias,3),"/",round(model_corn_only_2_var,3))
# Out:
# Bias / Variance of the model:
# 0.143 / 0.036

# %% [markdown]
# #### CORN + BN

# %%
model_es_corn_bn = tuner_corn_2.hypermodel.build(hyps_corn_2)

# %%
# Fit with the entire dataset.
# Epochs= 22, monitor='val_loss', patience=20
history_model_es_corn_bn=model_es_corn_bn.fit(x=X_train_L1reg_np, y=y_train, epochs=100, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights= True)])
# Out:
# Epoch 1/100
# 1114/1114 [==============================] - 5s 2ms/step - loss: 0.1924 - mean_absolute_error_labels: 1.7271 - val_loss: 0.1855 - val_mean_absolute_error_labels: 1.5693
# Epoch 2/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1831 - mean_absolute_error_labels: 1.6530 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.6217
# Epoch 3/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1811 - mean_absolute_error_labels: 1.6224 - val_loss: 0.1813 - val_mean_absolute_error_labels: 1.5395
# Epoch 4/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1802 - mean_absolute_error_labels: 1.6135 - val_loss: 0.1908 - val_mean_absolute_error_labels: 1.4730
# Epoch 5/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1784 - mean_absolute_error_labels: 1.5965 - val_loss: 0.1780 - val_mean_absolute_error_labels: 1.5440
# Epoch 6/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1773 - mean_absolute_error_labels: 1.6017 - val_loss: 0.1847 - val_mean_absolute_error_labels: 1.6238
# Epoch 7/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1774 - mean_absolute_error_labels: 1.6035 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.5553
# Epoch 8/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1757 - mean_absolute_error_labels: 1.6037 - val_loss: 0.1755 - val_mean_absolute_error_labels: 1.6614
# Epoch 9/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6121 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5721
# Epoch 10/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1755 - mean_absolute_error_labels: 1.6080 - val_loss: 0.1766 - val_mean_absolute_error_labels: 1.4276
# Epoch 11/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1747 - mean_absolute_error_labels: 1.6040 - val_loss: 0.1706 - val_mean_absolute_error_labels: 1.5267
# Epoch 12/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1742 - mean_absolute_error_labels: 1.6112 - val_loss: 0.1740 - val_mean_absolute_error_labels: 1.4723
# Epoch 13/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1730 - mean_absolute_error_labels: 1.5836 - val_loss: 0.1729 - val_mean_absolute_error_labels: 1.5884
# Epoch 14/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1729 - mean_absolute_error_labels: 1.5939 - val_loss: 0.1771 - val_mean_absolute_error_labels: 1.6938
# Epoch 15/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.6106 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5801
# Epoch 16/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1731 - mean_absolute_error_labels: 1.5940 - val_loss: 0.1761 - val_mean_absolute_error_labels: 1.5722
# Epoch 17/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1720 - mean_absolute_error_labels: 1.5869 - val_loss: 0.1789 - val_mean_absolute_error_labels: 1.5878
# Epoch 18/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5856 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.6120
# Epoch 19/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1718 - mean_absolute_error_labels: 1.5875 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5162
# Epoch 20/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1708 - mean_absolute_error_labels: 1.5779 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5913
# Epoch 21/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1710 - mean_absolute_error_labels: 1.5958 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.4766
# Epoch 22/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1711 - mean_absolute_error_labels: 1.5960 - val_loss: 0.1737 - val_mean_absolute_error_labels: 1.4801
# Epoch 23/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1706 - mean_absolute_error_labels: 1.5845 - val_loss: 0.1694 - val_mean_absolute_error_labels: 1.5763
# Epoch 24/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1701 - mean_absolute_error_labels: 1.5945 - val_loss: 0.1812 - val_mean_absolute_error_labels: 1.5050
# Epoch 25/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1695 - mean_absolute_error_labels: 1.5813 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.6803
# Epoch 26/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1693 - mean_absolute_error_labels: 1.5778 - val_loss: 0.1765 - val_mean_absolute_error_labels: 1.6016
# Epoch 27/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1693 - mean_absolute_error_labels: 1.5834 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5523
# Epoch 28/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1700 - mean_absolute_error_labels: 1.5911 - val_loss: 0.1697 - val_mean_absolute_error_labels: 1.5462
# Epoch 29/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1693 - mean_absolute_error_labels: 1.5820 - val_loss: 0.1882 - val_mean_absolute_error_labels: 1.7476
# Epoch 30/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5714 - val_loss: 0.1711 - val_mean_absolute_error_labels: 1.6180
# Epoch 31/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1687 - mean_absolute_error_labels: 1.5788 - val_loss: 0.1743 - val_mean_absolute_error_labels: 1.7005
# Epoch 32/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5647 - val_loss: 0.1734 - val_mean_absolute_error_labels: 1.5319
# Epoch 33/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5634 - val_loss: 0.1695 - val_mean_absolute_error_labels: 1.5825
# Epoch 34/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1686 - mean_absolute_error_labels: 1.5787 - val_loss: 0.1731 - val_mean_absolute_error_labels: 1.5920
# Epoch 35/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1684 - mean_absolute_error_labels: 1.5763 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5429
# Epoch 36/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1678 - mean_absolute_error_labels: 1.5719 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.5482
# Epoch 37/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5713 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.6638
# Epoch 38/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1671 - mean_absolute_error_labels: 1.5720 - val_loss: 0.1733 - val_mean_absolute_error_labels: 1.5761
# Epoch 39/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1674 - mean_absolute_error_labels: 1.5578 - val_loss: 0.1709 - val_mean_absolute_error_labels: 1.6389
# Epoch 40/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1675 - mean_absolute_error_labels: 1.5776 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.5241
# Epoch 41/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1671 - mean_absolute_error_labels: 1.5926 - val_loss: 0.1764 - val_mean_absolute_error_labels: 1.6400
# Epoch 42/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1674 - mean_absolute_error_labels: 1.5747 - val_loss: 0.1712 - val_mean_absolute_error_labels: 1.5320
# Epoch 43/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5660 - val_loss: 0.1714 - val_mean_absolute_error_labels: 1.5336
# Epoch 44/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1668 - mean_absolute_error_labels: 1.5715 - val_loss: 0.1735 - val_mean_absolute_error_labels: 1.6137
# Epoch 45/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1670 - mean_absolute_error_labels: 1.5582 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.5381
# Epoch 46/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1669 - mean_absolute_error_labels: 1.5576 - val_loss: 0.1724 - val_mean_absolute_error_labels: 1.5468
# Epoch 47/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1663 - mean_absolute_error_labels: 1.5628 - val_loss: 0.1716 - val_mean_absolute_error_labels: 1.5605
# Epoch 48/100
# 1114/1114 [==============================] - 2s 2ms/step - loss: 0.1666 - mean_absolute_error_labels: 1.5408 - val_loss: 0.1727 - val_mean_absolute_error_labels: 1.5612

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
model_es_corn_bn_ordinal_logits_train = model_es_corn_bn.predict(X_train_L1reg_np)
model_es_corn_bn_ordinal_logits_valid = model_es_corn_bn.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
model_es_corn_bn_tensor_probs_train = coral.corn_ordinal_softmax(model_es_corn_bn_ordinal_logits_train)
model_es_corn_bn_tensor_probs_valid = coral.corn_ordinal_softmax(model_es_corn_bn_ordinal_logits_valid)

# Obtain labels from probabilities
model_es_corn_bn_labels_train = coral.cumprobs_to_label(model_es_corn_bn_tensor_probs_train)
model_es_corn_bn_labels_valid = coral.cumprobs_to_label(model_es_corn_bn_tensor_probs_valid)
# Out:
# 1114/1114 [==============================] - 1s 803us/step
# 372/372 [==============================] - 0s 838us/step

# %%
#In train
# Epochs= 22, monitor='val_loss', patience=20
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_es_corn_bn.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_es_corn_bn = QuadraticWeightedKappa(y_train, model_es_corn_bn_tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_es_corn_bn)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 964us/step - loss: 0.1597 - mean_absolute_error_labels: 1.5574
# [Loss, Mean Absolute Error Labels] : [0.15972940623760223, 1.5573571920394897]
# Quadratic Weighted Kappa on training set: 0.5189632

# %%
#In validation
# Epochs= 22, monitor='val_loss', patience=30

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_2.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_2 = QuadraticWeightedKappa(y_valid, model_es_corn_bn_tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on validation set:", qwk_valid_model_corn_2)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 1ms/step - loss: 0.1747 - mean_absolute_error_labels: 1.4772
# [Loss, Mean Absolute Error Labels] : [0.17470628023147583, 1.4772346019744873]
# Quadratic Weighted Kappa on validation set: 0.5075833

# %% [markdown]
# ### CORN +BN +0.1 DO

# %%
# Get the optimal hyperparameters
model_corn_do_01_es = tuner_corn_do_01.hypermodel.build(hyps_corn_do_01)
print(hyps_corn_do_01.values)
# Out:
# {'batch_norm': True, 'hidden_layers': 5, 'units_1': 124, 'units_2': 124, 'units_3': 124, 'units_4': 17, 'units_5': 124, 'dropout': True, 'dropout_rate': 0.1, 'learning_rate': 0.04621726369179639, 'batch_size': 64, 'tuner/epochs': 100, 'tuner/initial_epoch': 34, 'tuner/bracket': 4, 'tuner/round': 4, 'tuner/trial_id': '0142'}

# %%
# monitor='loss', patience=20, Epochs= 118
history_model_corn_do_01_es=model_corn_do_01_es.fit(x=X_train_L1reg_np, y=y_train, epochs=100, validation_data=(X_valid_L1reg_np, y_valid), callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights= True)])
# Out:
# Epoch 1/100
# 1114/1114 [==============================] - 7s 3ms/step - loss: 0.1983 - mean_absolute_error_labels: 1.7824 - val_loss: 0.1861 - val_mean_absolute_error_labels: 1.5338
# Epoch 2/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1876 - mean_absolute_error_labels: 1.7013 - val_loss: 0.1805 - val_mean_absolute_error_labels: 1.5853
# Epoch 3/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1861 - mean_absolute_error_labels: 1.6826 - val_loss: 0.1820 - val_mean_absolute_error_labels: 1.6278
# Epoch 4/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1850 - mean_absolute_error_labels: 1.6855 - val_loss: 0.1775 - val_mean_absolute_error_labels: 1.5204
# Epoch 5/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1838 - mean_absolute_error_labels: 1.6613 - val_loss: 0.1758 - val_mean_absolute_error_labels: 1.5079
# Epoch 6/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1832 - mean_absolute_error_labels: 1.6665 - val_loss: 0.1790 - val_mean_absolute_error_labels: 1.6316
# Epoch 7/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1827 - mean_absolute_error_labels: 1.6690 - val_loss: 0.1738 - val_mean_absolute_error_labels: 1.5058
# Epoch 8/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1814 - mean_absolute_error_labels: 1.6521 - val_loss: 0.1770 - val_mean_absolute_error_labels: 1.6356
# Epoch 9/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1820 - mean_absolute_error_labels: 1.6690 - val_loss: 0.1776 - val_mean_absolute_error_labels: 1.7137
# Epoch 10/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1815 - mean_absolute_error_labels: 1.6627 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5649
# Epoch 11/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1807 - mean_absolute_error_labels: 1.6545 - val_loss: 0.1725 - val_mean_absolute_error_labels: 1.5041
# Epoch 12/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1803 - mean_absolute_error_labels: 1.6420 - val_loss: 0.1745 - val_mean_absolute_error_labels: 1.6521
# Epoch 13/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1797 - mean_absolute_error_labels: 1.6438 - val_loss: 0.1753 - val_mean_absolute_error_labels: 1.5548
# Epoch 14/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1791 - mean_absolute_error_labels: 1.6479 - val_loss: 0.1721 - val_mean_absolute_error_labels: 1.5956
# Epoch 15/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1786 - mean_absolute_error_labels: 1.6442 - val_loss: 0.1746 - val_mean_absolute_error_labels: 1.4794
# Epoch 16/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1788 - mean_absolute_error_labels: 1.6363 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.6135
# Epoch 17/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1778 - mean_absolute_error_labels: 1.6284 - val_loss: 0.1757 - val_mean_absolute_error_labels: 1.5161
# Epoch 18/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1779 - mean_absolute_error_labels: 1.6309 - val_loss: 0.1767 - val_mean_absolute_error_labels: 1.7192
# Epoch 19/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1775 - mean_absolute_error_labels: 1.6245 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5010
# Epoch 20/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1769 - mean_absolute_error_labels: 1.6181 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5413
# Epoch 21/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1768 - mean_absolute_error_labels: 1.6228 - val_loss: 0.1741 - val_mean_absolute_error_labels: 1.4643
# Epoch 22/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1771 - mean_absolute_error_labels: 1.6239 - val_loss: 0.1723 - val_mean_absolute_error_labels: 1.5617
# Epoch 23/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1766 - mean_absolute_error_labels: 1.6277 - val_loss: 0.1699 - val_mean_absolute_error_labels: 1.5374
# Epoch 24/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1765 - mean_absolute_error_labels: 1.6228 - val_loss: 0.1726 - val_mean_absolute_error_labels: 1.5225
# Epoch 25/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1765 - mean_absolute_error_labels: 1.6177 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.5911
# Epoch 26/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1761 - mean_absolute_error_labels: 1.6143 - val_loss: 0.1710 - val_mean_absolute_error_labels: 1.5879
# Epoch 27/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1759 - mean_absolute_error_labels: 1.6128 - val_loss: 0.1687 - val_mean_absolute_error_labels: 1.5213
# Epoch 28/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1758 - mean_absolute_error_labels: 1.6150 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5374
# Epoch 29/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1756 - mean_absolute_error_labels: 1.6087 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.6114
# Epoch 30/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1752 - mean_absolute_error_labels: 1.6129 - val_loss: 0.1717 - val_mean_absolute_error_labels: 1.6028
# Epoch 31/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1752 - mean_absolute_error_labels: 1.6083 - val_loss: 0.1826 - val_mean_absolute_error_labels: 1.9341
# Epoch 32/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1750 - mean_absolute_error_labels: 1.6133 - val_loss: 0.1703 - val_mean_absolute_error_labels: 1.5232
# Epoch 33/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1748 - mean_absolute_error_labels: 1.6102 - val_loss: 0.1687 - val_mean_absolute_error_labels: 1.5502
# Epoch 34/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1754 - mean_absolute_error_labels: 1.6087 - val_loss: 0.1688 - val_mean_absolute_error_labels: 1.5259
# Epoch 35/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1746 - mean_absolute_error_labels: 1.6103 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5800
# Epoch 36/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.6025 - val_loss: 0.1687 - val_mean_absolute_error_labels: 1.5707
# Epoch 37/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.6042 - val_loss: 0.1704 - val_mean_absolute_error_labels: 1.5788
# Epoch 38/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5981 - val_loss: 0.1750 - val_mean_absolute_error_labels: 1.6734
# Epoch 39/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1740 - mean_absolute_error_labels: 1.5975 - val_loss: 0.1707 - val_mean_absolute_error_labels: 1.5867
# Epoch 40/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1738 - mean_absolute_error_labels: 1.5992 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5400
# Epoch 41/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1734 - mean_absolute_error_labels: 1.6007 - val_loss: 0.1715 - val_mean_absolute_error_labels: 1.4973
# Epoch 42/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.5997 - val_loss: 0.1688 - val_mean_absolute_error_labels: 1.4846
# Epoch 43/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1743 - mean_absolute_error_labels: 1.6042 - val_loss: 0.1696 - val_mean_absolute_error_labels: 1.5146
# Epoch 44/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1739 - mean_absolute_error_labels: 1.6046 - val_loss: 0.1689 - val_mean_absolute_error_labels: 1.5297
# Epoch 45/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1733 - mean_absolute_error_labels: 1.6143 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.4749
# Epoch 46/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.5841 - val_loss: 0.1689 - val_mean_absolute_error_labels: 1.5610
# Epoch 47/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1735 - mean_absolute_error_labels: 1.6001 - val_loss: 0.1730 - val_mean_absolute_error_labels: 1.5343
# Epoch 48/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1726 - mean_absolute_error_labels: 1.5778 - val_loss: 0.1705 - val_mean_absolute_error_labels: 1.5738
# Epoch 49/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1739 - mean_absolute_error_labels: 1.5967 - val_loss: 0.1693 - val_mean_absolute_error_labels: 1.5254
# Epoch 50/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1722 - mean_absolute_error_labels: 1.5961 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5745
# Epoch 51/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1723 - mean_absolute_error_labels: 1.5837 - val_loss: 0.1708 - val_mean_absolute_error_labels: 1.5428
# Epoch 52/100
# 1114/1114 [==============================] - 3s 3ms/step - loss: 0.1728 - mean_absolute_error_labels: 1.5872 - val_loss: 0.1702 - val_mean_absolute_error_labels: 1.4643

# %%
history_model_corn_do_01_es=history_model_corn_do_01_es.history

# %%
plt.plot(history_model_corn_do_01_es['mean_absolute_error_labels'])
plt.plot(history_model_corn_do_01_es['val_mean_absolute_error_labels'])
plt.title('model mean_absolute_error_labels')
plt.ylabel('mean_absolute_error_labels')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
print("Performance on datasets")

# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
model_corn_do_01_es_ordinal_logits_train = model_corn_do_01_es.predict(X_train_L1reg_np)
model_corn_do_01_es_ordinal_logits_valid = model_corn_do_01_es.predict(X_valid_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
model_corn_do_01_es_tensor_probs_train = coral.corn_ordinal_softmax(model_corn_do_01_es_ordinal_logits_train)
model_corn_do_01_es_tensor_probs_valid = coral.corn_ordinal_softmax(model_corn_do_01_es_ordinal_logits_valid)

# Convert the tensor into a pandas dataframe.
model_corn_do_01_es_labels_train = coral.cumprobs_to_label(model_corn_do_01_es_tensor_probs_train)
model_corn_do_01_es_labels_valid = coral.cumprobs_to_label(model_corn_do_01_es_tensor_probs_valid)
# Out:
# Performance on datasets
# 1114/1114 [==============================] - 1s 869us/step
# 372/372 [==============================] - 0s 853us/step

# %%
#In train
# monitor='loss', patience=20, Epochs= 118
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_01_es.evaluate(X_train_L1reg_np, y_train))
qwk_train_model_corn_do_01_es = QuadraticWeightedKappa(y_train, model_corn_do_01_es_tensor_probs_train).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_train_model_corn_do_01_es)
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 1ms/step - loss: 0.1607 - mean_absolute_error_labels: 1.5031
# [Loss, Mean Absolute Error Labels] : [0.16069923341274261, 1.5031137466430664]
# Quadratic Weighted Kappa on training set: 0.5144448

# %%
#In validation
# monitor='loss', patience=20, Epochs= 118

print("Validation evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", model_corn_do_01_es.evaluate(X_valid_L1reg_np, y_valid))
qwk_valid_model_corn_do_01_es = QuadraticWeightedKappa(y_valid, model_corn_do_01_es_tensor_probs_valid).numpy()
print("Quadratic Weighted Kappa on training set:", qwk_valid_model_corn_do_01_es)
# Out:
# Validation evaluation
#
# 372/372 [==============================] - 0s 989us/step - loss: 0.1687 - mean_absolute_error_labels: 1.5213
# [Loss, Mean Absolute Error Labels] : [0.16866078972816467, 1.5213373899459839]
# Quadratic Weighted Kappa on training set: 0.50626636

# %% [markdown]
# <a name='3.3'></a>
# ## 3.3 Model Selection
# From all models, we can observe that the best one turned out to be the CORN model with the batch normalzation.

# %% [markdown]
# <a name='4'></a>
# # 4. Evaluate the performance of the final model

# %% [markdown]
# In this section, we will evaluate the performance of our selected model on the testing set, and also compare its performance on the QWK metric and additionaly, its balanced accuracy, with the machine learning models constructed and fitted at [[10]](#R-10)
# These models include Support Vector Machines with different kernels, decision trees, random forests, and Gradient Boosting Machines.
#
# In this final section, we'll employ functions from both scikit-learn and scikit-plot libraries to visualize and evaluate the performance of our tuned model on the testing set. It's worth noting that, as mentioned earlier, all the following metrics except for the Quadratic Weighted Kappa (QWK) categorize predictions in a 'one-vs-rest' fashion, and therefore, they may not accurately reflect the difficulty level in correctly classifying each applicant with the exact rating they were given. Execute the next code cells to display the reports.
#
#
# ### Classification Reports (Loss/Mean Absolute Error Labels/QuadraticWeightedKappa/Accuracy)¶
# In the following code, we will first see the loss and Mean absolute error labels on the test set, with which the hyperparameter optimization was performed.

# %%
# Use the best performing model to generate predictions (as probability estimates) on the test dataset.
best_model=model_es_corn

# %%
# Note that these are ordinal (cumulative) logits, not probabilities or regular logits.
best_model_ordinal_logits = best_model.predict(X_test_L1reg_np)

# Convert from logits to label probabilities. This is initially a tensorflow tensor.
best_model_tensor_probs = coral.corn_ordinal_softmax(best_model_ordinal_logits)

# Obtain labels from probabilities
best_model_labels = coral.cumprobs_to_label(best_model_tensor_probs)
# Out:
# 372/372 [==============================] - 0s 718us/step

# %%
best_model_PredProbs = best_model_tensor_probs

# Convert the probability estimates into label-encoded predictions, then convert back to the original set of classes.
best_model_Preds = np.argmax(best_model_PredProbs, axis=1)

# %%
#In test
# Epochs= 22, monitor='val_loss', patience=20
print("Train evaluation")
print()
print("[Loss, Mean Absolute Error Labels] :", best_model.evaluate(X_train_L1reg_np, y_train))
# Out:
# Train evaluation
#
# 1114/1114 [==============================] - 1s 814us/step - loss: 0.1514 - mean_absolute_error_labels: 1.4701
# [Loss, Mean Absolute Error Labels] : [0.15135325491428375, 1.470096468925476]

# %% [markdown]
# Now we'll evaluate the Quadratic Weighted Kappa Metric on the testing set of our best model.

# %%
qwk_best_model = QuadraticWeightedKappa(y_test, best_model_tensor_probs).numpy()
print("Quadratic Weighted Kappa on testing set:", qwk_best_model)
# Out:
# Quadratic Weighted Kappa on testing set: 0.5141014

# %% [markdown]
# Finally we'll calculate the accuracy of our model on the testing set.

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, best_model_Preds)
# Out:
# 0.5139344952429065

# %% [markdown]
# We can note a small error discrepancy between the validation set and the test set.
#
# ## Performance Comparison with Other ML Models
#
# The code below utilizes the accuracy and QWK scores imported from the machine learning models mentioned earlier, accessible from the link: https://colab.research.google.com/drive/1YX5K5EY3bL4R9UmahPVK_HEQm-m2AmVM#scrollTo=MOHu0CZWjDky . These scores are then compared to those obtained by the selected top-performing neural network.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
#pip install xgboost

# %%
ML_PredProbs= pickle.load(open('ML_Results/ML_PredProbs', 'rb'))
ML_Preds= pickle.load(open('ML_Results/ML_Preds', 'rb'))

# %%
Model_Names ={
 "1": "LogisticRegression         ",
 "2": "GaussianNB                 ",
 "3": "SVC(kernel='linear')       ",
 "4": "LinearSVC                  ",
 "5": "SVC(kernel='poly')         ",
 "6": "SVC(kernel='rbf')          ",
 "7": "SVC(kernel='sigmoid')      ",
 "8": "DecisionTreeClassifier     ",
 "9": "RandomForestClassifier     ",
 "10":"AdaBoostClassifier         ",
 "11":"GradientBoostingClassifier ",
 "12":"XGBClassifier              ",
}

# %%
from sklearn.metrics import accuracy_score
print("Quadratic Weighted Kappa of fitted ML Models")
print()
# Print performance for models 1 to 10
for i in range(1, 13):
    print("QWK Model", i, Model_Names[str(i)],":", round(QuadraticWeightedKappa(y_test, ML_PredProbs[str(i)]).numpy(),3))
print_colored("QWK Model CORN", color ='purple')
print(round(0.5141014,3))
# Out:
# Quadratic Weighted Kappa of fitted ML Models
#
# QWK Model 1 LogisticRegression          : 0.45
# QWK Model 2 GaussianNB                  : 0.412
# QWK Model 3 SVC(kernel='linear')        : 0.158
# QWK Model 4 LinearSVC                   : 0.435
# QWK Model 5 SVC(kernel='poly')          : 0.242
# QWK Model 6 SVC(kernel='rbf')           : 0.275
# QWK Model 7 SVC(kernel='sigmoid')       : 0.023
# QWK Model 8 DecisionTreeClassifier      : 0.424
# QWK Model 9 RandomForestClassifier      : 0.468
# QWK Model 10 AdaBoostClassifier          : 0.47
# QWK Model 11 GradientBoostingClassifier  : 0.51
# QWK Model 12 XGBClassifier               : 0.492
# <text style=color:purple>QWK Model CORN</text>
# 0.514

# %%
y_valid = le.inverse_transform(y_valid)
y_test= le.inverse_transform(y_test)

# %%
from sklearn.metrics import accuracy_score
print_colored("Accuracy of fitted ML Models", color='purple')
print()
# Print performance for models 1 to 10
for i in range(1, 11):
    print("Accuracy Model", i, Model_Names[str(i)],":", round(accuracy_score(y_test, ML_Preds[str(i)]),3))

print("Accuracy Model", 12, Model_Names[str(12)],":", round(accuracy_score(y_test, ML_Preds[str(12)]),3))
print_colored("Accuracy Model CORN", color ='purple')
print(round(0.513934,3))
# Out:
# <text style=color:purple>Accuracy of fitted ML Models</text>
# Accuracy Model 1 LogisticRegression          : 0.476
# Accuracy Model 2 GaussianNB                  : 0.398
# Accuracy Model 3 SVC(kernel='linear')        : 0.364
# Accuracy Model 4 LinearSVC                   : 0.469
# Accuracy Model 5 SVC(kernel='poly')          : 0.379
# Accuracy Model 6 SVC(kernel='rbf')           : 0.408
# Accuracy Model 7 SVC(kernel='sigmoid')       : 0.325
# Accuracy Model 8 DecisionTreeClassifier      : 0.514
# Accuracy Model 9 RandomForestClassifier      : 0.52
# Accuracy Model 10 AdaBoostClassifier          : 0.498
# Accuracy Model 12 XGBClassifier               : 0.527
# <text style=color:purple>Accuracy Model CORN</text>
# 0.514

# %% [markdown]
# ## Other Classification Metrics

# %%
# Convert back to the original set of classes.
best_model_Preds = le.inverse_transform(best_model_Preds)

# %% [markdown]
# ### Classification Reports (Precisions/Recalls/F1-Scores)

# %%
print(classification_report(y_test, best_model_Preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1241
#            1       0.26      0.15      0.19      1310
#            2       0.02      0.08      0.03       203
#            3       0.07      0.02      0.03       286
#            4       0.02      0.01      0.01      1086
#            5       0.15      0.06      0.08      2247
#            6       0.15      0.27      0.19      1606
#            7       0.13      0.03      0.05      3898
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.08     11877
#    macro avg       0.09      0.07      0.07     11877
# weighted avg       0.12      0.08      0.08     11877
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(y_test, best_model_Preds)
# Out:
# <Axes: title={'center': 'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### ROC Curve
# The plot below displays the ROC curves for our model. This curve is a graph of the true positive rate versus the false positive rate for each class.

# %%
# Display ROC Curves
plot_roc(y_test, best_model_PredProbs)
# Out:
# <Axes: title={'center': 'ROC Curves'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# <a name='6'></a>
# ## 5 - Bibliography
#
# <a name='R-1'></a>
# 1. Kaggle. (n.d.). Prudential Life Insurance Assessment: Evaluation. Retrieved from https://www.kaggle.com/competitions/prudential-life-insurance-assessment/overview/evaluation.
# <a name='R-2'></a>
# 2. Keras Tuner documentation for tuners. (n.d.). Retrieved from https://keras.io/api/keras_tuner/tuners/.
# <a name='R-3'></a>
# 3. Keras API documentation for metrics. (n.d.). Retrieved from https://keras.io/api/metrics/.
# <a name='R-4'></a>
# 4. Keras API documentation for losses. (n.d.). Retrieved from https://keras.io/api/losses/.
# <a name='R-5'></a>
# 5. Keras Tuner documentation for objective. (n.d.). Retrieved from https://keras.io/api/keras_tuner/tuners/objective/.
# <a name='R-6'></a>
# 6. Keras: Creating custom metrics. (n.d.). Retrieved from https://keras.io/api/metrics/#creating-custom-metrics.
# <a name='R-7'></a>
# 7. Keras. (2021, October 27). Tailoring the search space. Retrieved from https://keras.io/guides/keras_tuner/tailor_the_search_space/.
# <a name='R-8'></a>
# 8. Keras API documentation for Activations. Retrieved from https://keras.io/api/layers/activations/.
# <a name='R-9'></a>
# 9. Keras API documentation for Hyperparameters. Retrieved from https://keras.io/api/keras_tuner/hyperparameters/.
# <a name='R-10'></a>
# 10. Kaggle. (n.d.). Machine Learning for Risk Classification. Retrieved from https://www.kaggle.com/code/karansarpal/machine-learning-for-risk-classification-ks.
# <a name='R-11'></a>
# 11. Balasubramanian, R., Libarikian, A., & McElhaney, D. (2021). Insurance 2030—The impact of AI on the future of insurance. McKinsey & Company website. Retrieved from https://www.mckinsey.com/industries/financial-services/our-insights/insurance-2030-the-impact-of-ai-on-the-future-of-insurance#
